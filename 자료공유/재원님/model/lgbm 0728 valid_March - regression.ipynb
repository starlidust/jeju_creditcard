# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data

# %%
data1 = pd.read_csv('../../Data/Jeju/201901-202003.csv')
data1 = data1.fillna('')
data2 = pd.read_csv('../../Data/Jeju/202004.csv')
data2 = data2.fillna('')

# %%
data = pd.concat([data1, data2])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26048114 entries, 0 to 1350321
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   REG_YYMM      int64
#  1   CARD_SIDO_NM  object
#  2   CARD_CCG_NM   object
#  3   STD_CLSS_NM   object
#  4   HOM_SIDO_NM   object
#  5   HOM_CCG_NM    object
#  6   AGE           object
#  7   SEX_CTGO_CD   int64
#  8   FLC           int64
#  9   CSTMR_CNT     int64
#  10  AMT           int64
#  11  CNT           int64
# dtypes: int64(6), object(6)
# memory usage: 2.5+ GB

# %% [markdown]
# #### 결측 처리

# %%
data.loc[data.CARD_CCG_NM.isna(),'CARD_CCG_NM'] = '세종'
data.loc[data.HOM_CCG_NM.isna(),'HOM_CCG_NM'] = '세종'

# %% [markdown]
# #### 18 사업체총조사

# %%
all_jobs_df = pd.read_csv('data/18 사업체총조사_키워드매칭.csv',encoding = 'cp949')
all_jobs_df = all_jobs_df[['행정구역별','데이터업종명','사업체수 (개)', '종사자수 (명)']]
all_jobs_df.columns = ['CARD_SIDO_NM','STD_CLSS_NM', 'company','employee']
all_jobs_df.employee = all_jobs_df.employee.apply(lambda x : x.replace("X","0")).astype(int)
all_jobs_df = all_jobs_df.groupby(['CARD_SIDO_NM','STD_CLSS_NM'])[['company','employee']].sum().reset_index()

all_jobs_df = all_jobs_df[~(all_jobs_df.CARD_SIDO_NM == '전국')]

# %% [markdown]
# #### 지역내 각 업종이 차지하는 매출비중

# %%
def local_percent(data):
    pivoted = data.pivot_table(index = ['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM'],columns ='REG_YYMM',values= "AMT",aggfunc='sum').reset_index()
    pivoted.fillna(0,inplace= True)

    #각 지역별(시군구)업종의 매출비율을 저장
    sidos = pivoted.CARD_SIDO_NM.unique()

    local_percent_df = pd.DataFrame()
    for sido in sidos:
        sample_sido = pivoted[pivoted.CARD_SIDO_NM == sido]
        sigungus = sample_sido.CARD_CCG_NM.unique()
        for sigungu in sigungus:
            sample = sample_sido[sample_sido.CARD_CCG_NM == sigungu]
            sum_arr = sample.iloc[:,3:].sum().values.reshape(1,-1)
            parcent_df = (sample.iloc[:,3:]/sum_arr)*100

            fin = pd.concat([sample.iloc[:,:3],parcent_df],axis=1)
            local_percent_df = pd.concat([local_percent_df,fin])

    #신규변수 LP(local percent) : 지역내 각 업종이 차지하는 매출비중
    local_percent_df = local_percent_df.melt(id_vars=['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM'],value_name='LP')
    return local_percent_df

# %% [markdown]
# #### 전체업종에서 각 지역업종이 차지하는 매출비중

# %%
def job_percent(data):
    pivoted = data.pivot_table(index = ['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM'],columns ='REG_YYMM',values= "AMT",aggfunc='sum').reset_index()
    pivoted.fillna(0,inplace= True)

    all_pivoted = data.pivot_table(index = ['STD_CLSS_NM'],columns ='REG_YYMM',values= "AMT",aggfunc= 'sum').reset_index()
    all_pivoted.fillna(0,inplace= True)
    all_pivoted = all_pivoted.set_index('STD_CLSS_NM')

    job_percent_df = pd.DataFrame()
    for job in all_pivoted.index:
        taget_df = pivoted[pivoted.STD_CLSS_NM == job]
        tail = (taget_df.iloc[:,3:]/all_pivoted.iloc[0].values)*100
        head = taget_df.iloc[:,:3]
        full = pd.concat([head,tail],axis =1)
        job_percent_df = pd.concat([job_percent_df,full])

    #신규변수 JP(Job percent): 전체업종에서 해당지역의 업종이 차이하는 비율
    job_percent_df = job_percent_df.melt(id_vars=['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM'],value_name='JP')
    return job_percent_df

# %%
local_percent_df = local_percent(data)
job_percent_df = job_percent(data)

# %% [markdown]
# #### 거래횟수와 이용고객과의 관계 (2019)

# %%
def cust_differ(data):
    data['differ'] = (data.CNT- data.CSTMR_CNT)
    
    #양수(단골)
    plus_custom = data[data['differ']>0]
    pivot_plus = plus_custom.pivot_table(index = ['CARD_SIDO_NM','STD_CLSS_NM'],columns = 'REG_YYMM', values= 'differ', aggfunc ='sum').reset_index()
    
    melt_plus = pivot_plus.melt(id_vars=['CARD_SIDO_NM','STD_CLSS_NM'],value_name='loyal')
    melt_plus['year'] = melt_plus['REG_YYMM'].apply(lambda x: int(str(x)[:4]))
    melt_plus['month'] = melt_plus['REG_YYMM'].apply(lambda x: int(str(x)[5:]))
    
    #2019만 사용
    melt_plus = melt_plus[melt_plus.year == 2019]
    melt_plus.drop(['year'],axis= 1,inplace = True)
    
    #음수(환불)
    minus_custom = data[data['differ']<0]
    pivot_minus = minus_custom.pivot_table(index = ['CARD_SIDO_NM','STD_CLSS_NM'],columns = 'REG_YYMM', values= 'differ', aggfunc ='sum').reset_index()
    
    melt_minus = pivot_minus.melt(id_vars=['CARD_SIDO_NM','STD_CLSS_NM'],value_name='refund')
    melt_minus['year'] = melt_minus['REG_YYMM'].apply(lambda x: int(str(x)[:4]))
    melt_minus['month'] = melt_minus['REG_YYMM'].apply(lambda x: int(str(x)[5:]))
    #2019만 사용
    melt_minus = melt_minus[melt_minus.year == 2019]
    melt_minus.drop(['year'],axis= 1,inplace = True)
    
  
    #둘 결헙
    cust_differ_df = pd.merge(melt_plus,melt_minus,how= 'outer')
    
    return cust_differ_df

# %%
trade_num_2019 = cust_differ(data)

# %% [markdown]
# #### 거래횟수와 이용고객과의 관계 (2020)

# %%
def cust_differ_2020(data):
    data['differ'] = (data.CNT- data.CSTMR_CNT)
    
    #양수(단골)
    plus_custom = data[data['differ']>0]
    pivot_plus = plus_custom.pivot_table(index = ['CARD_SIDO_NM','STD_CLSS_NM'],columns = 'REG_YYMM', values= 'differ', aggfunc ='sum').reset_index()
    
    melt_plus = pivot_plus.melt(id_vars=['CARD_SIDO_NM','STD_CLSS_NM'],value_name='loyal')
    melt_plus['year'] = melt_plus['REG_YYMM'].apply(lambda x: int(str(x)[:4]))
    melt_plus['month'] = melt_plus['REG_YYMM'].apply(lambda x: int(str(x)[5:]))
    
    #2020만 사용
    melt_plus = melt_plus[melt_plus.year == 2020]
    melt_plus.drop(['year'],axis= 1,inplace = True)
    
    #음수(환불)
    minus_custom = data[data['differ']<0]
    pivot_minus = minus_custom.pivot_table(index = ['CARD_SIDO_NM','STD_CLSS_NM'],columns = 'REG_YYMM', values= 'differ', aggfunc ='sum').reset_index()
    
    melt_minus = pivot_minus.melt(id_vars=['CARD_SIDO_NM','STD_CLSS_NM'],value_name='refund')
    melt_minus['year'] = melt_minus['REG_YYMM'].apply(lambda x: int(str(x)[:4]))
    melt_minus['month'] = melt_minus['REG_YYMM'].apply(lambda x: int(str(x)[5:]))
    #2020만 사용
    melt_minus = melt_minus[melt_minus.year == 2020]
    melt_minus.drop(['year'],axis= 1,inplace = True)
    
  
    #둘 결헙
    cust_differ_df = pd.merge(melt_plus,melt_minus,how= 'outer')
    
    return cust_differ_df

# %%
trade_num_2020 = cust_differ_2020(data)

# %%
trade_num = pd.concat([trade_num_2019, trade_num_2020])

# %%
trade_num.loyal = trade_num.loyal.fillna(-999)
trade_num.refund = trade_num.refund.fillna(999)

# %%
trade_num
# Out:
#      CARD_SIDO_NM           STD_CLSS_NM  REG_YYMM    loyal  month  refund
# 0              강원            건강보조식품 소매업  201901.0     80.0      1   -32.0
# 1              강원               골프장 운영업  201901.0  14890.0      1   999.0
# 2              강원           과실 및 채소 소매업  201901.0   7484.0      1   999.0
# 3              강원     관광 민예품 및 선물용품 소매업  201901.0    195.0      1   999.0
# 4              강원  그외 기타 분류안된 오락관련 서비스업  201901.0   -999.0      1   999.0
# ...           ...                   ...       ...      ...    ...     ...
# 2575           충북              휴양콘도 운영업  202004.0     62.0      4   999.0
# 2576           대전                  여행사업  202001.0   -999.0      1   999.0
# 2577           대전                  여행사업  202002.0   -999.0      2   999.0
# 2578           대전                  여행사업  202003.0   -999.0      3   999.0
# 2579           대전                  여행사업  202004.0   -999.0      4   999.0
#
# [10320 rows x 6 columns]

# %% [markdown]
# #### 추가변수 결합

# %%
data.shape
# Out:
# (26048114, 13)

# %%
local_percent_df
# Out:
#        CARD_SIDO_NM CARD_CCG_NM            STD_CLSS_NM REG_YYMM         LP
# 0                강원         강릉시             건강보조식품 소매업   201901   0.138432
# 1                강원         강릉시                골프장 운영업   201901   0.148825
# 2                강원         강릉시            과실 및 채소 소매업   201901   1.468549
# 3                강원         강릉시      관광 민예품 및 선물용품 소매업   201901   0.022661
# 4                강원         강릉시        그외 기타 스포츠시설 운영업   201901   0.003255
# ...             ...         ...                    ...      ...        ...
# 124523           충북         충주시  피자 햄버거 샌드위치 및 유사 음식점업   202004   1.362619
# 124524           충북         충주시                한식 음식점업   202004  18.402971
# 124525           충북         충주시                    호텔업   202004   0.059226
# 124526           충북         충주시          화장품 및 방향제 소매업   202004   0.368080
# 124527           충북         충주시               휴양콘도 운영업   202004   0.004580
#
# [124528 rows x 5 columns]

# %%
columns = ['REG_YYMM', 'CARD_SIDO_NM', 'CARD_CCG_NM', 'STD_CLSS_NM', 'HOM_SIDO_NM', 'AGE', 'SEX_CTGO_CD', 'FLC']
df = data.groupby(columns, as_index=False)[['AMT']].sum()

# %%
grouped = pd.merge(df,all_jobs_df,on =['CARD_SIDO_NM','STD_CLSS_NM'],how = 'left')
grouped = pd.merge(grouped,local_percent_df,on =['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM','REG_YYMM'],how = 'left')
grouped = pd.merge(grouped,job_percent_df,on =['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM','REG_YYMM'],how = 'left')
grouped = pd.merge(grouped, trade_num, on =['CARD_SIDO_NM','STD_CLSS_NM','REG_YYMM'], how = 'left')

# %%
grouped.head(5)
# Out:
#   REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM  AGE  SEX_CTGO_CD  \
# 0   201901           강원         강릉시  건강보조식품 소매업          강원  20s            1
# 1   201901           강원         강릉시  건강보조식품 소매업          강원  30s            1
# 2   201901           강원         강릉시  건강보조식품 소매업          강원  30s            2
# 3   201901           강원         강릉시  건강보조식품 소매업          강원  40s            1
# 4   201901           강원         강릉시  건강보조식품 소매업          강원  40s            1
#
#    FLC      AMT  company  employee        LP        JP  loyal  month  refund
# 0    1   311200    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0
# 1    2  1374500    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0
# 2    2   818700    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0
# 3    3  1717000    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0
# 4    4  1047300    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0

# %%
grouped.REG_YYMM = pd.to_datetime(grouped.REG_YYMM, format='%Y%m')

# %%
from sklearn.preprocessing import LabelEncoder

# 인코딩
dtypes = grouped.dtypes
encoders = {}
for column in grouped.columns:
    if str(dtypes[column]) == 'object':
        encoder = LabelEncoder()
        encoder.fit(grouped[column])
        encoders[column] = encoder
        
df_num = grouped.copy()        
for column in encoders.keys():
    encoder = encoders[column]
    df_num[column] = encoder.transform(grouped[column])

# %%
df_num
# Out:
#           REG_YYMM  CARD_SIDO_NM  CARD_CCG_NM  STD_CLSS_NM  HOM_SIDO_NM  AGE  \
# 0       2019-01-01             0            4            0            0    1
# 1       2019-01-01             0            4            0            0    2
# 2       2019-01-01             0            4            0            0    2
# 3       2019-01-01             0            4            0            0    3
# 4       2019-01-01             0            4            0            0    3
# ...            ...           ...          ...          ...          ...  ...
# 5630138 2020-04-01            16          202           40           16    1
# 5630139 2020-04-01            16          202           40           16    2
# 5630140 2020-04-01            16          202           40           16    3
# 5630141 2020-04-01            16          202           40           16    4
# 5630142 2020-04-01            16          202           40           16    5
#
#          SEX_CTGO_CD  FLC      AMT  company  employee        LP        JP  \
# 0                  1    1   311200    263.0     399.0  0.138432  0.279221
# 1                  1    2  1374500    263.0     399.0  0.138432  0.279221
# 2                  2    2   818700    263.0     399.0  0.138432  0.279221
# 3                  1    3  1717000    263.0     399.0  0.138432  0.279221
# 4                  1    4  1047300    263.0     399.0  0.138432  0.279221
# ...              ...  ...      ...      ...       ...       ...       ...
# 5630138            1    1    77000     11.0     492.0  0.004580  0.011570
# 5630139            1    2    92000     11.0     492.0  0.004580  0.011570
# 5630140            2    3   193000     11.0     492.0  0.004580  0.011570
# 5630141            1    4    86000     11.0     492.0  0.004580  0.011570
# 5630142            2    5   227000     11.0     492.0  0.004580  0.011570
#
#          loyal  month  refund
# 0         80.0    1.0   -32.0
# 1         80.0    1.0   -32.0
# 2         80.0    1.0   -32.0
# 3         80.0    1.0   -32.0
# 4         80.0    1.0   -32.0
# ...        ...    ...     ...
# 5630138   62.0    4.0   999.0
# 5630139   62.0    4.0   999.0
# 5630140   62.0    4.0   999.0
# 5630141   62.0    4.0   999.0
# 5630142   62.0    4.0   999.0
#
# [5630143 rows x 16 columns]

# %%
import datetime as dt

df_num['month'] = df_num['REG_YYMM'].dt.month
df_num['year'] = df_num['REG_YYMM'].dt.year

# %%
train_df = df_num[df_num['REG_YYMM'] < '2020-03-01']
validation_df = df_num[df_num['REG_YYMM'] == '2020-03-01']

# %%
# 7월 데이터 = 2020년의 평균값을 사용.

temp = df_num[df_num['REG_YYMM'] >= '2020']
temp = temp.groupby(['CARD_SIDO_NM', 'CARD_CCG_NM', 'STD_CLSS_NM',
                     'HOM_SIDO_NM', 'AGE', 'SEX_CTGO_CD', 'FLC'], as_index=False)[['company', 'employee', 
                                                            'LP', 'JP', 'loyal', 'month', 'refund', 'year']].mean()

# %%
temp.month = 7
temp = pd.concat([df_num[df_num['REG_YYMM'] == '2020-04-01'], temp])

# %%
temp = temp.drop(['REG_YYMM', 'AMT'], axis=1)

# %% [markdown]
# ### Light GBM

# %%
import lightgbm as lgb

# %%
train_df.head(1)
# Out:
#     REG_YYMM  CARD_SIDO_NM  CARD_CCG_NM  STD_CLSS_NM  HOM_SIDO_NM  AGE  \
# 0 2019-01-01             0            4            0            0    1
#
#    SEX_CTGO_CD  FLC     AMT  company  employee        LP        JP  loyal  \
# 0            1    1  311200    263.0     399.0  0.138432  0.279221   80.0
#
#    month  refund  year
# 0      1   -32.0  2019

# %%
train = train_df.drop(['AMT', 'REG_YYMM'], axis=1)
trian_label = np.log1p(train_df[['AMT']])

# %%
validation = validation_df.drop(['AMT', 'REG_YYMM'], axis=1)
validation_label = np.log1p(validation_df[['AMT']])

# %%
lgb_train = lgb.Dataset(train, label=trian_label)
lgb_eval = lgb.Dataset(validation, label=validation_label, reference=lgb_train)

# %%
evals_result = {}
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'max_depth':11,
    'num_leaves': 31,
    'learning_rate': 0.7,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0}

# %%
model = lgb.train(params, lgb_train, early_stopping_rounds=100,
                  num_boost_round=1000, evals_result=evals_result,
                  valid_sets= (lgb_train, lgb_eval),)
# Out:
# [1]	training's rmse: 1.96834	valid_1's rmse: 1.95911
# Training until validation scores don't improve for 100 rounds
# [2]	training's rmse: 1.86935	valid_1's rmse: 1.86315
# [3]	training's rmse: 1.77486	valid_1's rmse: 1.76633
# [4]	training's rmse: 1.74857	valid_1's rmse: 1.73876
# [5]	training's rmse: 1.68361	valid_1's rmse: 1.67075
# [6]	training's rmse: 1.65488	valid_1's rmse: 1.64285
# [7]	training's rmse: 1.64294	valid_1's rmse: 1.63009
# [8]	training's rmse: 1.60874	valid_1's rmse: 1.59555
# [9]	training's rmse: 1.5677	valid_1's rmse: 1.55059
# [10]	training's rmse: 1.54218	valid_1's rmse: 1.52604
# [11]	training's rmse: 1.51902	valid_1's rmse: 1.50664
# [12]	training's rmse: 1.51488	valid_1's rmse: 1.50442
# [13]	training's rmse: 1.49084	valid_1's rmse: 1.47887
# [14]	training's rmse: 1.47741	valid_1's rmse: 1.46332
# [15]	training's rmse: 1.44619	valid_1's rmse: 1.42748
# [16]	training's rmse: 1.4375	valid_1's rmse: 1.41943
# [17]	training's rmse: 1.43221	valid_1's rmse: 1.41507
# [18]	training's rmse: 1.42623	valid_1's rmse: 1.40958
# [19]	training's rmse: 1.42051	valid_1's rmse: 1.40358
# [20]	training's rmse: 1.41434	valid_1's rmse: 1.3967
# [21]	training's rmse: 1.4071	valid_1's rmse: 1.39022
# [22]	training's rmse: 1.40235	valid_1's rmse: 1.38484
# [23]	training's rmse: 1.3965	valid_1's rmse: 1.38001
# [24]	training's rmse: 1.39012	valid_1's rmse: 1.37274
# [25]	training's rmse: 1.37793	valid_1's rmse: 1.36022
# [26]	training's rmse: 1.37461	valid_1's rmse: 1.35917
# [27]	training's rmse: 1.37171	valid_1's rmse: 1.35529
# [28]	training's rmse: 1.33662	valid_1's rmse: 1.32219
# [29]	training's rmse: 1.32185	valid_1's rmse: 1.30849
# [30]	training's rmse: 1.31664	valid_1's rmse: 1.30348
# [31]	training's rmse: 1.31016	valid_1's rmse: 1.29651
# [32]	training's rmse: 1.30548	valid_1's rmse: 1.29238
# [33]	training's rmse: 1.30159	valid_1's rmse: 1.28692
# [34]	training's rmse: 1.27631	valid_1's rmse: 1.26169
# [35]	training's rmse: 1.24956	valid_1's rmse: 1.23508
# [36]	training's rmse: 1.24085	valid_1's rmse: 1.22617
# [37]	training's rmse: 1.23512	valid_1's rmse: 1.22061
# [38]	training's rmse: 1.23229	valid_1's rmse: 1.2175
# [39]	training's rmse: 1.22529	valid_1's rmse: 1.21138
# [40]	training's rmse: 1.22215	valid_1's rmse: 1.21081
# [41]	training's rmse: 1.21762	valid_1's rmse: 1.20541
# [42]	training's rmse: 1.21152	valid_1's rmse: 1.20003
# [43]	training's rmse: 1.20844	valid_1's rmse: 1.19688
# [44]	training's rmse: 1.20554	valid_1's rmse: 1.19396
# [45]	training's rmse: 1.19881	valid_1's rmse: 1.18681
# [46]	training's rmse: 1.19356	valid_1's rmse: 1.18248
# [47]	training's rmse: 1.19046	valid_1's rmse: 1.17979
# [48]	training's rmse: 1.18763	valid_1's rmse: 1.17678
# [49]	training's rmse: 1.1848	valid_1's rmse: 1.17505
# [50]	training's rmse: 1.18193	valid_1's rmse: 1.17207
# [51]	training's rmse: 1.18041	valid_1's rmse: 1.17246
# [52]	training's rmse: 1.17951	valid_1's rmse: 1.17174
# [53]	training's rmse: 1.17737	valid_1's rmse: 1.16957
# [54]	training's rmse: 1.17506	valid_1's rmse: 1.16717
# [55]	training's rmse: 1.17401	valid_1's rmse: 1.16638
# [56]	training's rmse: 1.16791	valid_1's rmse: 1.15897
# [57]	training's rmse: 1.16358	valid_1's rmse: 1.15385
# [58]	training's rmse: 1.16146	valid_1's rmse: 1.15169
# [59]	training's rmse: 1.15988	valid_1's rmse: 1.15049
# [60]	training's rmse: 1.15781	valid_1's rmse: 1.14924
# [61]	training's rmse: 1.15439	valid_1's rmse: 1.14563
# [62]	training's rmse: 1.14772	valid_1's rmse: 1.13881
# [63]	training's rmse: 1.14372	valid_1's rmse: 1.13492
# [64]	training's rmse: 1.14181	valid_1's rmse: 1.1332
# [65]	training's rmse: 1.13749	valid_1's rmse: 1.12842
# [66]	training's rmse: 1.13246	valid_1's rmse: 1.12398
# [67]	training's rmse: 1.12999	valid_1's rmse: 1.12151
# [68]	training's rmse: 1.12877	valid_1's rmse: 1.12018
# [69]	training's rmse: 1.12595	valid_1's rmse: 1.11771
# [70]	training's rmse: 1.12463	valid_1's rmse: 1.11641
# [71]	training's rmse: 1.12285	valid_1's rmse: 1.11495
# [72]	training's rmse: 1.12186	valid_1's rmse: 1.11405
# [73]	training's rmse: 1.12054	valid_1's rmse: 1.11286
# [74]	training's rmse: 1.11627	valid_1's rmse: 1.10852
# [75]	training's rmse: 1.11104	valid_1's rmse: 1.1037
# [76]	training's rmse: 1.10756	valid_1's rmse: 1.09961
# [77]	training's rmse: 1.10318	valid_1's rmse: 1.09516
# [78]	training's rmse: 1.10174	valid_1's rmse: 1.09513
# [79]	training's rmse: 1.09176	valid_1's rmse: 1.08803
# [80]	training's rmse: 1.09084	valid_1's rmse: 1.0867
# [81]	training's rmse: 1.08972	valid_1's rmse: 1.08563
# [82]	training's rmse: 1.08823	valid_1's rmse: 1.08429
# [83]	training's rmse: 1.08591	valid_1's rmse: 1.08208
# [84]	training's rmse: 1.08208	valid_1's rmse: 1.07872
# [85]	training's rmse: 1.07877	valid_1's rmse: 1.07515
# [86]	training's rmse: 1.07683	valid_1's rmse: 1.07377
# [87]	training's rmse: 1.07401	valid_1's rmse: 1.07057
# [88]	training's rmse: 1.07289	valid_1's rmse: 1.06994
# [89]	training's rmse: 1.07108	valid_1's rmse: 1.06857
# [90]	training's rmse: 1.06794	valid_1's rmse: 1.06541
# [91]	training's rmse: 1.06684	valid_1's rmse: 1.06437
# [92]	training's rmse: 1.06599	valid_1's rmse: 1.06347
# [93]	training's rmse: 1.06529	valid_1's rmse: 1.06345
# [94]	training's rmse: 1.06427	valid_1's rmse: 1.06267
# [95]	training's rmse: 1.06298	valid_1's rmse: 1.06169
# [96]	training's rmse: 1.06205	valid_1's rmse: 1.0609
# [97]	training's rmse: 1.0608	valid_1's rmse: 1.05967
# [98]	training's rmse: 1.05989	valid_1's rmse: 1.05888
# [99]	training's rmse: 1.05773	valid_1's rmse: 1.05687
# [100]	training's rmse: 1.05361	valid_1's rmse: 1.0527
# [101]	training's rmse: 1.0528	valid_1's rmse: 1.05212
# [102]	training's rmse: 1.05142	valid_1's rmse: 1.05067
# [103]	training's rmse: 1.04814	valid_1's rmse: 1.04792
# [104]	training's rmse: 1.04698	valid_1's rmse: 1.04725
# [105]	training's rmse: 1.04628	valid_1's rmse: 1.04662
# [106]	training's rmse: 1.04276	valid_1's rmse: 1.04279
# [107]	training's rmse: 1.04021	valid_1's rmse: 1.04151
# [108]	training's rmse: 1.03748	valid_1's rmse: 1.03924
# [109]	training's rmse: 1.03623	valid_1's rmse: 1.03787
# [110]	training's rmse: 1.03546	valid_1's rmse: 1.03755
# [111]	training's rmse: 1.03488	valid_1's rmse: 1.03574
# [112]	training's rmse: 1.0314	valid_1's rmse: 1.03141
# [113]	training's rmse: 1.03074	valid_1's rmse: 1.0309
# [114]	training's rmse: 1.02851	valid_1's rmse: 1.02862
# [115]	training's rmse: 1.02721	valid_1's rmse: 1.02701
# [116]	training's rmse: 1.02624	valid_1's rmse: 1.02606
# [117]	training's rmse: 1.02399	valid_1's rmse: 1.02411
# [118]	training's rmse: 1.02286	valid_1's rmse: 1.02312
# [119]	training's rmse: 1.02216	valid_1's rmse: 1.02277
# [120]	training's rmse: 1.02039	valid_1's rmse: 1.0212
# [121]	training's rmse: 1.0195	valid_1's rmse: 1.02051
# [122]	training's rmse: 1.01788	valid_1's rmse: 1.01917
# [123]	training's rmse: 1.01612	valid_1's rmse: 1.01872
# [124]	training's rmse: 1.01533	valid_1's rmse: 1.01815
# [125]	training's rmse: 1.01382	valid_1's rmse: 1.01684
# [126]	training's rmse: 1.01292	valid_1's rmse: 1.01677
# [127]	training's rmse: 1.01232	valid_1's rmse: 1.01745
# [128]	training's rmse: 1.01026	valid_1's rmse: 1.01518
# [129]	training's rmse: 1.00797	valid_1's rmse: 1.01323
# [130]	training's rmse: 1.00715	valid_1's rmse: 1.01232
# [131]	training's rmse: 1.00602	valid_1's rmse: 1.01146
# [132]	training's rmse: 1.00477	valid_1's rmse: 1.01032
# [133]	training's rmse: 1.00376	valid_1's rmse: 1.00935
# [134]	training's rmse: 1.00319	valid_1's rmse: 1.00871
# [135]	training's rmse: 1.00187	valid_1's rmse: 1.00731
# [136]	training's rmse: 1.00067	valid_1's rmse: 1.0063
# [137]	training's rmse: 1.00003	valid_1's rmse: 1.00586
# [138]	training's rmse: 0.998945	valid_1's rmse: 1.00456
# [139]	training's rmse: 0.997663	valid_1's rmse: 1.0037
# [140]	training's rmse: 0.996674	valid_1's rmse: 1.00278
# [141]	training's rmse: 0.995926	valid_1's rmse: 1.00205
# [142]	training's rmse: 0.995055	valid_1's rmse: 1.00113
# [143]	training's rmse: 0.994667	valid_1's rmse: 1.00076
# [144]	training's rmse: 0.994052	valid_1's rmse: 1.0002
# [145]	training's rmse: 0.993498	valid_1's rmse: 0.999931
# [146]	training's rmse: 0.992263	valid_1's rmse: 0.998633
# [147]	training's rmse: 0.991276	valid_1's rmse: 0.998396
# [148]	training's rmse: 0.99017	valid_1's rmse: 0.997609
# [149]	training's rmse: 0.989336	valid_1's rmse: 0.996886
# [150]	training's rmse: 0.988466	valid_1's rmse: 0.996295
# [151]	training's rmse: 0.987539	valid_1's rmse: 0.994993
# [152]	training's rmse: 0.986865	valid_1's rmse: 0.994123
# [153]	training's rmse: 0.986082	valid_1's rmse: 0.993572
# [154]	training's rmse: 0.985284	valid_1's rmse: 0.992831
# [155]	training's rmse: 0.984963	valid_1's rmse: 0.992682
# [156]	training's rmse: 0.984411	valid_1's rmse: 0.992247
# [157]	training's rmse: 0.984013	valid_1's rmse: 0.992011
# [158]	training's rmse: 0.982533	valid_1's rmse: 0.990405
# [159]	training's rmse: 0.981911	valid_1's rmse: 0.990104
# [160]	training's rmse: 0.981278	valid_1's rmse: 0.989434
# [161]	training's rmse: 0.980708	valid_1's rmse: 0.989078
# [162]	training's rmse: 0.979972	valid_1's rmse: 0.988535
# [163]	training's rmse: 0.978713	valid_1's rmse: 0.987597
# [164]	training's rmse: 0.978232	valid_1's rmse: 0.987193
# [165]	training's rmse: 0.977348	valid_1's rmse: 0.986787
# [166]	training's rmse: 0.976826	valid_1's rmse: 0.986563
# [167]	training's rmse: 0.975933	valid_1's rmse: 0.985668
# [168]	training's rmse: 0.97553	valid_1's rmse: 0.985245
# [169]	training's rmse: 0.975239	valid_1's rmse: 0.984843
# [170]	training's rmse: 0.974222	valid_1's rmse: 0.983944
# [171]	training's rmse: 0.973399	valid_1's rmse: 0.984083
# [172]	training's rmse: 0.973158	valid_1's rmse: 0.98401
# [173]	training's rmse: 0.971247	valid_1's rmse: 0.981787
# [174]	training's rmse: 0.970627	valid_1's rmse: 0.981308
# [175]	training's rmse: 0.969641	valid_1's rmse: 0.980187
# [176]	training's rmse: 0.968901	valid_1's rmse: 0.979769
# [177]	training's rmse: 0.967314	valid_1's rmse: 0.978272
# [178]	training's rmse: 0.966893	valid_1's rmse: 0.977968
# [179]	training's rmse: 0.965471	valid_1's rmse: 0.976638
# [180]	training's rmse: 0.964456	valid_1's rmse: 0.975786
# [181]	training's rmse: 0.963796	valid_1's rmse: 0.975032
# [182]	training's rmse: 0.962735	valid_1's rmse: 0.974369
# [183]	training's rmse: 0.96199	valid_1's rmse: 0.973907
# [184]	training's rmse: 0.961514	valid_1's rmse: 0.973617
# [185]	training's rmse: 0.961067	valid_1's rmse: 0.974735
# [186]	training's rmse: 0.96009	valid_1's rmse: 0.973783
# [187]	training's rmse: 0.959576	valid_1's rmse: 0.973754
# [188]	training's rmse: 0.958769	valid_1's rmse: 0.972999
# [189]	training's rmse: 0.958143	valid_1's rmse: 0.972424
# [190]	training's rmse: 0.957544	valid_1's rmse: 0.97161
# [191]	training's rmse: 0.956951	valid_1's rmse: 0.971312
# [192]	training's rmse: 0.956525	valid_1's rmse: 0.970231
# [193]	training's rmse: 0.956148	valid_1's rmse: 0.969773
# [194]	training's rmse: 0.955885	valid_1's rmse: 0.969525
# [195]	training's rmse: 0.955015	valid_1's rmse: 0.968771
# [196]	training's rmse: 0.954557	valid_1's rmse: 0.968589
# [197]	training's rmse: 0.953787	valid_1's rmse: 0.967752
# [198]	training's rmse: 0.953097	valid_1's rmse: 0.967313
# [199]	training's rmse: 0.952708	valid_1's rmse: 0.967142
# [200]	training's rmse: 0.951498	valid_1's rmse: 0.96576
# [201]	training's rmse: 0.950821	valid_1's rmse: 0.964864
# [202]	training's rmse: 0.950058	valid_1's rmse: 0.964526
# [203]	training's rmse: 0.949768	valid_1's rmse: 0.964578
# [204]	training's rmse: 0.949254	valid_1's rmse: 0.964428
# [205]	training's rmse: 0.948959	valid_1's rmse: 0.963959
# [206]	training's rmse: 0.948442	valid_1's rmse: 0.963455
# [207]	training's rmse: 0.948094	valid_1's rmse: 0.96329
# [208]	training's rmse: 0.947341	valid_1's rmse: 0.963092
# [209]	training's rmse: 0.945729	valid_1's rmse: 0.961136
# [210]	training's rmse: 0.945217	valid_1's rmse: 0.960743
# [211]	training's rmse: 0.943945	valid_1's rmse: 0.95964
# [212]	training's rmse: 0.943622	valid_1's rmse: 0.959412
# [213]	training's rmse: 0.943174	valid_1's rmse: 0.959081
# [214]	training's rmse: 0.942455	valid_1's rmse: 0.958371
# [215]	training's rmse: 0.942151	valid_1's rmse: 0.958159
# [216]	training's rmse: 0.941578	valid_1's rmse: 0.957375
# [217]	training's rmse: 0.940254	valid_1's rmse: 0.956092
# [218]	training's rmse: 0.939747	valid_1's rmse: 0.955336
# [219]	training's rmse: 0.938195	valid_1's rmse: 0.9538
# [220]	training's rmse: 0.937827	valid_1's rmse: 0.95363
# [221]	training's rmse: 0.936747	valid_1's rmse: 0.953497
# [222]	training's rmse: 0.936355	valid_1's rmse: 0.953074
# [223]	training's rmse: 0.935396	valid_1's rmse: 0.952291
# [224]	training's rmse: 0.935136	valid_1's rmse: 0.952011
# [225]	training's rmse: 0.934568	valid_1's rmse: 0.951367
# [226]	training's rmse: 0.934132	valid_1's rmse: 0.951006
# [227]	training's rmse: 0.933653	valid_1's rmse: 0.950627
# [228]	training's rmse: 0.932972	valid_1's rmse: 0.949792
# [229]	training's rmse: 0.932467	valid_1's rmse: 0.949269
# [230]	training's rmse: 0.931396	valid_1's rmse: 0.94847
# [231]	training's rmse: 0.931005	valid_1's rmse: 0.94818
# [232]	training's rmse: 0.930593	valid_1's rmse: 0.94766
# [233]	training's rmse: 0.929964	valid_1's rmse: 0.947093
# [234]	training's rmse: 0.929318	valid_1's rmse: 0.946296
# [235]	training's rmse: 0.928928	valid_1's rmse: 0.946109
# [236]	training's rmse: 0.928644	valid_1's rmse: 0.946149
# [237]	training's rmse: 0.92789	valid_1's rmse: 0.945395
# [238]	training's rmse: 0.927658	valid_1's rmse: 0.945078
# [239]	training's rmse: 0.927336	valid_1's rmse: 0.945075
# [240]	training's rmse: 0.926681	valid_1's rmse: 0.944519
# [241]	training's rmse: 0.926029	valid_1's rmse: 0.944041
# [242]	training's rmse: 0.925771	valid_1's rmse: 0.943874
# [243]	training's rmse: 0.925325	valid_1's rmse: 0.943559
# [244]	training's rmse: 0.924839	valid_1's rmse: 0.943058
# [245]	training's rmse: 0.924606	valid_1's rmse: 0.942877
# [246]	training's rmse: 0.924308	valid_1's rmse: 0.94283
# [247]	training's rmse: 0.923709	valid_1's rmse: 0.94245
# [248]	training's rmse: 0.923061	valid_1's rmse: 0.941731
# [249]	training's rmse: 0.922006	valid_1's rmse: 0.941163
# [250]	training's rmse: 0.921304	valid_1's rmse: 0.940413
# [251]	training's rmse: 0.920647	valid_1's rmse: 0.939621
# [252]	training's rmse: 0.919714	valid_1's rmse: 0.938737
# [253]	training's rmse: 0.919391	valid_1's rmse: 0.938486
# [254]	training's rmse: 0.91912	valid_1's rmse: 0.938269
# [255]	training's rmse: 0.918508	valid_1's rmse: 0.937772
# [256]	training's rmse: 0.918336	valid_1's rmse: 0.937534
# [257]	training's rmse: 0.917715	valid_1's rmse: 0.936756
# [258]	training's rmse: 0.917345	valid_1's rmse: 0.936449
# [259]	training's rmse: 0.916318	valid_1's rmse: 0.935796
# [260]	training's rmse: 0.915827	valid_1's rmse: 0.935309
# [261]	training's rmse: 0.915531	valid_1's rmse: 0.935036
# [262]	training's rmse: 0.915053	valid_1's rmse: 0.934847
# [263]	training's rmse: 0.914458	valid_1's rmse: 0.934549
# [264]	training's rmse: 0.914254	valid_1's rmse: 0.934468
# [265]	training's rmse: 0.914093	valid_1's rmse: 0.934272
# [266]	training's rmse: 0.91333	valid_1's rmse: 0.93342
# [267]	training's rmse: 0.912991	valid_1's rmse: 0.933315
# [268]	training's rmse: 0.912811	valid_1's rmse: 0.933215
# [269]	training's rmse: 0.912443	valid_1's rmse: 0.933073
# [270]	training's rmse: 0.912246	valid_1's rmse: 0.932962
# [271]	training's rmse: 0.911839	valid_1's rmse: 0.932583
# [272]	training's rmse: 0.911506	valid_1's rmse: 0.932415
# [273]	training's rmse: 0.910534	valid_1's rmse: 0.931421
# [274]	training's rmse: 0.910155	valid_1's rmse: 0.931129
# [275]	training's rmse: 0.909552	valid_1's rmse: 0.930567
# [276]	training's rmse: 0.908898	valid_1's rmse: 0.929638
# [277]	training's rmse: 0.908434	valid_1's rmse: 0.929233
# [278]	training's rmse: 0.908022	valid_1's rmse: 0.928587
# [279]	training's rmse: 0.907266	valid_1's rmse: 0.927716
# [280]	training's rmse: 0.906242	valid_1's rmse: 0.926701
# [281]	training's rmse: 0.906012	valid_1's rmse: 0.926424
# [282]	training's rmse: 0.905572	valid_1's rmse: 0.926017
# [283]	training's rmse: 0.904961	valid_1's rmse: 0.925366
# [284]	training's rmse: 0.904388	valid_1's rmse: 0.925271
# [285]	training's rmse: 0.904256	valid_1's rmse: 0.925179
# [286]	training's rmse: 0.903477	valid_1's rmse: 0.924902
# [287]	training's rmse: 0.903072	valid_1's rmse: 0.924681
# [288]	training's rmse: 0.902853	valid_1's rmse: 0.924526
# [289]	training's rmse: 0.902725	valid_1's rmse: 0.924507
# [290]	training's rmse: 0.901892	valid_1's rmse: 0.923979
# [291]	training's rmse: 0.901232	valid_1's rmse: 0.923187
# [292]	training's rmse: 0.900824	valid_1's rmse: 0.922876
# [293]	training's rmse: 0.899792	valid_1's rmse: 0.921964
# [294]	training's rmse: 0.899613	valid_1's rmse: 0.921729
# [295]	training's rmse: 0.899207	valid_1's rmse: 0.921471
# [296]	training's rmse: 0.898815	valid_1's rmse: 0.921235
# [297]	training's rmse: 0.89822	valid_1's rmse: 0.920757
# [298]	training's rmse: 0.897848	valid_1's rmse: 0.920432
# [299]	training's rmse: 0.897538	valid_1's rmse: 0.920131
# [300]	training's rmse: 0.897325	valid_1's rmse: 0.919979
# [301]	training's rmse: 0.897123	valid_1's rmse: 0.919907
# [302]	training's rmse: 0.896691	valid_1's rmse: 0.919439
# [303]	training's rmse: 0.896516	valid_1's rmse: 0.919357
# [304]	training's rmse: 0.895783	valid_1's rmse: 0.918616
# [305]	training's rmse: 0.895226	valid_1's rmse: 0.918052
# [306]	training's rmse: 0.894916	valid_1's rmse: 0.917676
# [307]	training's rmse: 0.894691	valid_1's rmse: 0.917529
# [308]	training's rmse: 0.894154	valid_1's rmse: 0.916751
# [309]	training's rmse: 0.893867	valid_1's rmse: 0.916568
# [310]	training's rmse: 0.893579	valid_1's rmse: 0.916412
# [311]	training's rmse: 0.893369	valid_1's rmse: 0.91624
# [312]	training's rmse: 0.893138	valid_1's rmse: 0.916069
# [313]	training's rmse: 0.892887	valid_1's rmse: 0.915856
# [314]	training's rmse: 0.892708	valid_1's rmse: 0.915644
# [315]	training's rmse: 0.892372	valid_1's rmse: 0.915585
# [316]	training's rmse: 0.891983	valid_1's rmse: 0.915237
# [317]	training's rmse: 0.891538	valid_1's rmse: 0.91475
# [318]	training's rmse: 0.891252	valid_1's rmse: 0.914538
# [319]	training's rmse: 0.890783	valid_1's rmse: 0.913965
# [320]	training's rmse: 0.890472	valid_1's rmse: 0.913643
# [321]	training's rmse: 0.890065	valid_1's rmse: 0.913324
# [322]	training's rmse: 0.889779	valid_1's rmse: 0.913214
# [323]	training's rmse: 0.889502	valid_1's rmse: 0.912934
# [324]	training's rmse: 0.889107	valid_1's rmse: 0.912625
# [325]	training's rmse: 0.888694	valid_1's rmse: 0.912259
# [326]	training's rmse: 0.888049	valid_1's rmse: 0.911594
# [327]	training's rmse: 0.887826	valid_1's rmse: 0.911449
# [328]	training's rmse: 0.887385	valid_1's rmse: 0.91092
# [329]	training's rmse: 0.886826	valid_1's rmse: 0.910385
# [330]	training's rmse: 0.88635	valid_1's rmse: 0.909854
# [331]	training's rmse: 0.88585	valid_1's rmse: 0.909324
# [332]	training's rmse: 0.885726	valid_1's rmse: 0.909253
# [333]	training's rmse: 0.885186	valid_1's rmse: 0.909098
# [334]	training's rmse: 0.884873	valid_1's rmse: 0.90879
# [335]	training's rmse: 0.884508	valid_1's rmse: 0.908571
# [336]	training's rmse: 0.884106	valid_1's rmse: 0.908406
# [337]	training's rmse: 0.883925	valid_1's rmse: 0.908228
# [338]	training's rmse: 0.883758	valid_1's rmse: 0.908138
# [339]	training's rmse: 0.883611	valid_1's rmse: 0.908069
# [340]	training's rmse: 0.88339	valid_1's rmse: 0.908118
# [341]	training's rmse: 0.883045	valid_1's rmse: 0.907788
# [342]	training's rmse: 0.88293	valid_1's rmse: 0.907801
# [343]	training's rmse: 0.882534	valid_1's rmse: 0.907804
# [344]	training's rmse: 0.882176	valid_1's rmse: 0.907531
# [345]	training's rmse: 0.881866	valid_1's rmse: 0.907286
# [346]	training's rmse: 0.881668	valid_1's rmse: 0.907293
# [347]	training's rmse: 0.881261	valid_1's rmse: 0.906969
# [348]	training's rmse: 0.880949	valid_1's rmse: 0.906561
# [349]	training's rmse: 0.880656	valid_1's rmse: 0.906347
# [350]	training's rmse: 0.880343	valid_1's rmse: 0.90611
# [351]	training's rmse: 0.880224	valid_1's rmse: 0.906108
# [352]	training's rmse: 0.880009	valid_1's rmse: 0.905967
# [353]	training's rmse: 0.879735	valid_1's rmse: 0.905613
# [354]	training's rmse: 0.878806	valid_1's rmse: 0.904643
# [355]	training's rmse: 0.878424	valid_1's rmse: 0.904247
# [356]	training's rmse: 0.878106	valid_1's rmse: 0.904029
# [357]	training's rmse: 0.877708	valid_1's rmse: 0.904098
# [358]	training's rmse: 0.87749	valid_1's rmse: 0.903935
# [359]	training's rmse: 0.876964	valid_1's rmse: 0.903486
# [360]	training's rmse: 0.876593	valid_1's rmse: 0.902988
# [361]	training's rmse: 0.876301	valid_1's rmse: 0.902768
# [362]	training's rmse: 0.876027	valid_1's rmse: 0.902543
# [363]	training's rmse: 0.875783	valid_1's rmse: 0.902347
# [364]	training's rmse: 0.875457	valid_1's rmse: 0.902257
# [365]	training's rmse: 0.875323	valid_1's rmse: 0.902125
# [366]	training's rmse: 0.875172	valid_1's rmse: 0.901997
# [367]	training's rmse: 0.874768	valid_1's rmse: 0.901537
# [368]	training's rmse: 0.874571	valid_1's rmse: 0.901225
# [369]	training's rmse: 0.874337	valid_1's rmse: 0.900573
# [370]	training's rmse: 0.874048	valid_1's rmse: 0.900485
# [371]	training's rmse: 0.873782	valid_1's rmse: 0.900416
# [372]	training's rmse: 0.872831	valid_1's rmse: 0.899454
# [373]	training's rmse: 0.872606	valid_1's rmse: 0.899351
# [374]	training's rmse: 0.872145	valid_1's rmse: 0.898835
# [375]	training's rmse: 0.871931	valid_1's rmse: 0.898622
# [376]	training's rmse: 0.871432	valid_1's rmse: 0.898326
# [377]	training's rmse: 0.871287	valid_1's rmse: 0.898278
# [378]	training's rmse: 0.871123	valid_1's rmse: 0.897961
# [379]	training's rmse: 0.87098	valid_1's rmse: 0.897833
# [380]	training's rmse: 0.870487	valid_1's rmse: 0.897221
# [381]	training's rmse: 0.870036	valid_1's rmse: 0.896757
# [382]	training's rmse: 0.869828	valid_1's rmse: 0.8966
# [383]	training's rmse: 0.869503	valid_1's rmse: 0.896222
# [384]	training's rmse: 0.869313	valid_1's rmse: 0.896156
# [385]	training's rmse: 0.869068	valid_1's rmse: 0.89605
# [386]	training's rmse: 0.868696	valid_1's rmse: 0.895705
# [387]	training's rmse: 0.868484	valid_1's rmse: 0.895523
# [388]	training's rmse: 0.868346	valid_1's rmse: 0.895497
# [389]	training's rmse: 0.868013	valid_1's rmse: 0.895274
# [390]	training's rmse: 0.867636	valid_1's rmse: 0.89508
# [391]	training's rmse: 0.867532	valid_1's rmse: 0.895048
# [392]	training's rmse: 0.867349	valid_1's rmse: 0.894906
# [393]	training's rmse: 0.867228	valid_1's rmse: 0.894827
# [394]	training's rmse: 0.867089	valid_1's rmse: 0.894745
# [395]	training's rmse: 0.866816	valid_1's rmse: 0.894465
# [396]	training's rmse: 0.866479	valid_1's rmse: 0.894136
# [397]	training's rmse: 0.866102	valid_1's rmse: 0.893817
# [398]	training's rmse: 0.86583	valid_1's rmse: 0.893692
# [399]	training's rmse: 0.865588	valid_1's rmse: 0.893621
# [400]	training's rmse: 0.865367	valid_1's rmse: 0.893442
# [401]	training's rmse: 0.865198	valid_1's rmse: 0.893392
# [402]	training's rmse: 0.865099	valid_1's rmse: 0.89335
# [403]	training's rmse: 0.864908	valid_1's rmse: 0.89316
# [404]	training's rmse: 0.864805	valid_1's rmse: 0.893167
# [405]	training's rmse: 0.864372	valid_1's rmse: 0.892787
# [406]	training's rmse: 0.864145	valid_1's rmse: 0.892551
# [407]	training's rmse: 0.863988	valid_1's rmse: 0.892451
# [408]	training's rmse: 0.86312	valid_1's rmse: 0.891724
# [409]	training's rmse: 0.862854	valid_1's rmse: 0.89167
# [410]	training's rmse: 0.862605	valid_1's rmse: 0.891438
# [411]	training's rmse: 0.862327	valid_1's rmse: 0.891016
# [412]	training's rmse: 0.862159	valid_1's rmse: 0.890863
# [413]	training's rmse: 0.861988	valid_1's rmse: 0.890651
# [414]	training's rmse: 0.861687	valid_1's rmse: 0.890597
# [415]	training's rmse: 0.860938	valid_1's rmse: 0.889893
# [416]	training's rmse: 0.860692	valid_1's rmse: 0.88987
# [417]	training's rmse: 0.860545	valid_1's rmse: 0.889809
# [418]	training's rmse: 0.860289	valid_1's rmse: 0.889914
# [419]	training's rmse: 0.859627	valid_1's rmse: 0.889228
# [420]	training's rmse: 0.858749	valid_1's rmse: 0.888218
# [421]	training's rmse: 0.858478	valid_1's rmse: 0.887991
# [422]	training's rmse: 0.857976	valid_1's rmse: 0.887586
# [423]	training's rmse: 0.85783	valid_1's rmse: 0.887435
# [424]	training's rmse: 0.857442	valid_1's rmse: 0.887082
# [425]	training's rmse: 0.857338	valid_1's rmse: 0.887024
# [426]	training's rmse: 0.857109	valid_1's rmse: 0.886857
# [427]	training's rmse: 0.856877	valid_1's rmse: 0.886621
# [428]	training's rmse: 0.856566	valid_1's rmse: 0.886517
# [429]	training's rmse: 0.856103	valid_1's rmse: 0.886687
# [430]	training's rmse: 0.856021	valid_1's rmse: 0.886695
# [431]	training's rmse: 0.855685	valid_1's rmse: 0.886475
# [432]	training's rmse: 0.855109	valid_1's rmse: 0.885949
# [433]	training's rmse: 0.854989	valid_1's rmse: 0.886018
# [434]	training's rmse: 0.854739	valid_1's rmse: 0.885883
# [435]	training's rmse: 0.854028	valid_1's rmse: 0.885577
# [436]	training's rmse: 0.853573	valid_1's rmse: 0.885018
# [437]	training's rmse: 0.853081	valid_1's rmse: 0.884646
# [438]	training's rmse: 0.852968	valid_1's rmse: 0.884602
# [439]	training's rmse: 0.852708	valid_1's rmse: 0.884491
# [440]	training's rmse: 0.85249	valid_1's rmse: 0.884333
# [441]	training's rmse: 0.852336	valid_1's rmse: 0.884392
# [442]	training's rmse: 0.851964	valid_1's rmse: 0.884229
# [443]	training's rmse: 0.851845	valid_1's rmse: 0.884178
# [444]	training's rmse: 0.851692	valid_1's rmse: 0.884018
# [445]	training's rmse: 0.851619	valid_1's rmse: 0.883993
# [446]	training's rmse: 0.851487	valid_1's rmse: 0.883806
# [447]	training's rmse: 0.851347	valid_1's rmse: 0.884042
# [448]	training's rmse: 0.851083	valid_1's rmse: 0.88394
# [449]	training's rmse: 0.850856	valid_1's rmse: 0.883741
# [450]	training's rmse: 0.850494	valid_1's rmse: 0.883573
# [451]	training's rmse: 0.850329	valid_1's rmse: 0.883569
# [452]	training's rmse: 0.849964	valid_1's rmse: 0.883215
# [453]	training's rmse: 0.849745	valid_1's rmse: 0.882991
# [454]	training's rmse: 0.849631	valid_1's rmse: 0.882897
# [455]	training's rmse: 0.849398	valid_1's rmse: 0.882758
# [456]	training's rmse: 0.848962	valid_1's rmse: 0.882277
# [457]	training's rmse: 0.84878	valid_1's rmse: 0.882108
# [458]	training's rmse: 0.848553	valid_1's rmse: 0.882031
# [459]	training's rmse: 0.848168	valid_1's rmse: 0.88166
# [460]	training's rmse: 0.847762	valid_1's rmse: 0.881412
# [461]	training's rmse: 0.847621	valid_1's rmse: 0.881237
# [462]	training's rmse: 0.84734	valid_1's rmse: 0.881114
# [463]	training's rmse: 0.84707	valid_1's rmse: 0.880919
# [464]	training's rmse: 0.846715	valid_1's rmse: 0.880697
# [465]	training's rmse: 0.84655	valid_1's rmse: 0.880536
# [466]	training's rmse: 0.846268	valid_1's rmse: 0.880313
# [467]	training's rmse: 0.846041	valid_1's rmse: 0.880178
# [468]	training's rmse: 0.845974	valid_1's rmse: 0.880064
# [469]	training's rmse: 0.845886	valid_1's rmse: 0.880013
# [470]	training's rmse: 0.845711	valid_1's rmse: 0.87994
# [471]	training's rmse: 0.84557	valid_1's rmse: 0.879917
# [472]	training's rmse: 0.845383	valid_1's rmse: 0.87982
# [473]	training's rmse: 0.845093	valid_1's rmse: 0.87966
# [474]	training's rmse: 0.844776	valid_1's rmse: 0.879361
# [475]	training's rmse: 0.844663	valid_1's rmse: 0.879294
# [476]	training's rmse: 0.844515	valid_1's rmse: 0.879156
# [477]	training's rmse: 0.844364	valid_1's rmse: 0.879081
# [478]	training's rmse: 0.844269	valid_1's rmse: 0.878996
# [479]	training's rmse: 0.844104	valid_1's rmse: 0.87878
# [480]	training's rmse: 0.843981	valid_1's rmse: 0.87873
# [481]	training's rmse: 0.843439	valid_1's rmse: 0.878336
# [482]	training's rmse: 0.843307	valid_1's rmse: 0.878181
# [483]	training's rmse: 0.843172	valid_1's rmse: 0.878094
# [484]	training's rmse: 0.84286	valid_1's rmse: 0.877698
# [485]	training's rmse: 0.842623	valid_1's rmse: 0.877449
# [486]	training's rmse: 0.84252	valid_1's rmse: 0.877333
# [487]	training's rmse: 0.842268	valid_1's rmse: 0.876858
# [488]	training's rmse: 0.842151	valid_1's rmse: 0.876793
# [489]	training's rmse: 0.841527	valid_1's rmse: 0.87619
# [490]	training's rmse: 0.841358	valid_1's rmse: 0.875861
# [491]	training's rmse: 0.841126	valid_1's rmse: 0.875741
# [492]	training's rmse: 0.841043	valid_1's rmse: 0.875685
# [493]	training's rmse: 0.840534	valid_1's rmse: 0.875185
# [494]	training's rmse: 0.840157	valid_1's rmse: 0.874807
# [495]	training's rmse: 0.840068	valid_1's rmse: 0.874743
# [496]	training's rmse: 0.839838	valid_1's rmse: 0.874471
# [497]	training's rmse: 0.839396	valid_1's rmse: 0.874082
# [498]	training's rmse: 0.838462	valid_1's rmse: 0.872797
# [499]	training's rmse: 0.838009	valid_1's rmse: 0.872421
# [500]	training's rmse: 0.837687	valid_1's rmse: 0.871981
# [501]	training's rmse: 0.83755	valid_1's rmse: 0.872011
# [502]	training's rmse: 0.837453	valid_1's rmse: 0.871938
# [503]	training's rmse: 0.837039	valid_1's rmse: 0.871476
# [504]	training's rmse: 0.8369	valid_1's rmse: 0.871374
# [505]	training's rmse: 0.836634	valid_1's rmse: 0.87115
# [506]	training's rmse: 0.836507	valid_1's rmse: 0.871102
# [507]	training's rmse: 0.836196	valid_1's rmse: 0.870906
# [508]	training's rmse: 0.83559	valid_1's rmse: 0.870434
# [509]	training's rmse: 0.835433	valid_1's rmse: 0.870418
# [510]	training's rmse: 0.835247	valid_1's rmse: 0.870299
# [511]	training's rmse: 0.835095	valid_1's rmse: 0.870359
# [512]	training's rmse: 0.834893	valid_1's rmse: 0.870207
# [513]	training's rmse: 0.834624	valid_1's rmse: 0.869851
# [514]	training's rmse: 0.834403	valid_1's rmse: 0.86965
# [515]	training's rmse: 0.834194	valid_1's rmse: 0.86948
# [516]	training's rmse: 0.833513	valid_1's rmse: 0.869165
# [517]	training's rmse: 0.833369	valid_1's rmse: 0.869141
# [518]	training's rmse: 0.833167	valid_1's rmse: 0.869186
# [519]	training's rmse: 0.832862	valid_1's rmse: 0.868986
# [520]	training's rmse: 0.832666	valid_1's rmse: 0.868755
# [521]	training's rmse: 0.832488	valid_1's rmse: 0.868724
# [522]	training's rmse: 0.832223	valid_1's rmse: 0.868631
# [523]	training's rmse: 0.831938	valid_1's rmse: 0.868429
# [524]	training's rmse: 0.831762	valid_1's rmse: 0.868314
# [525]	training's rmse: 0.831438	valid_1's rmse: 0.868128
# [526]	training's rmse: 0.83131	valid_1's rmse: 0.86801
# [527]	training's rmse: 0.831142	valid_1's rmse: 0.867934
# [528]	training's rmse: 0.831029	valid_1's rmse: 0.867936
# [529]	training's rmse: 0.830958	valid_1's rmse: 0.867903
# [530]	training's rmse: 0.830903	valid_1's rmse: 0.86792
# [531]	training's rmse: 0.830715	valid_1's rmse: 0.86773
# [532]	training's rmse: 0.830449	valid_1's rmse: 0.867505
# [533]	training's rmse: 0.830313	valid_1's rmse: 0.867307
# [534]	training's rmse: 0.830181	valid_1's rmse: 0.867264
# [535]	training's rmse: 0.829964	valid_1's rmse: 0.867109
# [536]	training's rmse: 0.829778	valid_1's rmse: 0.866968
# [537]	training's rmse: 0.829531	valid_1's rmse: 0.866761
# [538]	training's rmse: 0.829237	valid_1's rmse: 0.866613
# [539]	training's rmse: 0.829099	valid_1's rmse: 0.866557
# [540]	training's rmse: 0.828894	valid_1's rmse: 0.866341
# [541]	training's rmse: 0.828694	valid_1's rmse: 0.866131
# [542]	training's rmse: 0.828578	valid_1's rmse: 0.866056
# [543]	training's rmse: 0.828477	valid_1's rmse: 0.86603
# [544]	training's rmse: 0.828369	valid_1's rmse: 0.866018
# [545]	training's rmse: 0.828173	valid_1's rmse: 0.8659
# [546]	training's rmse: 0.827887	valid_1's rmse: 0.865783
# [547]	training's rmse: 0.827781	valid_1's rmse: 0.86576
# [548]	training's rmse: 0.827513	valid_1's rmse: 0.865571
# [549]	training's rmse: 0.827386	valid_1's rmse: 0.865887
# [550]	training's rmse: 0.827003	valid_1's rmse: 0.865537
# [551]	training's rmse: 0.826753	valid_1's rmse: 0.865515
# [552]	training's rmse: 0.826517	valid_1's rmse: 0.865693
# [553]	training's rmse: 0.826377	valid_1's rmse: 0.865754
# [554]	training's rmse: 0.826173	valid_1's rmse: 0.865697
# [555]	training's rmse: 0.825917	valid_1's rmse: 0.865473
# [556]	training's rmse: 0.8258	valid_1's rmse: 0.865376
# [557]	training's rmse: 0.82569	valid_1's rmse: 0.865309
# [558]	training's rmse: 0.825405	valid_1's rmse: 0.865524
# [559]	training's rmse: 0.825285	valid_1's rmse: 0.865391
# [560]	training's rmse: 0.825115	valid_1's rmse: 0.865266
# [561]	training's rmse: 0.825009	valid_1's rmse: 0.865203
# [562]	training's rmse: 0.824772	valid_1's rmse: 0.864896
# [563]	training's rmse: 0.824537	valid_1's rmse: 0.86459
# [564]	training's rmse: 0.824441	valid_1's rmse: 0.864603
# [565]	training's rmse: 0.824356	valid_1's rmse: 0.864565
# [566]	training's rmse: 0.824296	valid_1's rmse: 0.864542
# [567]	training's rmse: 0.824142	valid_1's rmse: 0.864493
# [568]	training's rmse: 0.823957	valid_1's rmse: 0.864239
# [569]	training's rmse: 0.823809	valid_1's rmse: 0.864157
# [570]	training's rmse: 0.823573	valid_1's rmse: 0.863863
# [571]	training's rmse: 0.823412	valid_1's rmse: 0.863723
# [572]	training's rmse: 0.823193	valid_1's rmse: 0.863584
# [573]	training's rmse: 0.823039	valid_1's rmse: 0.863517
# [574]	training's rmse: 0.822929	valid_1's rmse: 0.863607
# [575]	training's rmse: 0.822568	valid_1's rmse: 0.863116
# [576]	training's rmse: 0.822461	valid_1's rmse: 0.863065
# [577]	training's rmse: 0.822311	valid_1's rmse: 0.862956
# [578]	training's rmse: 0.821993	valid_1's rmse: 0.862544
# [579]	training's rmse: 0.821726	valid_1's rmse: 0.862352
# [580]	training's rmse: 0.821621	valid_1's rmse: 0.862314
# [581]	training's rmse: 0.821509	valid_1's rmse: 0.862316
# [582]	training's rmse: 0.821445	valid_1's rmse: 0.862322
# [583]	training's rmse: 0.821275	valid_1's rmse: 0.862195
# [584]	training's rmse: 0.821108	valid_1's rmse: 0.862097
# [585]	training's rmse: 0.820883	valid_1's rmse: 0.861931
# [586]	training's rmse: 0.820576	valid_1's rmse: 0.861569
# [587]	training's rmse: 0.820478	valid_1's rmse: 0.861475
# [588]	training's rmse: 0.820301	valid_1's rmse: 0.861363
# [589]	training's rmse: 0.820127	valid_1's rmse: 0.86124
# [590]	training's rmse: 0.819949	valid_1's rmse: 0.861182
# [591]	training's rmse: 0.819859	valid_1's rmse: 0.861109
# [592]	training's rmse: 0.8198	valid_1's rmse: 0.861068
# [593]	training's rmse: 0.819695	valid_1's rmse: 0.861
# [594]	training's rmse: 0.819377	valid_1's rmse: 0.860595
# [595]	training's rmse: 0.819157	valid_1's rmse: 0.860419
# [596]	training's rmse: 0.818899	valid_1's rmse: 0.860204
# [597]	training's rmse: 0.818696	valid_1's rmse: 0.860244
# [598]	training's rmse: 0.818554	valid_1's rmse: 0.860148
# [599]	training's rmse: 0.818061	valid_1's rmse: 0.859736
# [600]	training's rmse: 0.817739	valid_1's rmse: 0.859597
# [601]	training's rmse: 0.817361	valid_1's rmse: 0.859243
# [602]	training's rmse: 0.817189	valid_1's rmse: 0.859219
# [603]	training's rmse: 0.81696	valid_1's rmse: 0.859033
# [604]	training's rmse: 0.816788	valid_1's rmse: 0.858983
# [605]	training's rmse: 0.816433	valid_1's rmse: 0.858584
# [606]	training's rmse: 0.816361	valid_1's rmse: 0.858532
# [607]	training's rmse: 0.81627	valid_1's rmse: 0.858464
# [608]	training's rmse: 0.816096	valid_1's rmse: 0.858203
# [609]	training's rmse: 0.815934	valid_1's rmse: 0.858125
# [610]	training's rmse: 0.815805	valid_1's rmse: 0.857973
# [611]	training's rmse: 0.815737	valid_1's rmse: 0.857887
# [612]	training's rmse: 0.815652	valid_1's rmse: 0.857791
# [613]	training's rmse: 0.81552	valid_1's rmse: 0.857752
# [614]	training's rmse: 0.81524	valid_1's rmse: 0.857522
# [615]	training's rmse: 0.814854	valid_1's rmse: 0.856947
# [616]	training's rmse: 0.814671	valid_1's rmse: 0.856894
# [617]	training's rmse: 0.814501	valid_1's rmse: 0.856885
# [618]	training's rmse: 0.814394	valid_1's rmse: 0.856879
# [619]	training's rmse: 0.814321	valid_1's rmse: 0.856858
# [620]	training's rmse: 0.814081	valid_1's rmse: 0.856758
# [621]	training's rmse: 0.813996	valid_1's rmse: 0.856677
# [622]	training's rmse: 0.813879	valid_1's rmse: 0.856665
# [623]	training's rmse: 0.813592	valid_1's rmse: 0.856504
# [624]	training's rmse: 0.813559	valid_1's rmse: 0.856533
# [625]	training's rmse: 0.813478	valid_1's rmse: 0.85616
# [626]	training's rmse: 0.813306	valid_1's rmse: 0.856021
# [627]	training's rmse: 0.813152	valid_1's rmse: 0.855953
# [628]	training's rmse: 0.813091	valid_1's rmse: 0.85594
# [629]	training's rmse: 0.812943	valid_1's rmse: 0.855835
# [630]	training's rmse: 0.812819	valid_1's rmse: 0.855773
# [631]	training's rmse: 0.812676	valid_1's rmse: 0.855597
# [632]	training's rmse: 0.81249	valid_1's rmse: 0.855507
# [633]	training's rmse: 0.812303	valid_1's rmse: 0.855512
# [634]	training's rmse: 0.812062	valid_1's rmse: 0.855299
# [635]	training's rmse: 0.811917	valid_1's rmse: 0.85509
# [636]	training's rmse: 0.811746	valid_1's rmse: 0.854993
# [637]	training's rmse: 0.81157	valid_1's rmse: 0.854862
# [638]	training's rmse: 0.811226	valid_1's rmse: 0.854507
# [639]	training's rmse: 0.811076	valid_1's rmse: 0.854586
# [640]	training's rmse: 0.810899	valid_1's rmse: 0.854487
# [641]	training's rmse: 0.810799	valid_1's rmse: 0.854479
# [642]	training's rmse: 0.81073	valid_1's rmse: 0.854425
# [643]	training's rmse: 0.810569	valid_1's rmse: 0.854339
# [644]	training's rmse: 0.810456	valid_1's rmse: 0.854271
# [645]	training's rmse: 0.810366	valid_1's rmse: 0.854218
# [646]	training's rmse: 0.810206	valid_1's rmse: 0.854156
# [647]	training's rmse: 0.810095	valid_1's rmse: 0.854102
# [648]	training's rmse: 0.809865	valid_1's rmse: 0.854037
# [649]	training's rmse: 0.809734	valid_1's rmse: 0.853997
# [650]	training's rmse: 0.809633	valid_1's rmse: 0.853916
# [651]	training's rmse: 0.809523	valid_1's rmse: 0.854565
# [652]	training's rmse: 0.809092	valid_1's rmse: 0.854108
# [653]	training's rmse: 0.808992	valid_1's rmse: 0.854069
# [654]	training's rmse: 0.808818	valid_1's rmse: 0.853957
# [655]	training's rmse: 0.808561	valid_1's rmse: 0.853821
# [656]	training's rmse: 0.808462	valid_1's rmse: 0.853743
# [657]	training's rmse: 0.808337	valid_1's rmse: 0.853719
# [658]	training's rmse: 0.808275	valid_1's rmse: 0.8537
# [659]	training's rmse: 0.808234	valid_1's rmse: 0.853691
# [660]	training's rmse: 0.808193	valid_1's rmse: 0.853659
# [661]	training's rmse: 0.808053	valid_1's rmse: 0.85361
# [662]	training's rmse: 0.807878	valid_1's rmse: 0.853655
# [663]	training's rmse: 0.807707	valid_1's rmse: 0.853566
# [664]	training's rmse: 0.807627	valid_1's rmse: 0.853461
# [665]	training's rmse: 0.807558	valid_1's rmse: 0.853502
# [666]	training's rmse: 0.807444	valid_1's rmse: 0.853415
# [667]	training's rmse: 0.807356	valid_1's rmse: 0.853333
# [668]	training's rmse: 0.807192	valid_1's rmse: 0.85327
# [669]	training's rmse: 0.807138	valid_1's rmse: 0.853312
# [670]	training's rmse: 0.807052	valid_1's rmse: 0.853337
# [671]	training's rmse: 0.806987	valid_1's rmse: 0.853306
# [672]	training's rmse: 0.806729	valid_1's rmse: 0.853105
# [673]	training's rmse: 0.806485	valid_1's rmse: 0.852948
# [674]	training's rmse: 0.806331	valid_1's rmse: 0.852792
# [675]	training's rmse: 0.806188	valid_1's rmse: 0.852697
# [676]	training's rmse: 0.805992	valid_1's rmse: 0.852486
# [677]	training's rmse: 0.805844	valid_1's rmse: 0.852373
# [678]	training's rmse: 0.805723	valid_1's rmse: 0.852394
# [679]	training's rmse: 0.805514	valid_1's rmse: 0.85229
# [680]	training's rmse: 0.805338	valid_1's rmse: 0.852077
# [681]	training's rmse: 0.805075	valid_1's rmse: 0.851819
# [682]	training's rmse: 0.804904	valid_1's rmse: 0.851686
# [683]	training's rmse: 0.804792	valid_1's rmse: 0.851627
# [684]	training's rmse: 0.804392	valid_1's rmse: 0.85123
# [685]	training's rmse: 0.804006	valid_1's rmse: 0.850849
# [686]	training's rmse: 0.803818	valid_1's rmse: 0.850699
# [687]	training's rmse: 0.803683	valid_1's rmse: 0.850703
# [688]	training's rmse: 0.803471	valid_1's rmse: 0.850469
# [689]	training's rmse: 0.803277	valid_1's rmse: 0.850201
# [690]	training's rmse: 0.80309	valid_1's rmse: 0.850178
# [691]	training's rmse: 0.80295	valid_1's rmse: 0.850085
# [692]	training's rmse: 0.802783	valid_1's rmse: 0.850009
# [693]	training's rmse: 0.802437	valid_1's rmse: 0.849694
# [694]	training's rmse: 0.8023	valid_1's rmse: 0.84962
# [695]	training's rmse: 0.802204	valid_1's rmse: 0.849416
# [696]	training's rmse: 0.802153	valid_1's rmse: 0.849418
# [697]	training's rmse: 0.80204	valid_1's rmse: 0.849328
# [698]	training's rmse: 0.80181	valid_1's rmse: 0.849152
# [699]	training's rmse: 0.801634	valid_1's rmse: 0.849114
# [700]	training's rmse: 0.80156	valid_1's rmse: 0.848987
# [701]	training's rmse: 0.801362	valid_1's rmse: 0.848742
# [702]	training's rmse: 0.801044	valid_1's rmse: 0.848526
# [703]	training's rmse: 0.800924	valid_1's rmse: 0.84837
# [704]	training's rmse: 0.800698	valid_1's rmse: 0.848098
# [705]	training's rmse: 0.800477	valid_1's rmse: 0.847996
# [706]	training's rmse: 0.800341	valid_1's rmse: 0.847871
# [707]	training's rmse: 0.800036	valid_1's rmse: 0.84759
# [708]	training's rmse: 0.799834	valid_1's rmse: 0.847367
# [709]	training's rmse: 0.799697	valid_1's rmse: 0.84733
# [710]	training's rmse: 0.799383	valid_1's rmse: 0.847048
# [711]	training's rmse: 0.799167	valid_1's rmse: 0.846915
# [712]	training's rmse: 0.799114	valid_1's rmse: 0.846916
# [713]	training's rmse: 0.798767	valid_1's rmse: 0.846647
# [714]	training's rmse: 0.798718	valid_1's rmse: 0.846573
# [715]	training's rmse: 0.798562	valid_1's rmse: 0.846486
# [716]	training's rmse: 0.798468	valid_1's rmse: 0.846882
# [717]	training's rmse: 0.798399	valid_1's rmse: 0.846835
# [718]	training's rmse: 0.798215	valid_1's rmse: 0.846709
# [719]	training's rmse: 0.798037	valid_1's rmse: 0.846659
# [720]	training's rmse: 0.797837	valid_1's rmse: 0.846557
# [721]	training's rmse: 0.797705	valid_1's rmse: 0.846322
# [722]	training's rmse: 0.797625	valid_1's rmse: 0.846279
# [723]	training's rmse: 0.797343	valid_1's rmse: 0.846192
# [724]	training's rmse: 0.797139	valid_1's rmse: 0.846084
# [725]	training's rmse: 0.796879	valid_1's rmse: 0.845826
# [726]	training's rmse: 0.796549	valid_1's rmse: 0.845455
# [727]	training's rmse: 0.79647	valid_1's rmse: 0.845416
# [728]	training's rmse: 0.796258	valid_1's rmse: 0.845296
# [729]	training's rmse: 0.796158	valid_1's rmse: 0.845299
# [730]	training's rmse: 0.796079	valid_1's rmse: 0.84526
# [731]	training's rmse: 0.795953	valid_1's rmse: 0.84509
# [732]	training's rmse: 0.795858	valid_1's rmse: 0.845065
# [733]	training's rmse: 0.79573	valid_1's rmse: 0.844972
# [734]	training's rmse: 0.795369	valid_1's rmse: 0.844657
# [735]	training's rmse: 0.795234	valid_1's rmse: 0.844616
# [736]	training's rmse: 0.795066	valid_1's rmse: 0.844494
# [737]	training's rmse: 0.794896	valid_1's rmse: 0.844461
# [738]	training's rmse: 0.794614	valid_1's rmse: 0.8442
# [739]	training's rmse: 0.794436	valid_1's rmse: 0.843967
# [740]	training's rmse: 0.794336	valid_1's rmse: 0.843895
# [741]	training's rmse: 0.794251	valid_1's rmse: 0.843847
# [742]	training's rmse: 0.793989	valid_1's rmse: 0.843763
# [743]	training's rmse: 0.793919	valid_1's rmse: 0.84374
# [744]	training's rmse: 0.793802	valid_1's rmse: 0.843602
# [745]	training's rmse: 0.793585	valid_1's rmse: 0.843367
# [746]	training's rmse: 0.793451	valid_1's rmse: 0.843396
# [747]	training's rmse: 0.793294	valid_1's rmse: 0.843238
# [748]	training's rmse: 0.793101	valid_1's rmse: 0.843125
# [749]	training's rmse: 0.792934	valid_1's rmse: 0.842948
# [750]	training's rmse: 0.792828	valid_1's rmse: 0.842915
# [751]	training's rmse: 0.792687	valid_1's rmse: 0.842939
# [752]	training's rmse: 0.792535	valid_1's rmse: 0.842845
# [753]	training's rmse: 0.792394	valid_1's rmse: 0.842658
# [754]	training's rmse: 0.792128	valid_1's rmse: 0.842319
# [755]	training's rmse: 0.792032	valid_1's rmse: 0.842283
# [756]	training's rmse: 0.791951	valid_1's rmse: 0.842229
# [757]	training's rmse: 0.791732	valid_1's rmse: 0.842063
# [758]	training's rmse: 0.791637	valid_1's rmse: 0.842011
# [759]	training's rmse: 0.79148	valid_1's rmse: 0.842018
# [760]	training's rmse: 0.791376	valid_1's rmse: 0.841905
# [761]	training's rmse: 0.791233	valid_1's rmse: 0.84178
# [762]	training's rmse: 0.790949	valid_1's rmse: 0.841597
# [763]	training's rmse: 0.790872	valid_1's rmse: 0.841575
# [764]	training's rmse: 0.790768	valid_1's rmse: 0.84148
# [765]	training's rmse: 0.790587	valid_1's rmse: 0.841343
# [766]	training's rmse: 0.790525	valid_1's rmse: 0.841365
# [767]	training's rmse: 0.790328	valid_1's rmse: 0.841078
# [768]	training's rmse: 0.790197	valid_1's rmse: 0.840941
# [769]	training's rmse: 0.790094	valid_1's rmse: 0.840897
# [770]	training's rmse: 0.790051	valid_1's rmse: 0.840848
# [771]	training's rmse: 0.789906	valid_1's rmse: 0.840784
# [772]	training's rmse: 0.78978	valid_1's rmse: 0.840689
# [773]	training's rmse: 0.789699	valid_1's rmse: 0.840618
# [774]	training's rmse: 0.789624	valid_1's rmse: 0.840587
# [775]	training's rmse: 0.78934	valid_1's rmse: 0.840197
# [776]	training's rmse: 0.789224	valid_1's rmse: 0.84022
# [777]	training's rmse: 0.788967	valid_1's rmse: 0.840069
# [778]	training's rmse: 0.788872	valid_1's rmse: 0.839979
# [779]	training's rmse: 0.788736	valid_1's rmse: 0.839849
# [780]	training's rmse: 0.788587	valid_1's rmse: 0.839753
# [781]	training's rmse: 0.788514	valid_1's rmse: 0.839652
# [782]	training's rmse: 0.788409	valid_1's rmse: 0.839559
# [783]	training's rmse: 0.788338	valid_1's rmse: 0.839255
# [784]	training's rmse: 0.788271	valid_1's rmse: 0.839339
# [785]	training's rmse: 0.78817	valid_1's rmse: 0.839346
# [786]	training's rmse: 0.788076	valid_1's rmse: 0.839282
# [787]	training's rmse: 0.787964	valid_1's rmse: 0.839225
# [788]	training's rmse: 0.787789	valid_1's rmse: 0.839188
# [789]	training's rmse: 0.7877	valid_1's rmse: 0.839105
# [790]	training's rmse: 0.787602	valid_1's rmse: 0.838993
# [791]	training's rmse: 0.787428	valid_1's rmse: 0.838892
# [792]	training's rmse: 0.787261	valid_1's rmse: 0.838724
# [793]	training's rmse: 0.78705	valid_1's rmse: 0.838538
# [794]	training's rmse: 0.786864	valid_1's rmse: 0.838458
# [795]	training's rmse: 0.78677	valid_1's rmse: 0.83806
# [796]	training's rmse: 0.786562	valid_1's rmse: 0.837972
# [797]	training's rmse: 0.786426	valid_1's rmse: 0.837864
# [798]	training's rmse: 0.78624	valid_1's rmse: 0.837742
# [799]	training's rmse: 0.786182	valid_1's rmse: 0.837713
# [800]	training's rmse: 0.78606	valid_1's rmse: 0.837623
# [801]	training's rmse: 0.785953	valid_1's rmse: 0.837578
# [802]	training's rmse: 0.785825	valid_1's rmse: 0.837496
# [803]	training's rmse: 0.785734	valid_1's rmse: 0.837504
# [804]	training's rmse: 0.78565	valid_1's rmse: 0.837413
# [805]	training's rmse: 0.785528	valid_1's rmse: 0.837332
# [806]	training's rmse: 0.785448	valid_1's rmse: 0.837304
# [807]	training's rmse: 0.785391	valid_1's rmse: 0.837294
# [808]	training's rmse: 0.785294	valid_1's rmse: 0.8372
# [809]	training's rmse: 0.785139	valid_1's rmse: 0.837304
# [810]	training's rmse: 0.784892	valid_1's rmse: 0.837086
# [811]	training's rmse: 0.78486	valid_1's rmse: 0.837093
# [812]	training's rmse: 0.784683	valid_1's rmse: 0.836979
# [813]	training's rmse: 0.784579	valid_1's rmse: 0.836884
# [814]	training's rmse: 0.78442	valid_1's rmse: 0.83665
# [815]	training's rmse: 0.784339	valid_1's rmse: 0.836528
# [816]	training's rmse: 0.784292	valid_1's rmse: 0.836524
# [817]	training's rmse: 0.784157	valid_1's rmse: 0.835898
# [818]	training's rmse: 0.784037	valid_1's rmse: 0.835898
# [819]	training's rmse: 0.78395	valid_1's rmse: 0.835842
# [820]	training's rmse: 0.78386	valid_1's rmse: 0.835791
# [821]	training's rmse: 0.783747	valid_1's rmse: 0.835812
# [822]	training's rmse: 0.783559	valid_1's rmse: 0.835597
# [823]	training's rmse: 0.783431	valid_1's rmse: 0.835494
# [824]	training's rmse: 0.783366	valid_1's rmse: 0.835216
# [825]	training's rmse: 0.783072	valid_1's rmse: 0.834976
# [826]	training's rmse: 0.782848	valid_1's rmse: 0.834735
# [827]	training's rmse: 0.782661	valid_1's rmse: 0.834595
# [828]	training's rmse: 0.782397	valid_1's rmse: 0.834482
# [829]	training's rmse: 0.782322	valid_1's rmse: 0.834409
# [830]	training's rmse: 0.782097	valid_1's rmse: 0.834228
# [831]	training's rmse: 0.781975	valid_1's rmse: 0.834184
# [832]	training's rmse: 0.781893	valid_1's rmse: 0.834194
# [833]	training's rmse: 0.781791	valid_1's rmse: 0.834136
# [834]	training's rmse: 0.781733	valid_1's rmse: 0.834106
# [835]	training's rmse: 0.781442	valid_1's rmse: 0.833923
# [836]	training's rmse: 0.781362	valid_1's rmse: 0.833841
# [837]	training's rmse: 0.78114	valid_1's rmse: 0.833663
# [838]	training's rmse: 0.780989	valid_1's rmse: 0.833712
# [839]	training's rmse: 0.780937	valid_1's rmse: 0.833697
# [840]	training's rmse: 0.780853	valid_1's rmse: 0.833613
# [841]	training's rmse: 0.78081	valid_1's rmse: 0.83364
# [842]	training's rmse: 0.780625	valid_1's rmse: 0.833458
# [843]	training's rmse: 0.780491	valid_1's rmse: 0.833342
# [844]	training's rmse: 0.780366	valid_1's rmse: 0.833243
# [845]	training's rmse: 0.780184	valid_1's rmse: 0.833061
# [846]	training's rmse: 0.780083	valid_1's rmse: 0.832994
# [847]	training's rmse: 0.779993	valid_1's rmse: 0.83295
# [848]	training's rmse: 0.779949	valid_1's rmse: 0.832934
# [849]	training's rmse: 0.779878	valid_1's rmse: 0.832865
# [850]	training's rmse: 0.779486	valid_1's rmse: 0.832356
# [851]	training's rmse: 0.778993	valid_1's rmse: 0.832012
# [852]	training's rmse: 0.778919	valid_1's rmse: 0.831958
# [853]	training's rmse: 0.778845	valid_1's rmse: 0.831949
# [854]	training's rmse: 0.778746	valid_1's rmse: 0.831871
# [855]	training's rmse: 0.778575	valid_1's rmse: 0.831831
# [856]	training's rmse: 0.778372	valid_1's rmse: 0.831837
# [857]	training's rmse: 0.778316	valid_1's rmse: 0.83186
# [858]	training's rmse: 0.778225	valid_1's rmse: 0.831814
# [859]	training's rmse: 0.778095	valid_1's rmse: 0.831755
# [860]	training's rmse: 0.777915	valid_1's rmse: 0.831639
# [861]	training's rmse: 0.77784	valid_1's rmse: 0.831574
# [862]	training's rmse: 0.777776	valid_1's rmse: 0.831559
# [863]	training's rmse: 0.777711	valid_1's rmse: 0.831609
# [864]	training's rmse: 0.777542	valid_1's rmse: 0.831463
# [865]	training's rmse: 0.777439	valid_1's rmse: 0.831391
# [866]	training's rmse: 0.777335	valid_1's rmse: 0.831463
# [867]	training's rmse: 0.777274	valid_1's rmse: 0.831423
# [868]	training's rmse: 0.777149	valid_1's rmse: 0.831353
# [869]	training's rmse: 0.777083	valid_1's rmse: 0.831285
# [870]	training's rmse: 0.77691	valid_1's rmse: 0.831124
# [871]	training's rmse: 0.776734	valid_1's rmse: 0.83099
# [872]	training's rmse: 0.776665	valid_1's rmse: 0.830927
# [873]	training's rmse: 0.776448	valid_1's rmse: 0.830878
# [874]	training's rmse: 0.776289	valid_1's rmse: 0.830722
# [875]	training's rmse: 0.776175	valid_1's rmse: 0.830621
# [876]	training's rmse: 0.776109	valid_1's rmse: 0.830674
# [877]	training's rmse: 0.775953	valid_1's rmse: 0.83058
# [878]	training's rmse: 0.775848	valid_1's rmse: 0.830506
# [879]	training's rmse: 0.775758	valid_1's rmse: 0.830364
# [880]	training's rmse: 0.77568	valid_1's rmse: 0.830349
# [881]	training's rmse: 0.775611	valid_1's rmse: 0.830259
# [882]	training's rmse: 0.775525	valid_1's rmse: 0.830347
# [883]	training's rmse: 0.775449	valid_1's rmse: 0.830323
# [884]	training's rmse: 0.775234	valid_1's rmse: 0.830142
# [885]	training's rmse: 0.775191	valid_1's rmse: 0.83014
# [886]	training's rmse: 0.775123	valid_1's rmse: 0.830091
# [887]	training's rmse: 0.775048	valid_1's rmse: 0.830094
# [888]	training's rmse: 0.774952	valid_1's rmse: 0.830082
# [889]	training's rmse: 0.774796	valid_1's rmse: 0.829879
# [890]	training's rmse: 0.774696	valid_1's rmse: 0.829771
# [891]	training's rmse: 0.774649	valid_1's rmse: 0.829766
# [892]	training's rmse: 0.774392	valid_1's rmse: 0.829521
# [893]	training's rmse: 0.77422	valid_1's rmse: 0.829322
# [894]	training's rmse: 0.774164	valid_1's rmse: 0.829365
# [895]	training's rmse: 0.774072	valid_1's rmse: 0.829286
# [896]	training's rmse: 0.773985	valid_1's rmse: 0.829151
# [897]	training's rmse: 0.773934	valid_1's rmse: 0.829111
# [898]	training's rmse: 0.773782	valid_1's rmse: 0.82897
# [899]	training's rmse: 0.773654	valid_1's rmse: 0.828869
# [900]	training's rmse: 0.773587	valid_1's rmse: 0.828841
# [901]	training's rmse: 0.773433	valid_1's rmse: 0.828714
# [902]	training's rmse: 0.773305	valid_1's rmse: 0.828652
# [903]	training's rmse: 0.773259	valid_1's rmse: 0.828617
# [904]	training's rmse: 0.773181	valid_1's rmse: 0.828563
# [905]	training's rmse: 0.773097	valid_1's rmse: 0.828495
# [906]	training's rmse: 0.772976	valid_1's rmse: 0.828443
# [907]	training's rmse: 0.772842	valid_1's rmse: 0.828359
# [908]	training's rmse: 0.772794	valid_1's rmse: 0.82837
# [909]	training's rmse: 0.772755	valid_1's rmse: 0.828365
# [910]	training's rmse: 0.772719	valid_1's rmse: 0.828407
# [911]	training's rmse: 0.772614	valid_1's rmse: 0.828399
# [912]	training's rmse: 0.77257	valid_1's rmse: 0.828395
# [913]	training's rmse: 0.772512	valid_1's rmse: 0.828346
# [914]	training's rmse: 0.772444	valid_1's rmse: 0.828316
# [915]	training's rmse: 0.772361	valid_1's rmse: 0.828219
# [916]	training's rmse: 0.772293	valid_1's rmse: 0.828181
# [917]	training's rmse: 0.772202	valid_1's rmse: 0.828159
# [918]	training's rmse: 0.772064	valid_1's rmse: 0.828049
# [919]	training's rmse: 0.771995	valid_1's rmse: 0.827999
# [920]	training's rmse: 0.771935	valid_1's rmse: 0.827947
# [921]	training's rmse: 0.771886	valid_1's rmse: 0.827951
# [922]	training's rmse: 0.771739	valid_1's rmse: 0.827871
# [923]	training's rmse: 0.771645	valid_1's rmse: 0.827465
# [924]	training's rmse: 0.77157	valid_1's rmse: 0.827414
# [925]	training's rmse: 0.771511	valid_1's rmse: 0.827375
# [926]	training's rmse: 0.771388	valid_1's rmse: 0.8273
# [927]	training's rmse: 0.771292	valid_1's rmse: 0.827239
# [928]	training's rmse: 0.771209	valid_1's rmse: 0.827201
# [929]	training's rmse: 0.771109	valid_1's rmse: 0.827182
# [930]	training's rmse: 0.771073	valid_1's rmse: 0.827166
# [931]	training's rmse: 0.771012	valid_1's rmse: 0.827125
# [932]	training's rmse: 0.77097	valid_1's rmse: 0.827188
# [933]	training's rmse: 0.770848	valid_1's rmse: 0.827121
# [934]	training's rmse: 0.770689	valid_1's rmse: 0.827037
# [935]	training's rmse: 0.770647	valid_1's rmse: 0.827035
# [936]	training's rmse: 0.770509	valid_1's rmse: 0.826929
# [937]	training's rmse: 0.770392	valid_1's rmse: 0.826832
# [938]	training's rmse: 0.77018	valid_1's rmse: 0.826646
# [939]	training's rmse: 0.770075	valid_1's rmse: 0.82654
# [940]	training's rmse: 0.770002	valid_1's rmse: 0.826521
# [941]	training's rmse: 0.769918	valid_1's rmse: 0.826628
# [942]	training's rmse: 0.769835	valid_1's rmse: 0.826593
# [943]	training's rmse: 0.769791	valid_1's rmse: 0.826549
# [944]	training's rmse: 0.769631	valid_1's rmse: 0.826453
# [945]	training's rmse: 0.76944	valid_1's rmse: 0.826344
# [946]	training's rmse: 0.769235	valid_1's rmse: 0.826147
# [947]	training's rmse: 0.769191	valid_1's rmse: 0.826169
# [948]	training's rmse: 0.769135	valid_1's rmse: 0.826154
# [949]	training's rmse: 0.769073	valid_1's rmse: 0.826053
# [950]	training's rmse: 0.768924	valid_1's rmse: 0.825868
# [951]	training's rmse: 0.768651	valid_1's rmse: 0.82566
# [952]	training's rmse: 0.768483	valid_1's rmse: 0.825648
# [953]	training's rmse: 0.768376	valid_1's rmse: 0.825537
# [954]	training's rmse: 0.768351	valid_1's rmse: 0.825511
# [955]	training's rmse: 0.76826	valid_1's rmse: 0.825502
# [956]	training's rmse: 0.768156	valid_1's rmse: 0.825443
# [957]	training's rmse: 0.768081	valid_1's rmse: 0.825357
# [958]	training's rmse: 0.767956	valid_1's rmse: 0.825337
# [959]	training's rmse: 0.76789	valid_1's rmse: 0.825332
# [960]	training's rmse: 0.767831	valid_1's rmse: 0.825314
# [961]	training's rmse: 0.767799	valid_1's rmse: 0.825345
# [962]	training's rmse: 0.767707	valid_1's rmse: 0.825308
# [963]	training's rmse: 0.767623	valid_1's rmse: 0.825184
# [964]	training's rmse: 0.767605	valid_1's rmse: 0.825183
# [965]	training's rmse: 0.767408	valid_1's rmse: 0.825
# [966]	training's rmse: 0.767203	valid_1's rmse: 0.824763
# [967]	training's rmse: 0.767011	valid_1's rmse: 0.824616
# [968]	training's rmse: 0.76692	valid_1's rmse: 0.824548
# [969]	training's rmse: 0.766748	valid_1's rmse: 0.824387
# [970]	training's rmse: 0.766636	valid_1's rmse: 0.824345
# [971]	training's rmse: 0.766439	valid_1's rmse: 0.824122
# [972]	training's rmse: 0.766342	valid_1's rmse: 0.823737
# [973]	training's rmse: 0.766179	valid_1's rmse: 0.823586
# [974]	training's rmse: 0.76608	valid_1's rmse: 0.8235
# [975]	training's rmse: 0.765877	valid_1's rmse: 0.823276
# [976]	training's rmse: 0.765795	valid_1's rmse: 0.823294
# [977]	training's rmse: 0.765648	valid_1's rmse: 0.823219
# [978]	training's rmse: 0.765329	valid_1's rmse: 0.823002
# [979]	training's rmse: 0.76528	valid_1's rmse: 0.823
# [980]	training's rmse: 0.765237	valid_1's rmse: 0.823027
# [981]	training's rmse: 0.765159	valid_1's rmse: 0.822969
# [982]	training's rmse: 0.765066	valid_1's rmse: 0.822928
# [983]	training's rmse: 0.764972	valid_1's rmse: 0.822961
# [984]	training's rmse: 0.764861	valid_1's rmse: 0.822925
# [985]	training's rmse: 0.764788	valid_1's rmse: 0.822906
# [986]	training's rmse: 0.764658	valid_1's rmse: 0.822786
# [987]	training's rmse: 0.764524	valid_1's rmse: 0.822761
# [988]	training's rmse: 0.764439	valid_1's rmse: 0.822608
# [989]	training's rmse: 0.764388	valid_1's rmse: 0.822547
# [990]	training's rmse: 0.76435	valid_1's rmse: 0.822581
# [991]	training's rmse: 0.764229	valid_1's rmse: 0.822424
# [992]	training's rmse: 0.764173	valid_1's rmse: 0.822316
# [993]	training's rmse: 0.764105	valid_1's rmse: 0.822248
# [994]	training's rmse: 0.764028	valid_1's rmse: 0.822129
# [995]	training's rmse: 0.763948	valid_1's rmse: 0.822062
# [996]	training's rmse: 0.763837	valid_1's rmse: 0.822071
# [997]	training's rmse: 0.763734	valid_1's rmse: 0.821965
# [998]	training's rmse: 0.763671	valid_1's rmse: 0.821982
# [999]	training's rmse: 0.763617	valid_1's rmse: 0.82205
# [1000]	training's rmse: 0.763484	valid_1's rmse: 0.821924
# Did not meet early stopping. Best iteration is:
# [1000]	training's rmse: 0.763484	valid_1's rmse: 0.821924

# %%
import matplotlib as mlt
import matplotlib.pyplot as plt
# %matplotlib inline

lgb.plot_metric(evals_result, figsize=(12, 5))

# %%
pred = model.predict(temp)
pred = np.expm1(pred)
temp['AMT'] = np.round(pred, 0)
temp['REG_YYMM'] = temp['year']*100 + temp['month']
temp = temp[['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT']]
temp = temp.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM']).sum().reset_index(drop=False)

# %%
# 디코딩 (Random Forest)
temp['CARD_SIDO_NM'] = encoders['CARD_SIDO_NM'].inverse_transform(temp['CARD_SIDO_NM'])
temp['STD_CLSS_NM'] = encoders['STD_CLSS_NM'].inverse_transform(temp['STD_CLSS_NM'])

# %%
# 제출 파일 만들기(Random Forest)
submission = pd.read_csv('../../Data/Jeju/submission.csv', index_col=0)
submission = submission.drop(['AMT'], axis=1)
submission = submission.merge(temp, left_on=['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM'], right_on=['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM'], how='left')
submission.index.name = 'id'
compare_pred = submission.dropna()
submission = submission.fillna(0)
submission.head()
# Out:
#     REG_YYMM CARD_SIDO_NM           STD_CLSS_NM           AMT
# id
# 0     202004           강원            건강보조식품 소매업  5.243611e+07
# 1     202004           강원               골프장 운영업  3.120657e+09
# 2     202004           강원           과실 및 채소 소매업  9.537368e+08
# 3     202004           강원     관광 민예품 및 선물용품 소매업  1.095611e+07
# 4     202004           강원  그외 기타 분류안된 오락관련 서비스업  0.000000e+00

# %%
submission.to_csv('submission/submission lgbm 0728 valid March_re regression.csv', encoding='utf-8-sig')
