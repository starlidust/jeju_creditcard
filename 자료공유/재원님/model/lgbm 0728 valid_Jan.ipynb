# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data

# %%
data1 = pd.read_csv('../../Data/Jeju/201901-202003.csv')
data1 = data1.fillna('')
data2 = pd.read_csv('../../Data/Jeju/202004.csv')
data2 = data2.fillna('')

# %%
data = pd.concat([data1, data2])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26048114 entries, 0 to 1350321
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   REG_YYMM      int64
#  1   CARD_SIDO_NM  object
#  2   CARD_CCG_NM   object
#  3   STD_CLSS_NM   object
#  4   HOM_SIDO_NM   object
#  5   HOM_CCG_NM    object
#  6   AGE           object
#  7   SEX_CTGO_CD   int64
#  8   FLC           int64
#  9   CSTMR_CNT     int64
#  10  AMT           int64
#  11  CNT           int64
# dtypes: int64(6), object(6)
# memory usage: 2.5+ GB

# %% [markdown]
# #### 결측 처리

# %%
data.loc[data.CARD_CCG_NM.isna(),'CARD_CCG_NM'] = '세종'
data.loc[data.HOM_CCG_NM.isna(),'HOM_CCG_NM'] = '세종'

# %% [markdown]
# #### 18 사업체총조사

# %%
all_jobs_df = pd.read_csv('data/18 사업체총조사_키워드매칭.csv',encoding = 'cp949')
all_jobs_df = all_jobs_df[['행정구역별','데이터업종명','사업체수 (개)', '종사자수 (명)']]
all_jobs_df.columns = ['CARD_SIDO_NM','STD_CLSS_NM', 'company','employee']
all_jobs_df.employee = all_jobs_df.employee.apply(lambda x : x.replace("X","0")).astype(int)
all_jobs_df = all_jobs_df.groupby(['CARD_SIDO_NM','STD_CLSS_NM'])[['company','employee']].sum().reset_index()

all_jobs_df = all_jobs_df[~(all_jobs_df.CARD_SIDO_NM == '전국')]

# %% [markdown]
# #### 지역내 각 업종이 차지하는 매출비중

# %%
def local_percent(data):
    pivoted = data.pivot_table(index = ['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM'],columns ='REG_YYMM',values= "AMT",aggfunc='sum').reset_index()
    pivoted.fillna(0,inplace= True)

    #각 지역별(시군구)업종의 매출비율을 저장
    sidos = pivoted.CARD_SIDO_NM.unique()

    local_percent_df = pd.DataFrame()
    for sido in sidos:
        sample_sido = pivoted[pivoted.CARD_SIDO_NM == sido]
        sigungus = sample_sido.CARD_CCG_NM.unique()
        for sigungu in sigungus:
            sample = sample_sido[sample_sido.CARD_CCG_NM == sigungu]
            sum_arr = sample.iloc[:,3:].sum().values.reshape(1,-1)
            parcent_df = (sample.iloc[:,3:]/sum_arr)*100

            fin = pd.concat([sample.iloc[:,:3],parcent_df],axis=1)
            local_percent_df = pd.concat([local_percent_df,fin])

    #신규변수 LP(local percent) : 지역내 각 업종이 차지하는 매출비중
    local_percent_df = local_percent_df.melt(id_vars=['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM'],value_name='LP')
    return local_percent_df

# %% [markdown]
# #### 전체업종에서 각 지역업종이 차지하는 매출비중

# %%
def job_percent(data):
    pivoted = data.pivot_table(index = ['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM'],columns ='REG_YYMM',values= "AMT",aggfunc='sum').reset_index()
    pivoted.fillna(0,inplace= True)

    all_pivoted = data.pivot_table(index = ['STD_CLSS_NM'],columns ='REG_YYMM',values= "AMT",aggfunc= 'sum').reset_index()
    all_pivoted.fillna(0,inplace= True)
    all_pivoted = all_pivoted.set_index('STD_CLSS_NM')

    job_percent_df = pd.DataFrame()
    for job in all_pivoted.index:
        taget_df = pivoted[pivoted.STD_CLSS_NM == job]
        tail = (taget_df.iloc[:,3:]/all_pivoted.iloc[0].values)*100
        head = taget_df.iloc[:,:3]
        full = pd.concat([head,tail],axis =1)
        job_percent_df = pd.concat([job_percent_df,full])

    #신규변수 JP(Job percent): 전체업종에서 해당지역의 업종이 차이하는 비율
    job_percent_df = job_percent_df.melt(id_vars=['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM'],value_name='JP')
    return job_percent_df

# %%
local_percent_df = local_percent(data)
job_percent_df = job_percent(data)

# %% [markdown]
# #### 거래횟수와 이용고객과의 관계 (2019)

# %%
def cust_differ(data):
    data['differ'] = (data.CNT- data.CSTMR_CNT)
    
    #양수(단골)
    plus_custom = data[data['differ']>0]
    pivot_plus = plus_custom.pivot_table(index = ['CARD_SIDO_NM','STD_CLSS_NM'],columns = 'REG_YYMM', values= 'differ', aggfunc ='sum').reset_index()
    
    melt_plus = pivot_plus.melt(id_vars=['CARD_SIDO_NM','STD_CLSS_NM'],value_name='loyal')
    melt_plus['year'] = melt_plus['REG_YYMM'].apply(lambda x: int(str(x)[:4]))
    melt_plus['month'] = melt_plus['REG_YYMM'].apply(lambda x: int(str(x)[5:]))
    
    #2019만 사용
    melt_plus = melt_plus[melt_plus.year == 2019]
    melt_plus.drop(['year'],axis= 1,inplace = True)
    
    #음수(환불)
    minus_custom = data[data['differ']<0]
    pivot_minus = minus_custom.pivot_table(index = ['CARD_SIDO_NM','STD_CLSS_NM'],columns = 'REG_YYMM', values= 'differ', aggfunc ='sum').reset_index()
    
    melt_minus = pivot_minus.melt(id_vars=['CARD_SIDO_NM','STD_CLSS_NM'],value_name='refund')
    melt_minus['year'] = melt_minus['REG_YYMM'].apply(lambda x: int(str(x)[:4]))
    melt_minus['month'] = melt_minus['REG_YYMM'].apply(lambda x: int(str(x)[5:]))
    #2019만 사용
    melt_minus = melt_minus[melt_minus.year == 2019]
    melt_minus.drop(['year'],axis= 1,inplace = True)
    
  
    #둘 결헙
    cust_differ_df = pd.merge(melt_plus,melt_minus,how= 'outer')
    
    return cust_differ_df

# %%
trade_num_2019 = cust_differ(data)

# %% [markdown]
# #### 거래횟수와 이용고객과의 관계 (2020)

# %%
def cust_differ_2020(data):
    data['differ'] = (data.CNT- data.CSTMR_CNT)
    
    #양수(단골)
    plus_custom = data[data['differ']>0]
    pivot_plus = plus_custom.pivot_table(index = ['CARD_SIDO_NM','STD_CLSS_NM'],columns = 'REG_YYMM', values= 'differ', aggfunc ='sum').reset_index()
    
    melt_plus = pivot_plus.melt(id_vars=['CARD_SIDO_NM','STD_CLSS_NM'],value_name='loyal')
    melt_plus['year'] = melt_plus['REG_YYMM'].apply(lambda x: int(str(x)[:4]))
    melt_plus['month'] = melt_plus['REG_YYMM'].apply(lambda x: int(str(x)[5:]))
    
    #2020만 사용
    melt_plus = melt_plus[melt_plus.year == 2020]
    melt_plus.drop(['year'],axis= 1,inplace = True)
    
    #음수(환불)
    minus_custom = data[data['differ']<0]
    pivot_minus = minus_custom.pivot_table(index = ['CARD_SIDO_NM','STD_CLSS_NM'],columns = 'REG_YYMM', values= 'differ', aggfunc ='sum').reset_index()
    
    melt_minus = pivot_minus.melt(id_vars=['CARD_SIDO_NM','STD_CLSS_NM'],value_name='refund')
    melt_minus['year'] = melt_minus['REG_YYMM'].apply(lambda x: int(str(x)[:4]))
    melt_minus['month'] = melt_minus['REG_YYMM'].apply(lambda x: int(str(x)[5:]))
    #2020만 사용
    melt_minus = melt_minus[melt_minus.year == 2020]
    melt_minus.drop(['year'],axis= 1,inplace = True)
    
  
    #둘 결헙
    cust_differ_df = pd.merge(melt_plus,melt_minus,how= 'outer')
    
    return cust_differ_df

# %%
trade_num_2020 = cust_differ_2020(data)

# %%
trade_num = pd.concat([trade_num_2019, trade_num_2020])

# %%
trade_num.loyal = trade_num.loyal.fillna(-999)
trade_num.refund = trade_num.refund.fillna(999)

# %%
trade_num
# Out:
#      CARD_SIDO_NM           STD_CLSS_NM  REG_YYMM    loyal  month  refund
# 0              강원            건강보조식품 소매업  201901.0     80.0      1   -32.0
# 1              강원               골프장 운영업  201901.0  14890.0      1   999.0
# 2              강원           과실 및 채소 소매업  201901.0   7484.0      1   999.0
# 3              강원     관광 민예품 및 선물용품 소매업  201901.0    195.0      1   999.0
# 4              강원  그외 기타 분류안된 오락관련 서비스업  201901.0   -999.0      1   999.0
# ...           ...                   ...       ...      ...    ...     ...
# 2575           충북              휴양콘도 운영업  202004.0     62.0      4   999.0
# 2576           대전                  여행사업  202001.0   -999.0      1   999.0
# 2577           대전                  여행사업  202002.0   -999.0      2   999.0
# 2578           대전                  여행사업  202003.0   -999.0      3   999.0
# 2579           대전                  여행사업  202004.0   -999.0      4   999.0
#
# [10320 rows x 6 columns]

# %% [markdown]
# #### 추가변수 결합

# %%
data.shape
# Out:
# (26048114, 13)

# %%
local_percent_df
# Out:
#        CARD_SIDO_NM CARD_CCG_NM            STD_CLSS_NM REG_YYMM         LP
# 0                강원         강릉시             건강보조식품 소매업   201901   0.138432
# 1                강원         강릉시                골프장 운영업   201901   0.148825
# 2                강원         강릉시            과실 및 채소 소매업   201901   1.468549
# 3                강원         강릉시      관광 민예품 및 선물용품 소매업   201901   0.022661
# 4                강원         강릉시        그외 기타 스포츠시설 운영업   201901   0.003255
# ...             ...         ...                    ...      ...        ...
# 124523           충북         충주시  피자 햄버거 샌드위치 및 유사 음식점업   202004   1.362619
# 124524           충북         충주시                한식 음식점업   202004  18.402971
# 124525           충북         충주시                    호텔업   202004   0.059226
# 124526           충북         충주시          화장품 및 방향제 소매업   202004   0.368080
# 124527           충북         충주시               휴양콘도 운영업   202004   0.004580
#
# [124528 rows x 5 columns]

# %%
columns = ['REG_YYMM', 'CARD_SIDO_NM', 'CARD_CCG_NM', 'STD_CLSS_NM', 'HOM_SIDO_NM', 'AGE', 'SEX_CTGO_CD', 'FLC']
df = data.groupby(columns, as_index=False)[['AMT']].sum()

# %%
grouped = pd.merge(df,all_jobs_df,on =['CARD_SIDO_NM','STD_CLSS_NM'],how = 'left')
grouped = pd.merge(grouped,local_percent_df,on =['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM','REG_YYMM'],how = 'left')
grouped = pd.merge(grouped,job_percent_df,on =['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM','REG_YYMM'],how = 'left')
grouped = pd.merge(grouped, trade_num, on =['CARD_SIDO_NM','STD_CLSS_NM','REG_YYMM'], how = 'left')

# %%
grouped.head(5)
# Out:
#   REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM  AGE  SEX_CTGO_CD  \
# 0   201901           강원         강릉시  건강보조식품 소매업          강원  20s            1
# 1   201901           강원         강릉시  건강보조식품 소매업          강원  30s            1
# 2   201901           강원         강릉시  건강보조식품 소매업          강원  30s            2
# 3   201901           강원         강릉시  건강보조식품 소매업          강원  40s            1
# 4   201901           강원         강릉시  건강보조식품 소매업          강원  40s            1
#
#    FLC      AMT  company  employee        LP        JP  loyal  month  refund
# 0    1   311200    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0
# 1    2  1374500    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0
# 2    2   818700    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0
# 3    3  1717000    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0
# 4    4  1047300    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0

# %%
grouped.REG_YYMM = pd.to_datetime(grouped.REG_YYMM, format='%Y%m')

# %%
from sklearn.preprocessing import LabelEncoder

# 인코딩
dtypes = grouped.dtypes
encoders = {}
for column in grouped.columns:
    if str(dtypes[column]) == 'object':
        encoder = LabelEncoder()
        encoder.fit(grouped[column])
        encoders[column] = encoder
        
df_num = grouped.copy()        
for column in encoders.keys():
    encoder = encoders[column]
    df_num[column] = encoder.transform(grouped[column])

# %%
df_num
# Out:
#           REG_YYMM  CARD_SIDO_NM  CARD_CCG_NM  STD_CLSS_NM  HOM_SIDO_NM  AGE  \
# 0       2019-01-01             0            4            0            0    1
# 1       2019-01-01             0            4            0            0    2
# 2       2019-01-01             0            4            0            0    2
# 3       2019-01-01             0            4            0            0    3
# 4       2019-01-01             0            4            0            0    3
# ...            ...           ...          ...          ...          ...  ...
# 5630138 2020-04-01            16          202           40           16    1
# 5630139 2020-04-01            16          202           40           16    2
# 5630140 2020-04-01            16          202           40           16    3
# 5630141 2020-04-01            16          202           40           16    4
# 5630142 2020-04-01            16          202           40           16    5
#
#          SEX_CTGO_CD  FLC      AMT  company  employee        LP        JP  \
# 0                  1    1   311200    263.0     399.0  0.138432  0.279221
# 1                  1    2  1374500    263.0     399.0  0.138432  0.279221
# 2                  2    2   818700    263.0     399.0  0.138432  0.279221
# 3                  1    3  1717000    263.0     399.0  0.138432  0.279221
# 4                  1    4  1047300    263.0     399.0  0.138432  0.279221
# ...              ...  ...      ...      ...       ...       ...       ...
# 5630138            1    1    77000     11.0     492.0  0.004580  0.011570
# 5630139            1    2    92000     11.0     492.0  0.004580  0.011570
# 5630140            2    3   193000     11.0     492.0  0.004580  0.011570
# 5630141            1    4    86000     11.0     492.0  0.004580  0.011570
# 5630142            2    5   227000     11.0     492.0  0.004580  0.011570
#
#          loyal  month  refund
# 0         80.0    1.0   -32.0
# 1         80.0    1.0   -32.0
# 2         80.0    1.0   -32.0
# 3         80.0    1.0   -32.0
# 4         80.0    1.0   -32.0
# ...        ...    ...     ...
# 5630138   62.0    4.0   999.0
# 5630139   62.0    4.0   999.0
# 5630140   62.0    4.0   999.0
# 5630141   62.0    4.0   999.0
# 5630142   62.0    4.0   999.0
#
# [5630143 rows x 16 columns]

# %%
import datetime as dt

df_num['month'] = df_num['REG_YYMM'].dt.month
df_num['year'] = df_num['REG_YYMM'].dt.year

# %%
train_df = df_num[df_num['REG_YYMM'] <= '2020-01-01']
validation_df = df_num[(df_num['REG_YYMM'] > '2020-01-01') & (df_num['REG_YYMM'] <'2020-04-01')]

# %%
---------------------------

# %%
# 7월 데이터 = 2020년의 평균값을 사용.

temp = df_num[df_num['REG_YYMM'] >= '2020']
temp = temp.groupby(['CARD_SIDO_NM', 'CARD_CCG_NM', 'STD_CLSS_NM',
                     'HOM_SIDO_NM', 'AGE', 'SEX_CTGO_CD', 'FLC'], as_index=False)[['company', 'employee', 
                                                            'LP', 'JP', 'loyal', 'month', 'refund', 'year']].mean()

# %%
temp.month = 7
temp = pd.concat([df_num[df_num['REG_YYMM'] == '2020-04-01'], temp])

# %%
temp = temp.drop(['REG_YYMM', 'AMT'], axis=1)

# %% [markdown]
# ### Light GBM

# %%
import lightgbm as lgb

# %%
train_df.head(1)
# Out:
#     REG_YYMM  CARD_SIDO_NM  CARD_CCG_NM  STD_CLSS_NM  HOM_SIDO_NM  AGE  \
# 0 2019-01-01             0            4            0            0    1
#
#    SEX_CTGO_CD  FLC     AMT  company  employee        LP        JP  loyal  \
# 0            1    1  311200    263.0     399.0  0.138432  0.279221   80.0
#
#    month  refund  year
# 0      1   -32.0  2019

# %%
train = train_df.drop(['AMT', 'REG_YYMM'], axis=1)
trian_label = np.log1p(train_df[['AMT']])

# %%
validation = validation_df.drop(['AMT', 'REG_YYMM'], axis=1)
validation_label = np.log1p(validation_df[['AMT']])

# %%
lgb_train = lgb.Dataset(train, label=trian_label)
lgb_eval = lgb.Dataset(validation, label=validation_label, reference=lgb_train)

# %%
evals_result = {}
params = {
    'boosting_type': 'gbdt',
    'objective': 'tweedie',
    'metric': 'rmse',
    'tweedie_variance_power':1.1,
    'max_depth':11,
    'num_leaves': 31,
    'learning_rate': 0.7,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0}

# %%
model = lgb.train(params, lgb_train, early_stopping_rounds=100,
                  num_boost_round=1000, evals_result=evals_result,
                  valid_sets= (lgb_train, lgb_eval),)
# Out:
# [1]	training's rmse: 1.96827	valid_1's rmse: 1.95018
# Training until validation scores don't improve for 100 rounds
# [2]	training's rmse: 1.87047	valid_1's rmse: 1.85736
# [3]	training's rmse: 1.77447	valid_1's rmse: 1.76175
# [4]	training's rmse: 1.71736	valid_1's rmse: 1.70431
# [5]	training's rmse: 1.69637	valid_1's rmse: 1.68505
# [6]	training's rmse: 1.64524	valid_1's rmse: 1.61958
# [7]	training's rmse: 1.62393	valid_1's rmse: 1.59767
# [8]	training's rmse: 1.59902	valid_1's rmse: 1.57144
# [9]	training's rmse: 1.55539	valid_1's rmse: 1.52938
# [10]	training's rmse: 1.53424	valid_1's rmse: 1.51054
# [11]	training's rmse: 1.52773	valid_1's rmse: 1.51642
# [12]	training's rmse: 1.51231	valid_1's rmse: 1.50003
# [13]	training's rmse: 1.48151	valid_1's rmse: 1.46911
# [14]	training's rmse: 1.47469	valid_1's rmse: 1.46326
# [15]	training's rmse: 1.46427	valid_1's rmse: 1.45219
# [16]	training's rmse: 1.45269	valid_1's rmse: 1.44173
# [17]	training's rmse: 1.43851	valid_1's rmse: 1.4306
# [18]	training's rmse: 1.4177	valid_1's rmse: 1.41132
# [19]	training's rmse: 1.41365	valid_1's rmse: 1.40729
# [20]	training's rmse: 1.39866	valid_1's rmse: 1.39521
# [21]	training's rmse: 1.39291	valid_1's rmse: 1.40275
# [22]	training's rmse: 1.3735	valid_1's rmse: 1.38467
# [23]	training's rmse: 1.36607	valid_1's rmse: 1.377
# [24]	training's rmse: 1.35258	valid_1's rmse: 1.35446
# [25]	training's rmse: 1.34592	valid_1's rmse: 1.34852
# [26]	training's rmse: 1.34051	valid_1's rmse: 1.34363
# [27]	training's rmse: 1.33211	valid_1's rmse: 1.33683
# [28]	training's rmse: 1.32109	valid_1's rmse: 1.32463
# [29]	training's rmse: 1.31575	valid_1's rmse: 1.32031
# [30]	training's rmse: 1.31002	valid_1's rmse: 1.31595
# [31]	training's rmse: 1.30523	valid_1's rmse: 1.3114
# [32]	training's rmse: 1.28366	valid_1's rmse: 1.29113
# [33]	training's rmse: 1.27849	valid_1's rmse: 1.28702
# [34]	training's rmse: 1.27444	valid_1's rmse: 1.28263
# [35]	training's rmse: 1.2528	valid_1's rmse: 1.26259
# [36]	training's rmse: 1.24601	valid_1's rmse: 1.25589
# [37]	training's rmse: 1.22582	valid_1's rmse: 1.24051
# [38]	training's rmse: 1.22134	valid_1's rmse: 1.23617
# [39]	training's rmse: 1.21641	valid_1's rmse: 1.23254
# [40]	training's rmse: 1.21268	valid_1's rmse: 1.22964
# [41]	training's rmse: 1.20686	valid_1's rmse: 1.22524
# [42]	training's rmse: 1.20339	valid_1's rmse: 1.2215
# [43]	training's rmse: 1.1998	valid_1's rmse: 1.2192
# [44]	training's rmse: 1.19594	valid_1's rmse: 1.21505
# [45]	training's rmse: 1.19024	valid_1's rmse: 1.2117
# [46]	training's rmse: 1.18708	valid_1's rmse: 1.2088
# [47]	training's rmse: 1.18475	valid_1's rmse: 1.20638
# [48]	training's rmse: 1.18364	valid_1's rmse: 1.20508
# [49]	training's rmse: 1.18088	valid_1's rmse: 1.20338
# [50]	training's rmse: 1.17639	valid_1's rmse: 1.19971
# [51]	training's rmse: 1.17404	valid_1's rmse: 1.19839
# [52]	training's rmse: 1.168	valid_1's rmse: 1.19552
# [53]	training's rmse: 1.16645	valid_1's rmse: 1.19544
# [54]	training's rmse: 1.16437	valid_1's rmse: 1.19339
# [55]	training's rmse: 1.16349	valid_1's rmse: 1.19255
# [56]	training's rmse: 1.16074	valid_1's rmse: 1.19036
# [57]	training's rmse: 1.15641	valid_1's rmse: 1.18601
# [58]	training's rmse: 1.15438	valid_1's rmse: 1.1853
# [59]	training's rmse: 1.15274	valid_1's rmse: 1.18405
# [60]	training's rmse: 1.14975	valid_1's rmse: 1.18084
# [61]	training's rmse: 1.14847	valid_1's rmse: 1.17925
# [62]	training's rmse: 1.14705	valid_1's rmse: 1.17826
# [63]	training's rmse: 1.14608	valid_1's rmse: 1.17789
# [64]	training's rmse: 1.14534	valid_1's rmse: 1.1802
# [65]	training's rmse: 1.14301	valid_1's rmse: 1.1794
# [66]	training's rmse: 1.1416	valid_1's rmse: 1.17784
# [67]	training's rmse: 1.12813	valid_1's rmse: 1.16897
# [68]	training's rmse: 1.12527	valid_1's rmse: 1.16775
# [69]	training's rmse: 1.12411	valid_1's rmse: 1.1785
# [70]	training's rmse: 1.12156	valid_1's rmse: 1.17637
# [71]	training's rmse: 1.11949	valid_1's rmse: 1.17576
# [72]	training's rmse: 1.11771	valid_1's rmse: 1.17454
# [73]	training's rmse: 1.11545	valid_1's rmse: 1.17323
# [74]	training's rmse: 1.11047	valid_1's rmse: 1.17021
# [75]	training's rmse: 1.10566	valid_1's rmse: 1.16588
# [76]	training's rmse: 1.10372	valid_1's rmse: 1.16448
# [77]	training's rmse: 1.10279	valid_1's rmse: 1.16333
# [78]	training's rmse: 1.10006	valid_1's rmse: 1.16099
# [79]	training's rmse: 1.09895	valid_1's rmse: 1.15983
# [80]	training's rmse: 1.09764	valid_1's rmse: 1.15865
# [81]	training's rmse: 1.09356	valid_1's rmse: 1.15447
# [82]	training's rmse: 1.09044	valid_1's rmse: 1.15151
# [83]	training's rmse: 1.08797	valid_1's rmse: 1.14873
# [84]	training's rmse: 1.08441	valid_1's rmse: 1.14623
# [85]	training's rmse: 1.08269	valid_1's rmse: 1.14486
# [86]	training's rmse: 1.08086	valid_1's rmse: 1.14336
# [87]	training's rmse: 1.07786	valid_1's rmse: 1.14089
# [88]	training's rmse: 1.0762	valid_1's rmse: 1.13927
# [89]	training's rmse: 1.0735	valid_1's rmse: 1.13683
# [90]	training's rmse: 1.06951	valid_1's rmse: 1.13432
# [91]	training's rmse: 1.06851	valid_1's rmse: 1.13326
# [92]	training's rmse: 1.06648	valid_1's rmse: 1.13174
# [93]	training's rmse: 1.06382	valid_1's rmse: 1.12984
# [94]	training's rmse: 1.06312	valid_1's rmse: 1.12979
# [95]	training's rmse: 1.06192	valid_1's rmse: 1.12942
# [96]	training's rmse: 1.06075	valid_1's rmse: 1.12824
# [97]	training's rmse: 1.05951	valid_1's rmse: 1.12745
# [98]	training's rmse: 1.05803	valid_1's rmse: 1.12647
# [99]	training's rmse: 1.05634	valid_1's rmse: 1.12552
# [100]	training's rmse: 1.05366	valid_1's rmse: 1.12303
# [101]	training's rmse: 1.05062	valid_1's rmse: 1.12132
# [102]	training's rmse: 1.04933	valid_1's rmse: 1.12026
# [103]	training's rmse: 1.04876	valid_1's rmse: 1.12127
# [104]	training's rmse: 1.04713	valid_1's rmse: 1.12027
# [105]	training's rmse: 1.04351	valid_1's rmse: 1.11889
# [106]	training's rmse: 1.03826	valid_1's rmse: 1.11533
# [107]	training's rmse: 1.0372	valid_1's rmse: 1.11438
# [108]	training's rmse: 1.0353	valid_1's rmse: 1.11318
# [109]	training's rmse: 1.0344	valid_1's rmse: 1.11259
# [110]	training's rmse: 1.03315	valid_1's rmse: 1.11223
# [111]	training's rmse: 1.03189	valid_1's rmse: 1.11116
# [112]	training's rmse: 1.03079	valid_1's rmse: 1.11044
# [113]	training's rmse: 1.02958	valid_1's rmse: 1.11101
# [114]	training's rmse: 1.02813	valid_1's rmse: 1.11064
# [115]	training's rmse: 1.02692	valid_1's rmse: 1.10928
# [116]	training's rmse: 1.02449	valid_1's rmse: 1.10593
# [117]	training's rmse: 1.02357	valid_1's rmse: 1.10521
# [118]	training's rmse: 1.02298	valid_1's rmse: 1.1046
# [119]	training's rmse: 1.0207	valid_1's rmse: 1.10313
# [120]	training's rmse: 1.01897	valid_1's rmse: 1.10167
# [121]	training's rmse: 1.01701	valid_1's rmse: 1.10069
# [122]	training's rmse: 1.01662	valid_1's rmse: 1.10077
# [123]	training's rmse: 1.01582	valid_1's rmse: 1.10034
# [124]	training's rmse: 1.01519	valid_1's rmse: 1.09981
# [125]	training's rmse: 1.01428	valid_1's rmse: 1.0988
# [126]	training's rmse: 1.01255	valid_1's rmse: 1.09728
# [127]	training's rmse: 1.01176	valid_1's rmse: 1.0969
# [128]	training's rmse: 1.01011	valid_1's rmse: 1.0961
# [129]	training's rmse: 1.00946	valid_1's rmse: 1.09589
# [130]	training's rmse: 1.00857	valid_1's rmse: 1.09524
# [131]	training's rmse: 1.00719	valid_1's rmse: 1.09438
# [132]	training's rmse: 1.006	valid_1's rmse: 1.09433
# [133]	training's rmse: 1.00513	valid_1's rmse: 1.09378
# [134]	training's rmse: 1.00306	valid_1's rmse: 1.09286
# [135]	training's rmse: 1.00227	valid_1's rmse: 1.09268
# [136]	training's rmse: 1.0017	valid_1's rmse: 1.09234
# [137]	training's rmse: 1.001	valid_1's rmse: 1.09206
# [138]	training's rmse: 0.99937	valid_1's rmse: 1.0906
# [139]	training's rmse: 0.998424	valid_1's rmse: 1.0899
# [140]	training's rmse: 0.997269	valid_1's rmse: 1.08931
# [141]	training's rmse: 0.996486	valid_1's rmse: 1.0888
# [142]	training's rmse: 0.995644	valid_1's rmse: 1.08947
# [143]	training's rmse: 0.9947	valid_1's rmse: 1.08865
# [144]	training's rmse: 0.994066	valid_1's rmse: 1.08816
# [145]	training's rmse: 0.993506	valid_1's rmse: 1.08782
# [146]	training's rmse: 0.992873	valid_1's rmse: 1.08755
# [147]	training's rmse: 0.992406	valid_1's rmse: 1.08849
# [148]	training's rmse: 0.991344	valid_1's rmse: 1.08787
# [149]	training's rmse: 0.990659	valid_1's rmse: 1.08756
# [150]	training's rmse: 0.989502	valid_1's rmse: 1.08701
# [151]	training's rmse: 0.988108	valid_1's rmse: 1.08591
# [152]	training's rmse: 0.986347	valid_1's rmse: 1.08459
# [153]	training's rmse: 0.984855	valid_1's rmse: 1.08375
# [154]	training's rmse: 0.984056	valid_1's rmse: 1.08318
# [155]	training's rmse: 0.983229	valid_1's rmse: 1.08264
# [156]	training's rmse: 0.982427	valid_1's rmse: 1.08233
# [157]	training's rmse: 0.981951	valid_1's rmse: 1.08194
# [158]	training's rmse: 0.98105	valid_1's rmse: 1.08108
# [159]	training's rmse: 0.979875	valid_1's rmse: 1.08092
# [160]	training's rmse: 0.979516	valid_1's rmse: 1.08057
# [161]	training's rmse: 0.979061	valid_1's rmse: 1.0804
# [162]	training's rmse: 0.978738	valid_1's rmse: 1.08033
# [163]	training's rmse: 0.977535	valid_1's rmse: 1.0795
# [164]	training's rmse: 0.977055	valid_1's rmse: 1.07912
# [165]	training's rmse: 0.976563	valid_1's rmse: 1.07879
# [166]	training's rmse: 0.976115	valid_1's rmse: 1.07836
# [167]	training's rmse: 0.975556	valid_1's rmse: 1.07814
# [168]	training's rmse: 0.974302	valid_1's rmse: 1.0774
# [169]	training's rmse: 0.97319	valid_1's rmse: 1.07668
# [170]	training's rmse: 0.972769	valid_1's rmse: 1.07638
# [171]	training's rmse: 0.972443	valid_1's rmse: 1.07568
# [172]	training's rmse: 0.971833	valid_1's rmse: 1.07535
# [173]	training's rmse: 0.971595	valid_1's rmse: 1.07554
# [174]	training's rmse: 0.970022	valid_1's rmse: 1.07448
# [175]	training's rmse: 0.969352	valid_1's rmse: 1.07449
# [176]	training's rmse: 0.96877	valid_1's rmse: 1.07408
# [177]	training's rmse: 0.968474	valid_1's rmse: 1.07375
# [178]	training's rmse: 0.967831	valid_1's rmse: 1.07332
# [179]	training's rmse: 0.96715	valid_1's rmse: 1.07279
# [180]	training's rmse: 0.966484	valid_1's rmse: 1.07275
# [181]	training's rmse: 0.965547	valid_1's rmse: 1.07214
# [182]	training's rmse: 0.964941	valid_1's rmse: 1.07148
# [183]	training's rmse: 0.964248	valid_1's rmse: 1.07151
# [184]	training's rmse: 0.963899	valid_1's rmse: 1.07151
# [185]	training's rmse: 0.963506	valid_1's rmse: 1.07108
# [186]	training's rmse: 0.962826	valid_1's rmse: 1.07091
# [187]	training's rmse: 0.96184	valid_1's rmse: 1.07035
# [188]	training's rmse: 0.961189	valid_1's rmse: 1.06981
# [189]	training's rmse: 0.960086	valid_1's rmse: 1.06909
# [190]	training's rmse: 0.959469	valid_1's rmse: 1.06862
# [191]	training's rmse: 0.959161	valid_1's rmse: 1.0684
# [192]	training's rmse: 0.958695	valid_1's rmse: 1.06853
# [193]	training's rmse: 0.958342	valid_1's rmse: 1.06819
# [194]	training's rmse: 0.957996	valid_1's rmse: 1.06782
# [195]	training's rmse: 0.95707	valid_1's rmse: 1.06711
# [196]	training's rmse: 0.956258	valid_1's rmse: 1.0664
# [197]	training's rmse: 0.955618	valid_1's rmse: 1.06583
# [198]	training's rmse: 0.955356	valid_1's rmse: 1.06649
# [199]	training's rmse: 0.95466	valid_1's rmse: 1.0662
# [200]	training's rmse: 0.954044	valid_1's rmse: 1.06588
# [201]	training's rmse: 0.953582	valid_1's rmse: 1.06521
# [202]	training's rmse: 0.953334	valid_1's rmse: 1.06491
# [203]	training's rmse: 0.952624	valid_1's rmse: 1.06442
# [204]	training's rmse: 0.952356	valid_1's rmse: 1.06406
# [205]	training's rmse: 0.951992	valid_1's rmse: 1.06392
# [206]	training's rmse: 0.951472	valid_1's rmse: 1.06338
# [207]	training's rmse: 0.950967	valid_1's rmse: 1.06265
# [208]	training's rmse: 0.950302	valid_1's rmse: 1.06212
# [209]	training's rmse: 0.950012	valid_1's rmse: 1.062
# [210]	training's rmse: 0.94973	valid_1's rmse: 1.06179
# [211]	training's rmse: 0.949303	valid_1's rmse: 1.06186
# [212]	training's rmse: 0.948924	valid_1's rmse: 1.06161
# [213]	training's rmse: 0.948464	valid_1's rmse: 1.06176
# [214]	training's rmse: 0.947121	valid_1's rmse: 1.06147
# [215]	training's rmse: 0.946803	valid_1's rmse: 1.06141
# [216]	training's rmse: 0.946505	valid_1's rmse: 1.06107
# [217]	training's rmse: 0.945964	valid_1's rmse: 1.06086
# [218]	training's rmse: 0.94549	valid_1's rmse: 1.06051
# [219]	training's rmse: 0.944822	valid_1's rmse: 1.06015
# [220]	training's rmse: 0.943525	valid_1's rmse: 1.05906
# [221]	training's rmse: 0.942987	valid_1's rmse: 1.05875
# [222]	training's rmse: 0.942462	valid_1's rmse: 1.05883
# [223]	training's rmse: 0.942	valid_1's rmse: 1.0585
# [224]	training's rmse: 0.941511	valid_1's rmse: 1.05823
# [225]	training's rmse: 0.940594	valid_1's rmse: 1.0573
# [226]	training's rmse: 0.94031	valid_1's rmse: 1.05708
# [227]	training's rmse: 0.939487	valid_1's rmse: 1.05627
# [228]	training's rmse: 0.938984	valid_1's rmse: 1.05586
# [229]	training's rmse: 0.938619	valid_1's rmse: 1.05552
# [230]	training's rmse: 0.938346	valid_1's rmse: 1.05604
# [231]	training's rmse: 0.938131	valid_1's rmse: 1.05595
# [232]	training's rmse: 0.937799	valid_1's rmse: 1.05547
# [233]	training's rmse: 0.937502	valid_1's rmse: 1.05558
# [234]	training's rmse: 0.93687	valid_1's rmse: 1.05534
# [235]	training's rmse: 0.935148	valid_1's rmse: 1.05489
# [236]	training's rmse: 0.933865	valid_1's rmse: 1.05508
# [237]	training's rmse: 0.932733	valid_1's rmse: 1.05453
# [238]	training's rmse: 0.932358	valid_1's rmse: 1.05422
# [239]	training's rmse: 0.931953	valid_1's rmse: 1.05399
# [240]	training's rmse: 0.931819	valid_1's rmse: 1.05328
# [241]	training's rmse: 0.930751	valid_1's rmse: 1.05241
# [242]	training's rmse: 0.929923	valid_1's rmse: 1.05277
# [243]	training's rmse: 0.929606	valid_1's rmse: 1.05252
# [244]	training's rmse: 0.929303	valid_1's rmse: 1.05238
# [245]	training's rmse: 0.928459	valid_1's rmse: 1.05173
# [246]	training's rmse: 0.928303	valid_1's rmse: 1.05148
# [247]	training's rmse: 0.92775	valid_1's rmse: 1.05109
# [248]	training's rmse: 0.927377	valid_1's rmse: 1.05097
# [249]	training's rmse: 0.926925	valid_1's rmse: 1.05065
# [250]	training's rmse: 0.926275	valid_1's rmse: 1.05022
# [251]	training's rmse: 0.92585	valid_1's rmse: 1.04973
# [252]	training's rmse: 0.924858	valid_1's rmse: 1.04914
# [253]	training's rmse: 0.924171	valid_1's rmse: 1.04859
# [254]	training's rmse: 0.923809	valid_1's rmse: 1.04826
# [255]	training's rmse: 0.923126	valid_1's rmse: 1.04795
# [256]	training's rmse: 0.922531	valid_1's rmse: 1.0476
# [257]	training's rmse: 0.92211	valid_1's rmse: 1.04728
# [258]	training's rmse: 0.92186	valid_1's rmse: 1.04705
# [259]	training's rmse: 0.921698	valid_1's rmse: 1.04698
# [260]	training's rmse: 0.92143	valid_1's rmse: 1.04679
# [261]	training's rmse: 0.921025	valid_1's rmse: 1.04667
# [262]	training's rmse: 0.920492	valid_1's rmse: 1.04641
# [263]	training's rmse: 0.920147	valid_1's rmse: 1.04622
# [264]	training's rmse: 0.919247	valid_1's rmse: 1.04566
# [265]	training's rmse: 0.918954	valid_1's rmse: 1.04508
# [266]	training's rmse: 0.918712	valid_1's rmse: 1.04475
# [267]	training's rmse: 0.918165	valid_1's rmse: 1.04432
# [268]	training's rmse: 0.917402	valid_1's rmse: 1.04374
# [269]	training's rmse: 0.916929	valid_1's rmse: 1.04415
# [270]	training's rmse: 0.916602	valid_1's rmse: 1.04387
# [271]	training's rmse: 0.915705	valid_1's rmse: 1.04335
# [272]	training's rmse: 0.915235	valid_1's rmse: 1.04296
# [273]	training's rmse: 0.914706	valid_1's rmse: 1.04266
# [274]	training's rmse: 0.914421	valid_1's rmse: 1.04225
# [275]	training's rmse: 0.914194	valid_1's rmse: 1.04212
# [276]	training's rmse: 0.913773	valid_1's rmse: 1.04158
# [277]	training's rmse: 0.9134	valid_1's rmse: 1.04154
# [278]	training's rmse: 0.913226	valid_1's rmse: 1.04177
# [279]	training's rmse: 0.913008	valid_1's rmse: 1.04162
# [280]	training's rmse: 0.912352	valid_1's rmse: 1.04139
# [281]	training's rmse: 0.911699	valid_1's rmse: 1.04111
# [282]	training's rmse: 0.91052	valid_1's rmse: 1.04033
# [283]	training's rmse: 0.910297	valid_1's rmse: 1.04012
# [284]	training's rmse: 0.910018	valid_1's rmse: 1.03976
# [285]	training's rmse: 0.909881	valid_1's rmse: 1.03978
# [286]	training's rmse: 0.909624	valid_1's rmse: 1.0394
# [287]	training's rmse: 0.908927	valid_1's rmse: 1.03876
# [288]	training's rmse: 0.908649	valid_1's rmse: 1.03851
# [289]	training's rmse: 0.908122	valid_1's rmse: 1.03818
# [290]	training's rmse: 0.907846	valid_1's rmse: 1.03795
# [291]	training's rmse: 0.907122	valid_1's rmse: 1.03767
# [292]	training's rmse: 0.90646	valid_1's rmse: 1.03726
# [293]	training's rmse: 0.906152	valid_1's rmse: 1.03711
# [294]	training's rmse: 0.905004	valid_1's rmse: 1.03628
# [295]	training's rmse: 0.904248	valid_1's rmse: 1.03578
# [296]	training's rmse: 0.903584	valid_1's rmse: 1.03544
# [297]	training's rmse: 0.903293	valid_1's rmse: 1.03549
# [298]	training's rmse: 0.902627	valid_1's rmse: 1.03517
# [299]	training's rmse: 0.901962	valid_1's rmse: 1.03499
# [300]	training's rmse: 0.901591	valid_1's rmse: 1.03485
# [301]	training's rmse: 0.901201	valid_1's rmse: 1.03483
# [302]	training's rmse: 0.899584	valid_1's rmse: 1.03347
# [303]	training's rmse: 0.898906	valid_1's rmse: 1.03292
# [304]	training's rmse: 0.898461	valid_1's rmse: 1.03253
# [305]	training's rmse: 0.897913	valid_1's rmse: 1.03212
# [306]	training's rmse: 0.897512	valid_1's rmse: 1.03177
# [307]	training's rmse: 0.897	valid_1's rmse: 1.03144
# [308]	training's rmse: 0.896463	valid_1's rmse: 1.03146
# [309]	training's rmse: 0.896134	valid_1's rmse: 1.03239
# [310]	training's rmse: 0.895544	valid_1's rmse: 1.03169
# [311]	training's rmse: 0.894876	valid_1's rmse: 1.03166
# [312]	training's rmse: 0.894552	valid_1's rmse: 1.03158
# [313]	training's rmse: 0.894072	valid_1's rmse: 1.03106
# [314]	training's rmse: 0.893349	valid_1's rmse: 1.03028
# [315]	training's rmse: 0.893011	valid_1's rmse: 1.03023
# [316]	training's rmse: 0.892646	valid_1's rmse: 1.02977
# [317]	training's rmse: 0.892215	valid_1's rmse: 1.02936
# [318]	training's rmse: 0.891917	valid_1's rmse: 1.02927
# [319]	training's rmse: 0.891658	valid_1's rmse: 1.0291
# [320]	training's rmse: 0.891315	valid_1's rmse: 1.02941
# [321]	training's rmse: 0.890931	valid_1's rmse: 1.02907
# [322]	training's rmse: 0.890752	valid_1's rmse: 1.02876
# [323]	training's rmse: 0.890491	valid_1's rmse: 1.02865
# [324]	training's rmse: 0.89027	valid_1's rmse: 1.02844
# [325]	training's rmse: 0.889818	valid_1's rmse: 1.02807
# [326]	training's rmse: 0.889449	valid_1's rmse: 1.02832
# [327]	training's rmse: 0.888896	valid_1's rmse: 1.02794
# [328]	training's rmse: 0.88868	valid_1's rmse: 1.02778
# [329]	training's rmse: 0.888536	valid_1's rmse: 1.03084
# [330]	training's rmse: 0.888141	valid_1's rmse: 1.03049
# [331]	training's rmse: 0.887976	valid_1's rmse: 1.03042
# [332]	training's rmse: 0.887111	valid_1's rmse: 1.03007
# [333]	training's rmse: 0.886865	valid_1's rmse: 1.02992
# [334]	training's rmse: 0.8866	valid_1's rmse: 1.02971
# [335]	training's rmse: 0.886236	valid_1's rmse: 1.02936
# [336]	training's rmse: 0.885942	valid_1's rmse: 1.0292
# [337]	training's rmse: 0.885336	valid_1's rmse: 1.02894
# [338]	training's rmse: 0.884982	valid_1's rmse: 1.02892
# [339]	training's rmse: 0.884534	valid_1's rmse: 1.02847
# [340]	training's rmse: 0.883994	valid_1's rmse: 1.02803
# [341]	training's rmse: 0.88388	valid_1's rmse: 1.02801
# [342]	training's rmse: 0.883578	valid_1's rmse: 1.02787
# [343]	training's rmse: 0.883394	valid_1's rmse: 1.02781
# [344]	training's rmse: 0.883034	valid_1's rmse: 1.02772
# [345]	training's rmse: 0.882886	valid_1's rmse: 1.02774
# [346]	training's rmse: 0.882565	valid_1's rmse: 1.0276
# [347]	training's rmse: 0.88202	valid_1's rmse: 1.02735
# [348]	training's rmse: 0.881557	valid_1's rmse: 1.02704
# [349]	training's rmse: 0.880851	valid_1's rmse: 1.02669
# [350]	training's rmse: 0.880623	valid_1's rmse: 1.02644
# [351]	training's rmse: 0.880497	valid_1's rmse: 1.02634
# [352]	training's rmse: 0.880237	valid_1's rmse: 1.0261
# [353]	training's rmse: 0.87992	valid_1's rmse: 1.02586
# [354]	training's rmse: 0.879476	valid_1's rmse: 1.02553
# [355]	training's rmse: 0.879185	valid_1's rmse: 1.02531
# [356]	training's rmse: 0.878926	valid_1's rmse: 1.0253
# [357]	training's rmse: 0.878656	valid_1's rmse: 1.02527
# [358]	training's rmse: 0.878517	valid_1's rmse: 1.02519
# [359]	training's rmse: 0.878176	valid_1's rmse: 1.02493
# [360]	training's rmse: 0.877857	valid_1's rmse: 1.02489
# [361]	training's rmse: 0.877493	valid_1's rmse: 1.0248
# [362]	training's rmse: 0.877358	valid_1's rmse: 1.02461
# [363]	training's rmse: 0.877037	valid_1's rmse: 1.02427
# [364]	training's rmse: 0.876737	valid_1's rmse: 1.02412
# [365]	training's rmse: 0.87664	valid_1's rmse: 1.02407
# [366]	training's rmse: 0.876163	valid_1's rmse: 1.02383
# [367]	training's rmse: 0.875975	valid_1's rmse: 1.02366
# [368]	training's rmse: 0.87551	valid_1's rmse: 1.02313
# [369]	training's rmse: 0.875317	valid_1's rmse: 1.02308
# [370]	training's rmse: 0.87489	valid_1's rmse: 1.02287
# [371]	training's rmse: 0.874625	valid_1's rmse: 1.02214
# [372]	training's rmse: 0.874397	valid_1's rmse: 1.02208
# [373]	training's rmse: 0.874132	valid_1's rmse: 1.02186
# [374]	training's rmse: 0.873913	valid_1's rmse: 1.02154
# [375]	training's rmse: 0.873787	valid_1's rmse: 1.02156
# [376]	training's rmse: 0.8732	valid_1's rmse: 1.02118
# [377]	training's rmse: 0.873139	valid_1's rmse: 1.02117
# [378]	training's rmse: 0.872654	valid_1's rmse: 1.02069
# [379]	training's rmse: 0.872214	valid_1's rmse: 1.02054
# [380]	training's rmse: 0.872037	valid_1's rmse: 1.02049
# [381]	training's rmse: 0.871909	valid_1's rmse: 1.02044
# [382]	training's rmse: 0.87165	valid_1's rmse: 1.02027
# [383]	training's rmse: 0.871176	valid_1's rmse: 1.01984
# [384]	training's rmse: 0.870947	valid_1's rmse: 1.01973
# [385]	training's rmse: 0.870817	valid_1's rmse: 1.01961
# [386]	training's rmse: 0.870638	valid_1's rmse: 1.01959
# [387]	training's rmse: 0.870456	valid_1's rmse: 1.01941
# [388]	training's rmse: 0.870343	valid_1's rmse: 1.01936
# [389]	training's rmse: 0.870175	valid_1's rmse: 1.01931
# [390]	training's rmse: 0.869995	valid_1's rmse: 1.01899
# [391]	training's rmse: 0.869535	valid_1's rmse: 1.01878
# [392]	training's rmse: 0.869463	valid_1's rmse: 1.01871
# [393]	training's rmse: 0.869066	valid_1's rmse: 1.01856
# [394]	training's rmse: 0.868913	valid_1's rmse: 1.01852
# [395]	training's rmse: 0.868562	valid_1's rmse: 1.01826
# [396]	training's rmse: 0.868341	valid_1's rmse: 1.01799
# [397]	training's rmse: 0.868161	valid_1's rmse: 1.01837
# [398]	training's rmse: 0.867911	valid_1's rmse: 1.01821
# [399]	training's rmse: 0.867543	valid_1's rmse: 1.01799
# [400]	training's rmse: 0.867246	valid_1's rmse: 1.01781
# [401]	training's rmse: 0.866752	valid_1's rmse: 1.01738
# [402]	training's rmse: 0.86635	valid_1's rmse: 1.01687
# [403]	training's rmse: 0.866133	valid_1's rmse: 1.0166
# [404]	training's rmse: 0.866026	valid_1's rmse: 1.01659
# [405]	training's rmse: 0.865877	valid_1's rmse: 1.01688
# [406]	training's rmse: 0.865743	valid_1's rmse: 1.01671
# [407]	training's rmse: 0.865599	valid_1's rmse: 1.01544
# [408]	training's rmse: 0.86546	valid_1's rmse: 1.01534
# [409]	training's rmse: 0.864972	valid_1's rmse: 1.01509
# [410]	training's rmse: 0.864675	valid_1's rmse: 1.015
# [411]	training's rmse: 0.864337	valid_1's rmse: 1.01536
# [412]	training's rmse: 0.864153	valid_1's rmse: 1.01547
# [413]	training's rmse: 0.863687	valid_1's rmse: 1.01528
# [414]	training's rmse: 0.863422	valid_1's rmse: 1.01521
# [415]	training's rmse: 0.863197	valid_1's rmse: 1.0151
# [416]	training's rmse: 0.862923	valid_1's rmse: 1.01449
# [417]	training's rmse: 0.862779	valid_1's rmse: 1.01429
# [418]	training's rmse: 0.862599	valid_1's rmse: 1.01394
# [419]	training's rmse: 0.86253	valid_1's rmse: 1.01391
# [420]	training's rmse: 0.862188	valid_1's rmse: 1.01371
# [421]	training's rmse: 0.861404	valid_1's rmse: 1.01289
# [422]	training's rmse: 0.860793	valid_1's rmse: 1.01244
# [423]	training's rmse: 0.860575	valid_1's rmse: 1.01231
# [424]	training's rmse: 0.860376	valid_1's rmse: 1.01204
# [425]	training's rmse: 0.860193	valid_1's rmse: 1.00982
# [426]	training's rmse: 0.860014	valid_1's rmse: 1.00982
# [427]	training's rmse: 0.859874	valid_1's rmse: 1.00971
# [428]	training's rmse: 0.859566	valid_1's rmse: 1.00938
# [429]	training's rmse: 0.859198	valid_1's rmse: 1.00889
# [430]	training's rmse: 0.859067	valid_1's rmse: 1.00923
# [431]	training's rmse: 0.858947	valid_1's rmse: 1.00913
# [432]	training's rmse: 0.858829	valid_1's rmse: 1.0091
# [433]	training's rmse: 0.858549	valid_1's rmse: 1.00901
# [434]	training's rmse: 0.857923	valid_1's rmse: 1.00959
# [435]	training's rmse: 0.857524	valid_1's rmse: 1.00901
# [436]	training's rmse: 0.857301	valid_1's rmse: 1.00905
# [437]	training's rmse: 0.857023	valid_1's rmse: 1.00864
# [438]	training's rmse: 0.856259	valid_1's rmse: 1.00798
# [439]	training's rmse: 0.856094	valid_1's rmse: 1.00797
# [440]	training's rmse: 0.85595	valid_1's rmse: 1.00734
# [441]	training's rmse: 0.855846	valid_1's rmse: 1.00878
# [442]	training's rmse: 0.85559	valid_1's rmse: 1.00851
# [443]	training's rmse: 0.855112	valid_1's rmse: 1.00817
# [444]	training's rmse: 0.854933	valid_1's rmse: 1.00822
# [445]	training's rmse: 0.854645	valid_1's rmse: 1.00793
# [446]	training's rmse: 0.854086	valid_1's rmse: 1.00778
# [447]	training's rmse: 0.853834	valid_1's rmse: 1.00768
# [448]	training's rmse: 0.853612	valid_1's rmse: 1.00745
# [449]	training's rmse: 0.853348	valid_1's rmse: 1.00732
# [450]	training's rmse: 0.853136	valid_1's rmse: 1.00738
# [451]	training's rmse: 0.852812	valid_1's rmse: 1.00702
# [452]	training's rmse: 0.852741	valid_1's rmse: 1.00704
# [453]	training's rmse: 0.852627	valid_1's rmse: 1.00697
# [454]	training's rmse: 0.851891	valid_1's rmse: 1.00635
# [455]	training's rmse: 0.851719	valid_1's rmse: 1.00629
# [456]	training's rmse: 0.851446	valid_1's rmse: 1.00622
# [457]	training's rmse: 0.851249	valid_1's rmse: 1.00606
# [458]	training's rmse: 0.851118	valid_1's rmse: 1.00606
# [459]	training's rmse: 0.850934	valid_1's rmse: 1.00601
# [460]	training's rmse: 0.850843	valid_1's rmse: 1.00598
# [461]	training's rmse: 0.850476	valid_1's rmse: 1.00579
# [462]	training's rmse: 0.850023	valid_1's rmse: 1.00545
# [463]	training's rmse: 0.849798	valid_1's rmse: 1.00536
# [464]	training's rmse: 0.849152	valid_1's rmse: 1.00505
# [465]	training's rmse: 0.84901	valid_1's rmse: 1.00488
# [466]	training's rmse: 0.848663	valid_1's rmse: 1.00465
# [467]	training's rmse: 0.848393	valid_1's rmse: 1.00484
# [468]	training's rmse: 0.848188	valid_1's rmse: 1.00484
# [469]	training's rmse: 0.847967	valid_1's rmse: 1.00489
# [470]	training's rmse: 0.84779	valid_1's rmse: 1.00478
# [471]	training's rmse: 0.847534	valid_1's rmse: 1.00496
# [472]	training's rmse: 0.847115	valid_1's rmse: 1.00515
# [473]	training's rmse: 0.847028	valid_1's rmse: 1.00511
# [474]	training's rmse: 0.84688	valid_1's rmse: 1.00502
# [475]	training's rmse: 0.846779	valid_1's rmse: 1.00503
# [476]	training's rmse: 0.846479	valid_1's rmse: 1.00484
# [477]	training's rmse: 0.846365	valid_1's rmse: 1.00469
# [478]	training's rmse: 0.846131	valid_1's rmse: 1.00449
# [479]	training's rmse: 0.845623	valid_1's rmse: 1.00443
# [480]	training's rmse: 0.845387	valid_1's rmse: 1.0042
# [481]	training's rmse: 0.845045	valid_1's rmse: 1.00385
# [482]	training's rmse: 0.84471	valid_1's rmse: 1.00367
# [483]	training's rmse: 0.844404	valid_1's rmse: 1.00299
# [484]	training's rmse: 0.844255	valid_1's rmse: 1.00286
# [485]	training's rmse: 0.844139	valid_1's rmse: 1.00279
# [486]	training's rmse: 0.843856	valid_1's rmse: 1.00378
# [487]	training's rmse: 0.843746	valid_1's rmse: 1.00617
# [488]	training's rmse: 0.843153	valid_1's rmse: 1.00591
# [489]	training's rmse: 0.842484	valid_1's rmse: 1.00567
# [490]	training's rmse: 0.842111	valid_1's rmse: 1.00564
# [491]	training's rmse: 0.841914	valid_1's rmse: 1.00554
# [492]	training's rmse: 0.841771	valid_1's rmse: 1.00528
# [493]	training's rmse: 0.841494	valid_1's rmse: 1.00514
# [494]	training's rmse: 0.841135	valid_1's rmse: 1.00502
# [495]	training's rmse: 0.840999	valid_1's rmse: 1.00488
# [496]	training's rmse: 0.840801	valid_1's rmse: 1.00482
# [497]	training's rmse: 0.840613	valid_1's rmse: 1.00476
# [498]	training's rmse: 0.840524	valid_1's rmse: 1.00468
# [499]	training's rmse: 0.840333	valid_1's rmse: 1.00446
# [500]	training's rmse: 0.83999	valid_1's rmse: 1.00436
# [501]	training's rmse: 0.83973	valid_1's rmse: 1.00412
# [502]	training's rmse: 0.839568	valid_1's rmse: 1.00398
# [503]	training's rmse: 0.83933	valid_1's rmse: 1.00388
# [504]	training's rmse: 0.838975	valid_1's rmse: 1.00359
# [505]	training's rmse: 0.838741	valid_1's rmse: 1.00343
# [506]	training's rmse: 0.838398	valid_1's rmse: 1.00317
# [507]	training's rmse: 0.838158	valid_1's rmse: 1.00299
# [508]	training's rmse: 0.837975	valid_1's rmse: 1.00287
# [509]	training's rmse: 0.837857	valid_1's rmse: 1.00307
# [510]	training's rmse: 0.837717	valid_1's rmse: 1.00291
# [511]	training's rmse: 0.837492	valid_1's rmse: 1.00275
# [512]	training's rmse: 0.837176	valid_1's rmse: 1.00264
# [513]	training's rmse: 0.837068	valid_1's rmse: 1.0026
# [514]	training's rmse: 0.836754	valid_1's rmse: 1.00385
# [515]	training's rmse: 0.836642	valid_1's rmse: 1.0038
# [516]	training's rmse: 0.83641	valid_1's rmse: 1.00355
# [517]	training's rmse: 0.835868	valid_1's rmse: 1.00316
# [518]	training's rmse: 0.835712	valid_1's rmse: 1.00314
# [519]	training's rmse: 0.835487	valid_1's rmse: 1.00307
# [520]	training's rmse: 0.835342	valid_1's rmse: 1.00296
# [521]	training's rmse: 0.835049	valid_1's rmse: 1.00277
# [522]	training's rmse: 0.834997	valid_1's rmse: 1.00278
# [523]	training's rmse: 0.834791	valid_1's rmse: 1.00259
# [524]	training's rmse: 0.834465	valid_1's rmse: 1.00225
# [525]	training's rmse: 0.83424	valid_1's rmse: 1.00211
# [526]	training's rmse: 0.833833	valid_1's rmse: 1.00168
# [527]	training's rmse: 0.833644	valid_1's rmse: 1.00136
# [528]	training's rmse: 0.833469	valid_1's rmse: 1.00138
# [529]	training's rmse: 0.83328	valid_1's rmse: 1.00123
# [530]	training's rmse: 0.832788	valid_1's rmse: 1.00093
# [531]	training's rmse: 0.832521	valid_1's rmse: 1.00066
# [532]	training's rmse: 0.832412	valid_1's rmse: 1.00062
# [533]	training's rmse: 0.832203	valid_1's rmse: 1.00051
# [534]	training's rmse: 0.831957	valid_1's rmse: 1.00049
# [535]	training's rmse: 0.831773	valid_1's rmse: 1.00039
# [536]	training's rmse: 0.831613	valid_1's rmse: 1.00023
# [537]	training's rmse: 0.831343	valid_1's rmse: 1.00019
# [538]	training's rmse: 0.831102	valid_1's rmse: 1.00006
# [539]	training's rmse: 0.830895	valid_1's rmse: 0.99996
# [540]	training's rmse: 0.830702	valid_1's rmse: 0.999759
# [541]	training's rmse: 0.830338	valid_1's rmse: 0.999478
# [542]	training's rmse: 0.830113	valid_1's rmse: 0.999413
# [543]	training's rmse: 0.830003	valid_1's rmse: 0.999347
# [544]	training's rmse: 0.829829	valid_1's rmse: 0.999123
# [545]	training's rmse: 0.82957	valid_1's rmse: 0.998968
# [546]	training's rmse: 0.829426	valid_1's rmse: 0.998937
# [547]	training's rmse: 0.829226	valid_1's rmse: 0.99895
# [548]	training's rmse: 0.828963	valid_1's rmse: 0.998877
# [549]	training's rmse: 0.828838	valid_1's rmse: 0.999093
# [550]	training's rmse: 0.8287	valid_1's rmse: 0.99903
# [551]	training's rmse: 0.828539	valid_1's rmse: 0.999263
# [552]	training's rmse: 0.828385	valid_1's rmse: 0.999248
# [553]	training's rmse: 0.828238	valid_1's rmse: 0.999168
# [554]	training's rmse: 0.827886	valid_1's rmse: 0.998886
# [555]	training's rmse: 0.827767	valid_1's rmse: 0.998837
# [556]	training's rmse: 0.827509	valid_1's rmse: 0.998645
# [557]	training's rmse: 0.827417	valid_1's rmse: 0.998539
# [558]	training's rmse: 0.827227	valid_1's rmse: 0.998429
# [559]	training's rmse: 0.826991	valid_1's rmse: 0.998569
# [560]	training's rmse: 0.826931	valid_1's rmse: 0.998575
# [561]	training's rmse: 0.826616	valid_1's rmse: 0.998161
# [562]	training's rmse: 0.82651	valid_1's rmse: 0.998099
# [563]	training's rmse: 0.826356	valid_1's rmse: 0.998054
# [564]	training's rmse: 0.82621	valid_1's rmse: 0.99793
# [565]	training's rmse: 0.825937	valid_1's rmse: 0.997824
# [566]	training's rmse: 0.82563	valid_1's rmse: 0.997666
# [567]	training's rmse: 0.825323	valid_1's rmse: 0.997515
# [568]	training's rmse: 0.825124	valid_1's rmse: 0.99745
# [569]	training's rmse: 0.825061	valid_1's rmse: 0.997342
# [570]	training's rmse: 0.824932	valid_1's rmse: 0.99741
# [571]	training's rmse: 0.824674	valid_1's rmse: 0.997072
# [572]	training's rmse: 0.824327	valid_1's rmse: 0.996809
# [573]	training's rmse: 0.824265	valid_1's rmse: 0.996687
# [574]	training's rmse: 0.824117	valid_1's rmse: 0.996578
# [575]	training's rmse: 0.824006	valid_1's rmse: 0.996584
# [576]	training's rmse: 0.823875	valid_1's rmse: 0.996661
# [577]	training's rmse: 0.823704	valid_1's rmse: 0.996568
# [578]	training's rmse: 0.823509	valid_1's rmse: 0.996566
# [579]	training's rmse: 0.823329	valid_1's rmse: 0.996542
# [580]	training's rmse: 0.823081	valid_1's rmse: 0.996681
# [581]	training's rmse: 0.822991	valid_1's rmse: 0.996993
# [582]	training's rmse: 0.822865	valid_1's rmse: 0.997245
# [583]	training's rmse: 0.82277	valid_1's rmse: 0.997225
# [584]	training's rmse: 0.822556	valid_1's rmse: 0.99716
# [585]	training's rmse: 0.822387	valid_1's rmse: 0.997121
# [586]	training's rmse: 0.822282	valid_1's rmse: 0.99685
# [587]	training's rmse: 0.822092	valid_1's rmse: 0.99679
# [588]	training's rmse: 0.821735	valid_1's rmse: 0.996661
# [589]	training's rmse: 0.821587	valid_1's rmse: 0.997337
# [590]	training's rmse: 0.821431	valid_1's rmse: 0.99718
# [591]	training's rmse: 0.821341	valid_1's rmse: 0.997275
# [592]	training's rmse: 0.821216	valid_1's rmse: 0.996983
# [593]	training's rmse: 0.821077	valid_1's rmse: 0.996462
# [594]	training's rmse: 0.820903	valid_1's rmse: 0.99635
# [595]	training's rmse: 0.820495	valid_1's rmse: 0.996085
# [596]	training's rmse: 0.820341	valid_1's rmse: 0.995941
# [597]	training's rmse: 0.820213	valid_1's rmse: 0.995915
# [598]	training's rmse: 0.819728	valid_1's rmse: 0.995797
# [599]	training's rmse: 0.819601	valid_1's rmse: 0.995749
# [600]	training's rmse: 0.819454	valid_1's rmse: 0.995671
# [601]	training's rmse: 0.819176	valid_1's rmse: 0.995393
# [602]	training's rmse: 0.81897	valid_1's rmse: 0.995329
# [603]	training's rmse: 0.818769	valid_1's rmse: 0.995143
# [604]	training's rmse: 0.818644	valid_1's rmse: 0.995031
# [605]	training's rmse: 0.818548	valid_1's rmse: 0.995042
# [606]	training's rmse: 0.81847	valid_1's rmse: 0.994878
# [607]	training's rmse: 0.81839	valid_1's rmse: 0.994801
# [608]	training's rmse: 0.818194	valid_1's rmse: 0.994632
# [609]	training's rmse: 0.817949	valid_1's rmse: 0.994363
# [610]	training's rmse: 0.817846	valid_1's rmse: 0.994412
# [611]	training's rmse: 0.817695	valid_1's rmse: 0.994416
# [612]	training's rmse: 0.817637	valid_1's rmse: 0.994319
# [613]	training's rmse: 0.81744	valid_1's rmse: 0.99434
# [614]	training's rmse: 0.817297	valid_1's rmse: 0.994323
# [615]	training's rmse: 0.816961	valid_1's rmse: 0.994188
# [616]	training's rmse: 0.816767	valid_1's rmse: 0.994108
# [617]	training's rmse: 0.816589	valid_1's rmse: 0.993938
# [618]	training's rmse: 0.816222	valid_1's rmse: 0.99358
# [619]	training's rmse: 0.816057	valid_1's rmse: 0.993457
# [620]	training's rmse: 0.815959	valid_1's rmse: 0.993408
# [621]	training's rmse: 0.815875	valid_1's rmse: 0.99367
# [622]	training's rmse: 0.815727	valid_1's rmse: 0.993553
# [623]	training's rmse: 0.815578	valid_1's rmse: 0.993402
# [624]	training's rmse: 0.815425	valid_1's rmse: 0.993227
# [625]	training's rmse: 0.815334	valid_1's rmse: 0.993196
# [626]	training's rmse: 0.815218	valid_1's rmse: 0.993029
# [627]	training's rmse: 0.814958	valid_1's rmse: 0.992743
# [628]	training's rmse: 0.814887	valid_1's rmse: 0.992676
# [629]	training's rmse: 0.814282	valid_1's rmse: 0.9923
# [630]	training's rmse: 0.814127	valid_1's rmse: 0.99227
# [631]	training's rmse: 0.813995	valid_1's rmse: 0.991976
# [632]	training's rmse: 0.813872	valid_1's rmse: 0.991929
# [633]	training's rmse: 0.813736	valid_1's rmse: 0.992137
# [634]	training's rmse: 0.813608	valid_1's rmse: 0.992089
# [635]	training's rmse: 0.813494	valid_1's rmse: 0.992018
# [636]	training's rmse: 0.81326	valid_1's rmse: 0.991707
# [637]	training's rmse: 0.813081	valid_1's rmse: 0.991514
# [638]	training's rmse: 0.812991	valid_1's rmse: 0.991465
# [639]	training's rmse: 0.81284	valid_1's rmse: 0.991422
# [640]	training's rmse: 0.81278	valid_1's rmse: 0.991472
# [641]	training's rmse: 0.812722	valid_1's rmse: 0.994269
# [642]	training's rmse: 0.812355	valid_1's rmse: 0.994119
# [643]	training's rmse: 0.812071	valid_1's rmse: 0.993953
# [644]	training's rmse: 0.81185	valid_1's rmse: 0.993736
# [645]	training's rmse: 0.811632	valid_1's rmse: 0.993566
# [646]	training's rmse: 0.81139	valid_1's rmse: 0.993389
# [647]	training's rmse: 0.811151	valid_1's rmse: 0.993232
# [648]	training's rmse: 0.810951	valid_1's rmse: 0.993063
# [649]	training's rmse: 0.81084	valid_1's rmse: 0.992927
# [650]	training's rmse: 0.810752	valid_1's rmse: 0.992963
# [651]	training's rmse: 0.810614	valid_1's rmse: 0.992966
# [652]	training's rmse: 0.810266	valid_1's rmse: 0.992609
# [653]	training's rmse: 0.810162	valid_1's rmse: 0.992564
# [654]	training's rmse: 0.810093	valid_1's rmse: 0.991995
# [655]	training's rmse: 0.809993	valid_1's rmse: 0.992102
# [656]	training's rmse: 0.809829	valid_1's rmse: 0.992252
# [657]	training's rmse: 0.809644	valid_1's rmse: 0.992138
# [658]	training's rmse: 0.809522	valid_1's rmse: 0.991845
# [659]	training's rmse: 0.809425	valid_1's rmse: 0.991786
# [660]	training's rmse: 0.809228	valid_1's rmse: 0.991605
# [661]	training's rmse: 0.809086	valid_1's rmse: 0.991631
# [662]	training's rmse: 0.808967	valid_1's rmse: 0.991589
# [663]	training's rmse: 0.80888	valid_1's rmse: 0.991621
# [664]	training's rmse: 0.808793	valid_1's rmse: 0.991853
# [665]	training's rmse: 0.808621	valid_1's rmse: 0.991863
# [666]	training's rmse: 0.808393	valid_1's rmse: 0.991804
# [667]	training's rmse: 0.80823	valid_1's rmse: 0.99177
# [668]	training's rmse: 0.808136	valid_1's rmse: 0.991411
# [669]	training's rmse: 0.80801	valid_1's rmse: 0.991313
# [670]	training's rmse: 0.807808	valid_1's rmse: 0.991285
# [671]	training's rmse: 0.80768	valid_1's rmse: 0.991172
# [672]	training's rmse: 0.807553	valid_1's rmse: 0.991142
# [673]	training's rmse: 0.807485	valid_1's rmse: 0.991124
# [674]	training's rmse: 0.807366	valid_1's rmse: 0.991042
# [675]	training's rmse: 0.807101	valid_1's rmse: 0.990996
# [676]	training's rmse: 0.806875	valid_1's rmse: 0.990809
# [677]	training's rmse: 0.806792	valid_1's rmse: 0.990781
# [678]	training's rmse: 0.806765	valid_1's rmse: 0.990768
# [679]	training's rmse: 0.806648	valid_1's rmse: 0.990661
# [680]	training's rmse: 0.806598	valid_1's rmse: 0.99069
# [681]	training's rmse: 0.806536	valid_1's rmse: 0.990923
# [682]	training's rmse: 0.806336	valid_1's rmse: 0.990816
# [683]	training's rmse: 0.806281	valid_1's rmse: 0.990818
# [684]	training's rmse: 0.805953	valid_1's rmse: 0.990583
# [685]	training's rmse: 0.805816	valid_1's rmse: 0.990692
# [686]	training's rmse: 0.805737	valid_1's rmse: 0.990673
# [687]	training's rmse: 0.805656	valid_1's rmse: 0.99069
# [688]	training's rmse: 0.805323	valid_1's rmse: 0.990341
# [689]	training's rmse: 0.805249	valid_1's rmse: 0.990303
# [690]	training's rmse: 0.805143	valid_1's rmse: 0.99026
# [691]	training's rmse: 0.80481	valid_1's rmse: 0.99017
# [692]	training's rmse: 0.804546	valid_1's rmse: 0.989937
# [693]	training's rmse: 0.804335	valid_1's rmse: 0.990023
# [694]	training's rmse: 0.804222	valid_1's rmse: 0.989947
# [695]	training's rmse: 0.804152	valid_1's rmse: 0.989915
# [696]	training's rmse: 0.803972	valid_1's rmse: 0.989927
# [697]	training's rmse: 0.803938	valid_1's rmse: 0.989931
# [698]	training's rmse: 0.803665	valid_1's rmse: 0.989776
# [699]	training's rmse: 0.80359	valid_1's rmse: 0.9897
# [700]	training's rmse: 0.803518	valid_1's rmse: 0.989653
# [701]	training's rmse: 0.803424	valid_1's rmse: 0.989635
# [702]	training's rmse: 0.803282	valid_1's rmse: 0.989567
# [703]	training's rmse: 0.803135	valid_1's rmse: 0.989589
# [704]	training's rmse: 0.802932	valid_1's rmse: 0.989528
# [705]	training's rmse: 0.802733	valid_1's rmse: 0.989407
# [706]	training's rmse: 0.802512	valid_1's rmse: 0.989135
# [707]	training's rmse: 0.802373	valid_1's rmse: 0.988954
# [708]	training's rmse: 0.802208	valid_1's rmse: 0.988926
# [709]	training's rmse: 0.802164	valid_1's rmse: 0.988893
# [710]	training's rmse: 0.80208	valid_1's rmse: 0.988879
# [711]	training's rmse: 0.801977	valid_1's rmse: 0.989066
# [712]	training's rmse: 0.80183	valid_1's rmse: 0.988982
# [713]	training's rmse: 0.80165	valid_1's rmse: 0.989193
# [714]	training's rmse: 0.801556	valid_1's rmse: 0.989152
# [715]	training's rmse: 0.801085	valid_1's rmse: 0.988741
# [716]	training's rmse: 0.800855	valid_1's rmse: 0.988613
# [717]	training's rmse: 0.800652	valid_1's rmse: 0.988394
# [718]	training's rmse: 0.800518	valid_1's rmse: 0.988324
# [719]	training's rmse: 0.800347	valid_1's rmse: 0.988257
# [720]	training's rmse: 0.800274	valid_1's rmse: 0.988268
# [721]	training's rmse: 0.800218	valid_1's rmse: 0.988369
# [722]	training's rmse: 0.800126	valid_1's rmse: 0.988341
# [723]	training's rmse: 0.800018	valid_1's rmse: 0.988329
# [724]	training's rmse: 0.799864	valid_1's rmse: 0.988239
# [725]	training's rmse: 0.799832	valid_1's rmse: 0.988278
# [726]	training's rmse: 0.799484	valid_1's rmse: 0.988001
# [727]	training's rmse: 0.799127	valid_1's rmse: 0.987712
# [728]	training's rmse: 0.798943	valid_1's rmse: 0.987685
# [729]	training's rmse: 0.798847	valid_1's rmse: 0.987544
# [730]	training's rmse: 0.798719	valid_1's rmse: 0.987548
# [731]	training's rmse: 0.798562	valid_1's rmse: 0.987371
# [732]	training's rmse: 0.798423	valid_1's rmse: 0.987197
# [733]	training's rmse: 0.798101	valid_1's rmse: 0.987061
# [734]	training's rmse: 0.797976	valid_1's rmse: 0.987056
# [735]	training's rmse: 0.797749	valid_1's rmse: 0.986842
# [736]	training's rmse: 0.797546	valid_1's rmse: 0.986819
# [737]	training's rmse: 0.797348	valid_1's rmse: 0.986873
# [738]	training's rmse: 0.797129	valid_1's rmse: 0.986827
# [739]	training's rmse: 0.796941	valid_1's rmse: 0.986809
# [740]	training's rmse: 0.796905	valid_1's rmse: 0.986814
# [741]	training's rmse: 0.796799	valid_1's rmse: 0.986748
# [742]	training's rmse: 0.79672	valid_1's rmse: 0.986739
# [743]	training's rmse: 0.796565	valid_1's rmse: 0.986637
# [744]	training's rmse: 0.796506	valid_1's rmse: 0.986682
# [745]	training's rmse: 0.796376	valid_1's rmse: 0.986473
# [746]	training's rmse: 0.796212	valid_1's rmse: 0.986541
# [747]	training's rmse: 0.796049	valid_1's rmse: 0.986475
# [748]	training's rmse: 0.795951	valid_1's rmse: 0.986456
# [749]	training's rmse: 0.795753	valid_1's rmse: 0.986264
# [750]	training's rmse: 0.795655	valid_1's rmse: 0.986252
# [751]	training's rmse: 0.795436	valid_1's rmse: 0.986109
# [752]	training's rmse: 0.795334	valid_1's rmse: 0.985952
# [753]	training's rmse: 0.795072	valid_1's rmse: 0.985763
# [754]	training's rmse: 0.794861	valid_1's rmse: 0.98561
# [755]	training's rmse: 0.794761	valid_1's rmse: 0.985535
# [756]	training's rmse: 0.79463	valid_1's rmse: 0.985349
# [757]	training's rmse: 0.794507	valid_1's rmse: 0.985251
# [758]	training's rmse: 0.79444	valid_1's rmse: 0.985286
# [759]	training's rmse: 0.794345	valid_1's rmse: 0.98525
# [760]	training's rmse: 0.794271	valid_1's rmse: 0.985417
# [761]	training's rmse: 0.793972	valid_1's rmse: 0.98533
# [762]	training's rmse: 0.793874	valid_1's rmse: 0.985296
# [763]	training's rmse: 0.793755	valid_1's rmse: 0.985258
# [764]	training's rmse: 0.793458	valid_1's rmse: 0.984875
# [765]	training's rmse: 0.793336	valid_1's rmse: 0.984935
# [766]	training's rmse: 0.79323	valid_1's rmse: 0.984897
# [767]	training's rmse: 0.793083	valid_1's rmse: 0.984814
# [768]	training's rmse: 0.792965	valid_1's rmse: 0.984792
# [769]	training's rmse: 0.792907	valid_1's rmse: 0.984773
# [770]	training's rmse: 0.79288	valid_1's rmse: 0.984781
# [771]	training's rmse: 0.792676	valid_1's rmse: 0.98473
# [772]	training's rmse: 0.792546	valid_1's rmse: 0.984816
# [773]	training's rmse: 0.792444	valid_1's rmse: 0.984738
# [774]	training's rmse: 0.792376	valid_1's rmse: 0.984939
# [775]	training's rmse: 0.792058	valid_1's rmse: 0.984883
# [776]	training's rmse: 0.791762	valid_1's rmse: 0.984517
# [777]	training's rmse: 0.791647	valid_1's rmse: 0.984428
# [778]	training's rmse: 0.791535	valid_1's rmse: 0.984356
# [779]	training's rmse: 0.79118	valid_1's rmse: 0.984078
# [780]	training's rmse: 0.790892	valid_1's rmse: 0.983811
# [781]	training's rmse: 0.790791	valid_1's rmse: 0.983715
# [782]	training's rmse: 0.790605	valid_1's rmse: 0.98363
# [783]	training's rmse: 0.790483	valid_1's rmse: 0.983608
# [784]	training's rmse: 0.790282	valid_1's rmse: 0.983614
# [785]	training's rmse: 0.79014	valid_1's rmse: 0.983429
# [786]	training's rmse: 0.789948	valid_1's rmse: 0.983542
# [787]	training's rmse: 0.789758	valid_1's rmse: 0.983591
# [788]	training's rmse: 0.789655	valid_1's rmse: 0.983672
# [789]	training's rmse: 0.78952	valid_1's rmse: 0.983645
# [790]	training's rmse: 0.789461	valid_1's rmse: 0.983666
# [791]	training's rmse: 0.78938	valid_1's rmse: 0.983513
# [792]	training's rmse: 0.789145	valid_1's rmse: 0.983299
# [793]	training's rmse: 0.789014	valid_1's rmse: 0.983206
# [794]	training's rmse: 0.788776	valid_1's rmse: 0.982943
# [795]	training's rmse: 0.788721	valid_1's rmse: 0.983103
# [796]	training's rmse: 0.788497	valid_1's rmse: 0.983006
# [797]	training's rmse: 0.78843	valid_1's rmse: 0.982993
# [798]	training's rmse: 0.788257	valid_1's rmse: 0.982831
# [799]	training's rmse: 0.788107	valid_1's rmse: 0.982781
# [800]	training's rmse: 0.787934	valid_1's rmse: 0.982677
# [801]	training's rmse: 0.787736	valid_1's rmse: 0.98193
# [802]	training's rmse: 0.787664	valid_1's rmse: 0.981922
# [803]	training's rmse: 0.787417	valid_1's rmse: 0.981918
# [804]	training's rmse: 0.787322	valid_1's rmse: 0.981914
# [805]	training's rmse: 0.787224	valid_1's rmse: 0.981925
# [806]	training's rmse: 0.78706	valid_1's rmse: 0.981676
# [807]	training's rmse: 0.786859	valid_1's rmse: 0.981537
# [808]	training's rmse: 0.786679	valid_1's rmse: 0.981487
# [809]	training's rmse: 0.786608	valid_1's rmse: 0.981466
# [810]	training's rmse: 0.786388	valid_1's rmse: 0.981207
# [811]	training's rmse: 0.786295	valid_1's rmse: 0.981374
# [812]	training's rmse: 0.786231	valid_1's rmse: 0.981359
# [813]	training's rmse: 0.786048	valid_1's rmse: 0.981394
# [814]	training's rmse: 0.785964	valid_1's rmse: 0.981343
# [815]	training's rmse: 0.785798	valid_1's rmse: 0.981204
# [816]	training's rmse: 0.785635	valid_1's rmse: 0.981191
# [817]	training's rmse: 0.785576	valid_1's rmse: 0.981256
# [818]	training's rmse: 0.785488	valid_1's rmse: 0.981146
# [819]	training's rmse: 0.785079	valid_1's rmse: 0.980843
# [820]	training's rmse: 0.784959	valid_1's rmse: 0.98077
# [821]	training's rmse: 0.784919	valid_1's rmse: 0.98065
# [822]	training's rmse: 0.784759	valid_1's rmse: 0.980396
# [823]	training's rmse: 0.784485	valid_1's rmse: 0.980195
# [824]	training's rmse: 0.784402	valid_1's rmse: 0.980064
# [825]	training's rmse: 0.784273	valid_1's rmse: 0.980051
# [826]	training's rmse: 0.784151	valid_1's rmse: 0.979942
# [827]	training's rmse: 0.784048	valid_1's rmse: 0.979592
# [828]	training's rmse: 0.783789	valid_1's rmse: 0.979624
# [829]	training's rmse: 0.783693	valid_1's rmse: 0.97954
# [830]	training's rmse: 0.783454	valid_1's rmse: 0.979376
# [831]	training's rmse: 0.783345	valid_1's rmse: 0.979372
# [832]	training's rmse: 0.783268	valid_1's rmse: 0.979397
# [833]	training's rmse: 0.783131	valid_1's rmse: 0.97932
# [834]	training's rmse: 0.782996	valid_1's rmse: 0.979262
# [835]	training's rmse: 0.782899	valid_1's rmse: 0.979315
# [836]	training's rmse: 0.782788	valid_1's rmse: 0.979142
# [837]	training's rmse: 0.782735	valid_1's rmse: 0.979128
# [838]	training's rmse: 0.782695	valid_1's rmse: 0.97923
# [839]	training's rmse: 0.782605	valid_1's rmse: 0.979155
# [840]	training's rmse: 0.782511	valid_1's rmse: 0.979143
# [841]	training's rmse: 0.78235	valid_1's rmse: 0.979115
# [842]	training's rmse: 0.782185	valid_1's rmse: 0.978964
# [843]	training's rmse: 0.782122	valid_1's rmse: 0.978953
# [844]	training's rmse: 0.782051	valid_1's rmse: 0.978925
# [845]	training's rmse: 0.781884	valid_1's rmse: 0.978884
# [846]	training's rmse: 0.781624	valid_1's rmse: 0.978579
# [847]	training's rmse: 0.781514	valid_1's rmse: 0.978784
# [848]	training's rmse: 0.781488	valid_1's rmse: 0.978746
# [849]	training's rmse: 0.781411	valid_1's rmse: 0.978604
# [850]	training's rmse: 0.781294	valid_1's rmse: 0.978501
# [851]	training's rmse: 0.781087	valid_1's rmse: 0.978536
# [852]	training's rmse: 0.78102	valid_1's rmse: 0.978538
# [853]	training's rmse: 0.780975	valid_1's rmse: 0.978531
# [854]	training's rmse: 0.780876	valid_1's rmse: 0.978265
# [855]	training's rmse: 0.780777	valid_1's rmse: 0.978159
# [856]	training's rmse: 0.780733	valid_1's rmse: 0.978359
# [857]	training's rmse: 0.780586	valid_1's rmse: 0.978337
# [858]	training's rmse: 0.780441	valid_1's rmse: 0.97831
# [859]	training's rmse: 0.780374	valid_1's rmse: 0.978348
# [860]	training's rmse: 0.780299	valid_1's rmse: 0.978214
# [861]	training's rmse: 0.7801	valid_1's rmse: 0.978045
# [862]	training's rmse: 0.780062	valid_1's rmse: 0.97807
# [863]	training's rmse: 0.779975	valid_1's rmse: 0.978019
# [864]	training's rmse: 0.779791	valid_1's rmse: 0.977919
# [865]	training's rmse: 0.779681	valid_1's rmse: 0.977849
# [866]	training's rmse: 0.779518	valid_1's rmse: 0.977853
# [867]	training's rmse: 0.779465	valid_1's rmse: 0.977884
# [868]	training's rmse: 0.779344	valid_1's rmse: 0.977736
# [869]	training's rmse: 0.779305	valid_1's rmse: 0.977741
# [870]	training's rmse: 0.779237	valid_1's rmse: 0.977748
# [871]	training's rmse: 0.779136	valid_1's rmse: 0.977623
# [872]	training's rmse: 0.779047	valid_1's rmse: 0.976912
# [873]	training's rmse: 0.778946	valid_1's rmse: 0.976868
# [874]	training's rmse: 0.778872	valid_1's rmse: 0.976861
# [875]	training's rmse: 0.778777	valid_1's rmse: 0.97681
# [876]	training's rmse: 0.778635	valid_1's rmse: 0.976891
# [877]	training's rmse: 0.778536	valid_1's rmse: 0.97684
# [878]	training's rmse: 0.778427	valid_1's rmse: 0.976672
# [879]	training's rmse: 0.778388	valid_1's rmse: 0.976674
# [880]	training's rmse: 0.778342	valid_1's rmse: 0.976177
# [881]	training's rmse: 0.778245	valid_1's rmse: 0.976766
# [882]	training's rmse: 0.778195	valid_1's rmse: 0.976719
# [883]	training's rmse: 0.778025	valid_1's rmse: 0.976545
# [884]	training's rmse: 0.777874	valid_1's rmse: 0.976503
# [885]	training's rmse: 0.777841	valid_1's rmse: 0.976429
# [886]	training's rmse: 0.777756	valid_1's rmse: 0.976455
# [887]	training's rmse: 0.777666	valid_1's rmse: 0.976456
# [888]	training's rmse: 0.777576	valid_1's rmse: 0.976406
# [889]	training's rmse: 0.777434	valid_1's rmse: 0.976351
# [890]	training's rmse: 0.777262	valid_1's rmse: 0.976322
# [891]	training's rmse: 0.77715	valid_1's rmse: 0.97619
# [892]	training's rmse: 0.776906	valid_1's rmse: 0.975902
# [893]	training's rmse: 0.776751	valid_1's rmse: 0.975873
# [894]	training's rmse: 0.776488	valid_1's rmse: 0.97574
# [895]	training's rmse: 0.776329	valid_1's rmse: 0.975785
# [896]	training's rmse: 0.776286	valid_1's rmse: 0.975935
# [897]	training's rmse: 0.776234	valid_1's rmse: 0.975936
# [898]	training's rmse: 0.776136	valid_1's rmse: 0.975956
# [899]	training's rmse: 0.776028	valid_1's rmse: 0.975891
# [900]	training's rmse: 0.775884	valid_1's rmse: 0.975908
# [901]	training's rmse: 0.775835	valid_1's rmse: 0.975927
# [902]	training's rmse: 0.775599	valid_1's rmse: 0.975813
# [903]	training's rmse: 0.775548	valid_1's rmse: 0.975768
# [904]	training's rmse: 0.775473	valid_1's rmse: 0.975607
# [905]	training's rmse: 0.775378	valid_1's rmse: 0.975609
# [906]	training's rmse: 0.775219	valid_1's rmse: 0.975545
# [907]	training's rmse: 0.774999	valid_1's rmse: 0.97542
# [908]	training's rmse: 0.774868	valid_1's rmse: 0.975287
# [909]	training's rmse: 0.774669	valid_1's rmse: 0.97522
# [910]	training's rmse: 0.774346	valid_1's rmse: 0.975047
# [911]	training's rmse: 0.774261	valid_1's rmse: 0.975035
# [912]	training's rmse: 0.774218	valid_1's rmse: 0.97508
# [913]	training's rmse: 0.774122	valid_1's rmse: 0.975026
# [914]	training's rmse: 0.773979	valid_1's rmse: 0.974939
# [915]	training's rmse: 0.773768	valid_1's rmse: 0.974901
# [916]	training's rmse: 0.77367	valid_1's rmse: 0.975027
# [917]	training's rmse: 0.77354	valid_1's rmse: 0.974953
# [918]	training's rmse: 0.773415	valid_1's rmse: 0.974889
# [919]	training's rmse: 0.773352	valid_1's rmse: 0.974901
# [920]	training's rmse: 0.773294	valid_1's rmse: 0.974896
# [921]	training's rmse: 0.773235	valid_1's rmse: 0.974892
# [922]	training's rmse: 0.773177	valid_1's rmse: 0.97485
# [923]	training's rmse: 0.772894	valid_1's rmse: 0.974667
# [924]	training's rmse: 0.772786	valid_1's rmse: 0.97464
# [925]	training's rmse: 0.772742	valid_1's rmse: 0.974949
# [926]	training's rmse: 0.772646	valid_1's rmse: 0.974745
# [927]	training's rmse: 0.772582	valid_1's rmse: 0.974805
# [928]	training's rmse: 0.772494	valid_1's rmse: 0.97477
# [929]	training's rmse: 0.772265	valid_1's rmse: 0.974814
# [930]	training's rmse: 0.772141	valid_1's rmse: 0.97472
# [931]	training's rmse: 0.771976	valid_1's rmse: 0.974735
# [932]	training's rmse: 0.771922	valid_1's rmse: 0.974817
# [933]	training's rmse: 0.771857	valid_1's rmse: 0.974832
# [934]	training's rmse: 0.771779	valid_1's rmse: 0.974852
# [935]	training's rmse: 0.771638	valid_1's rmse: 0.974375
# [936]	training's rmse: 0.771568	valid_1's rmse: 0.974424
# [937]	training's rmse: 0.771445	valid_1's rmse: 0.97429
# [938]	training's rmse: 0.771348	valid_1's rmse: 0.974325
# [939]	training's rmse: 0.771141	valid_1's rmse: 0.974257
# [940]	training's rmse: 0.77096	valid_1's rmse: 0.974056
# [941]	training's rmse: 0.770864	valid_1's rmse: 0.974199
# [942]	training's rmse: 0.770554	valid_1's rmse: 0.973982
# [943]	training's rmse: 0.770478	valid_1's rmse: 0.974112
# [944]	training's rmse: 0.770398	valid_1's rmse: 0.974014
# [945]	training's rmse: 0.770274	valid_1's rmse: 0.973871
# [946]	training's rmse: 0.770198	valid_1's rmse: 0.973209
# [947]	training's rmse: 0.770136	valid_1's rmse: 0.973155
# [948]	training's rmse: 0.769865	valid_1's rmse: 0.973089
# [949]	training's rmse: 0.769724	valid_1's rmse: 0.972956
# [950]	training's rmse: 0.769585	valid_1's rmse: 0.972873
# [951]	training's rmse: 0.769494	valid_1's rmse: 0.972758
# [952]	training's rmse: 0.769429	valid_1's rmse: 0.972784
# [953]	training's rmse: 0.769375	valid_1's rmse: 0.972788
# [954]	training's rmse: 0.7693	valid_1's rmse: 0.972836
# [955]	training's rmse: 0.769217	valid_1's rmse: 0.972808
# [956]	training's rmse: 0.769077	valid_1's rmse: 0.972747
# [957]	training's rmse: 0.76898	valid_1's rmse: 0.973135
# [958]	training's rmse: 0.768874	valid_1's rmse: 0.973006
# [959]	training's rmse: 0.768789	valid_1's rmse: 0.972961
# [960]	training's rmse: 0.768744	valid_1's rmse: 0.972911
# [961]	training's rmse: 0.768555	valid_1's rmse: 0.972821
# [962]	training's rmse: 0.768435	valid_1's rmse: 0.972652
# [963]	training's rmse: 0.768274	valid_1's rmse: 0.972534
# [964]	training's rmse: 0.768107	valid_1's rmse: 0.972401
# [965]	training's rmse: 0.767829	valid_1's rmse: 0.972192
# [966]	training's rmse: 0.767638	valid_1's rmse: 0.972464
# [967]	training's rmse: 0.767515	valid_1's rmse: 0.972473
# [968]	training's rmse: 0.767442	valid_1's rmse: 0.972315
# [969]	training's rmse: 0.767337	valid_1's rmse: 0.972248
# [970]	training's rmse: 0.767261	valid_1's rmse: 0.972149
# [971]	training's rmse: 0.767132	valid_1's rmse: 0.971857
# [972]	training's rmse: 0.766902	valid_1's rmse: 0.971679
# [973]	training's rmse: 0.766779	valid_1's rmse: 0.971634
# [974]	training's rmse: 0.766717	valid_1's rmse: 0.971613
# [975]	training's rmse: 0.766633	valid_1's rmse: 0.971674
# [976]	training's rmse: 0.766566	valid_1's rmse: 0.971564
# [977]	training's rmse: 0.766488	valid_1's rmse: 0.97157
# [978]	training's rmse: 0.76641	valid_1's rmse: 0.971511
# [979]	training's rmse: 0.766277	valid_1's rmse: 0.971643
# [980]	training's rmse: 0.766236	valid_1's rmse: 0.971956
# [981]	training's rmse: 0.766184	valid_1's rmse: 0.97194
# [982]	training's rmse: 0.766143	valid_1's rmse: 0.971921
# [983]	training's rmse: 0.766044	valid_1's rmse: 0.971873
# [984]	training's rmse: 0.765835	valid_1's rmse: 0.971665
# [985]	training's rmse: 0.765773	valid_1's rmse: 0.971527
# [986]	training's rmse: 0.765606	valid_1's rmse: 0.971563
# [987]	training's rmse: 0.765498	valid_1's rmse: 0.971482
# [988]	training's rmse: 0.76543	valid_1's rmse: 0.971407
# [989]	training's rmse: 0.765267	valid_1's rmse: 0.971389
# [990]	training's rmse: 0.765142	valid_1's rmse: 0.971339
# [991]	training's rmse: 0.765077	valid_1's rmse: 0.97135
# [992]	training's rmse: 0.765018	valid_1's rmse: 0.971444
# [993]	training's rmse: 0.764752	valid_1's rmse: 0.971462
# [994]	training's rmse: 0.764716	valid_1's rmse: 0.971387
# [995]	training's rmse: 0.764625	valid_1's rmse: 0.971134
# [996]	training's rmse: 0.764499	valid_1's rmse: 0.970957
# [997]	training's rmse: 0.764465	valid_1's rmse: 0.970979
# [998]	training's rmse: 0.764399	valid_1's rmse: 0.971185
# [999]	training's rmse: 0.764159	valid_1's rmse: 0.970923
# [1000]	training's rmse: 0.763975	valid_1's rmse: 0.970834
# Did not meet early stopping. Best iteration is:
# [1000]	training's rmse: 0.763975	valid_1's rmse: 0.970834

# %%
import matplotlib as mlt
import matplotlib.pyplot as plt
# %matplotlib inline

lgb.plot_metric(evals_result, figsize=(12, 5))

# %%
pred = model.predict(temp)
pred = np.expm1(pred)
temp['AMT'] = np.round(pred, 0)
temp['REG_YYMM'] = temp['year']*100 + temp['month']
temp = temp[['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT']]
temp = temp.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM']).sum().reset_index(drop=False)

# %%
# 디코딩 (Random Forest)
temp['CARD_SIDO_NM'] = encoders['CARD_SIDO_NM'].inverse_transform(temp['CARD_SIDO_NM'])
temp['STD_CLSS_NM'] = encoders['STD_CLSS_NM'].inverse_transform(temp['STD_CLSS_NM'])

# %%
# 제출 파일 만들기(Random Forest)
submission = pd.read_csv('../../Data/Jeju/submission.csv', index_col=0)
submission = submission.drop(['AMT'], axis=1)
submission = submission.merge(temp, left_on=['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM'], right_on=['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM'], how='left')
submission.index.name = 'id'
compare_pred = submission.dropna()
submission = submission.fillna(0)
submission.head()
# Out:
#     REG_YYMM CARD_SIDO_NM           STD_CLSS_NM           AMT
# id
# 0     202004           강원            건강보조식품 소매업  7.063329e+07
# 1     202004           강원               골프장 운영업  6.971827e+09
# 2     202004           강원           과실 및 채소 소매업  1.464486e+09
# 3     202004           강원     관광 민예품 및 선물용품 소매업  1.517039e+07
# 4     202004           강원  그외 기타 분류안된 오락관련 서비스업  0.000000e+00

# %% [markdown]
# ### Score

# %%
compare_pred_4 = compare_pred[compare_pred['REG_YYMM']==202004]
compare_real = data2.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM'], as_index=False)[['AMT']].sum()

# %%
from sklearn.metrics import mean_squared_log_error

(mean_squared_log_error(compare_pred_4.AMT, compare_real.AMT))**0.5
# Out:
# 0.491668432019557

# %%
submission.to_csv('submission/submission lgbm 0728 valid Jan.csv', encoding='utf-8-sig')
