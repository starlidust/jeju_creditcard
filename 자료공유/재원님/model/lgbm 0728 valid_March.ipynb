# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data

# %%
data1 = pd.read_csv('../../Data/Jeju/201901-202003.csv')
data1 = data1.fillna('')
data2 = pd.read_csv('../../Data/Jeju/202004.csv')
data2 = data2.fillna('')

# %%
data = pd.concat([data1, data2])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26048114 entries, 0 to 1350321
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   REG_YYMM      int64
#  1   CARD_SIDO_NM  object
#  2   CARD_CCG_NM   object
#  3   STD_CLSS_NM   object
#  4   HOM_SIDO_NM   object
#  5   HOM_CCG_NM    object
#  6   AGE           object
#  7   SEX_CTGO_CD   int64
#  8   FLC           int64
#  9   CSTMR_CNT     int64
#  10  AMT           int64
#  11  CNT           int64
# dtypes: int64(6), object(6)
# memory usage: 2.5+ GB

# %% [markdown]
# #### 결측 처리

# %%
data.loc[data.CARD_CCG_NM.isna(),'CARD_CCG_NM'] = '세종'
data.loc[data.HOM_CCG_NM.isna(),'HOM_CCG_NM'] = '세종'

# %% [markdown]
# #### 18 사업체총조사

# %%
all_jobs_df = pd.read_csv('data/18 사업체총조사_키워드매칭.csv',encoding = 'cp949')
all_jobs_df = all_jobs_df[['행정구역별','데이터업종명','사업체수 (개)', '종사자수 (명)']]
all_jobs_df.columns = ['CARD_SIDO_NM','STD_CLSS_NM', 'company','employee']
all_jobs_df.employee = all_jobs_df.employee.apply(lambda x : x.replace("X","0")).astype(int)
all_jobs_df = all_jobs_df.groupby(['CARD_SIDO_NM','STD_CLSS_NM'])[['company','employee']].sum().reset_index()

all_jobs_df = all_jobs_df[~(all_jobs_df.CARD_SIDO_NM == '전국')]

# %% [markdown]
# #### 지역내 각 업종이 차지하는 매출비중

# %%
def local_percent(data):
    pivoted = data.pivot_table(index = ['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM'],columns ='REG_YYMM',values= "AMT",aggfunc='sum').reset_index()
    pivoted.fillna(0,inplace= True)

    #각 지역별(시군구)업종의 매출비율을 저장
    sidos = pivoted.CARD_SIDO_NM.unique()

    local_percent_df = pd.DataFrame()
    for sido in sidos:
        sample_sido = pivoted[pivoted.CARD_SIDO_NM == sido]
        sigungus = sample_sido.CARD_CCG_NM.unique()
        for sigungu in sigungus:
            sample = sample_sido[sample_sido.CARD_CCG_NM == sigungu]
            sum_arr = sample.iloc[:,3:].sum().values.reshape(1,-1)
            parcent_df = (sample.iloc[:,3:]/sum_arr)*100

            fin = pd.concat([sample.iloc[:,:3],parcent_df],axis=1)
            local_percent_df = pd.concat([local_percent_df,fin])

    #신규변수 LP(local percent) : 지역내 각 업종이 차지하는 매출비중
    local_percent_df = local_percent_df.melt(id_vars=['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM'],value_name='LP')
    return local_percent_df

# %% [markdown]
# #### 전체업종에서 각 지역업종이 차지하는 매출비중

# %%
def job_percent(data):
    pivoted = data.pivot_table(index = ['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM'],columns ='REG_YYMM',values= "AMT",aggfunc='sum').reset_index()
    pivoted.fillna(0,inplace= True)

    all_pivoted = data.pivot_table(index = ['STD_CLSS_NM'],columns ='REG_YYMM',values= "AMT",aggfunc= 'sum').reset_index()
    all_pivoted.fillna(0,inplace= True)
    all_pivoted = all_pivoted.set_index('STD_CLSS_NM')

    job_percent_df = pd.DataFrame()
    for job in all_pivoted.index:
        taget_df = pivoted[pivoted.STD_CLSS_NM == job]
        tail = (taget_df.iloc[:,3:]/all_pivoted.iloc[0].values)*100
        head = taget_df.iloc[:,:3]
        full = pd.concat([head,tail],axis =1)
        job_percent_df = pd.concat([job_percent_df,full])

    #신규변수 JP(Job percent): 전체업종에서 해당지역의 업종이 차이하는 비율
    job_percent_df = job_percent_df.melt(id_vars=['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM'],value_name='JP')
    return job_percent_df

# %%
local_percent_df = local_percent(data)
job_percent_df = job_percent(data)

# %% [markdown]
# #### 거래횟수와 이용고객과의 관계 (2019)

# %%
def cust_differ(data):
    data['differ'] = (data.CNT- data.CSTMR_CNT)
    
    #양수(단골)
    plus_custom = data[data['differ']>0]
    pivot_plus = plus_custom.pivot_table(index = ['CARD_SIDO_NM','STD_CLSS_NM'],columns = 'REG_YYMM', values= 'differ', aggfunc ='sum').reset_index()
    
    melt_plus = pivot_plus.melt(id_vars=['CARD_SIDO_NM','STD_CLSS_NM'],value_name='loyal')
    melt_plus['year'] = melt_plus['REG_YYMM'].apply(lambda x: int(str(x)[:4]))
    melt_plus['month'] = melt_plus['REG_YYMM'].apply(lambda x: int(str(x)[5:]))
    
    #2019만 사용
    melt_plus = melt_plus[melt_plus.year == 2019]
    melt_plus.drop(['year'],axis= 1,inplace = True)
    
    #음수(환불)
    minus_custom = data[data['differ']<0]
    pivot_minus = minus_custom.pivot_table(index = ['CARD_SIDO_NM','STD_CLSS_NM'],columns = 'REG_YYMM', values= 'differ', aggfunc ='sum').reset_index()
    
    melt_minus = pivot_minus.melt(id_vars=['CARD_SIDO_NM','STD_CLSS_NM'],value_name='refund')
    melt_minus['year'] = melt_minus['REG_YYMM'].apply(lambda x: int(str(x)[:4]))
    melt_minus['month'] = melt_minus['REG_YYMM'].apply(lambda x: int(str(x)[5:]))
    #2019만 사용
    melt_minus = melt_minus[melt_minus.year == 2019]
    melt_minus.drop(['year'],axis= 1,inplace = True)
    
  
    #둘 결헙
    cust_differ_df = pd.merge(melt_plus,melt_minus,how= 'outer')
    
    return cust_differ_df

# %%
trade_num_2019 = cust_differ(data)

# %% [markdown]
# #### 거래횟수와 이용고객과의 관계 (2020)

# %%
def cust_differ_2020(data):
    data['differ'] = (data.CNT- data.CSTMR_CNT)
    
    #양수(단골)
    plus_custom = data[data['differ']>0]
    pivot_plus = plus_custom.pivot_table(index = ['CARD_SIDO_NM','STD_CLSS_NM'],columns = 'REG_YYMM', values= 'differ', aggfunc ='sum').reset_index()
    
    melt_plus = pivot_plus.melt(id_vars=['CARD_SIDO_NM','STD_CLSS_NM'],value_name='loyal')
    melt_plus['year'] = melt_plus['REG_YYMM'].apply(lambda x: int(str(x)[:4]))
    melt_plus['month'] = melt_plus['REG_YYMM'].apply(lambda x: int(str(x)[5:]))
    
    #2020만 사용
    melt_plus = melt_plus[melt_plus.year == 2020]
    melt_plus.drop(['year'],axis= 1,inplace = True)
    
    #음수(환불)
    minus_custom = data[data['differ']<0]
    pivot_minus = minus_custom.pivot_table(index = ['CARD_SIDO_NM','STD_CLSS_NM'],columns = 'REG_YYMM', values= 'differ', aggfunc ='sum').reset_index()
    
    melt_minus = pivot_minus.melt(id_vars=['CARD_SIDO_NM','STD_CLSS_NM'],value_name='refund')
    melt_minus['year'] = melt_minus['REG_YYMM'].apply(lambda x: int(str(x)[:4]))
    melt_minus['month'] = melt_minus['REG_YYMM'].apply(lambda x: int(str(x)[5:]))
    #2020만 사용
    melt_minus = melt_minus[melt_minus.year == 2020]
    melt_minus.drop(['year'],axis= 1,inplace = True)
    
  
    #둘 결헙
    cust_differ_df = pd.merge(melt_plus,melt_minus,how= 'outer')
    
    return cust_differ_df

# %%
trade_num_2020 = cust_differ_2020(data)

# %%
trade_num = pd.concat([trade_num_2019, trade_num_2020])

# %%
trade_num.loyal = trade_num.loyal.fillna(-999)
trade_num.refund = trade_num.refund.fillna(999)

# %%
trade_num
# Out:
#      CARD_SIDO_NM           STD_CLSS_NM  REG_YYMM    loyal  month  refund
# 0              강원            건강보조식품 소매업  201901.0     80.0      1   -32.0
# 1              강원               골프장 운영업  201901.0  14890.0      1   999.0
# 2              강원           과실 및 채소 소매업  201901.0   7484.0      1   999.0
# 3              강원     관광 민예품 및 선물용품 소매업  201901.0    195.0      1   999.0
# 4              강원  그외 기타 분류안된 오락관련 서비스업  201901.0   -999.0      1   999.0
# ...           ...                   ...       ...      ...    ...     ...
# 2575           충북              휴양콘도 운영업  202004.0     62.0      4   999.0
# 2576           대전                  여행사업  202001.0   -999.0      1   999.0
# 2577           대전                  여행사업  202002.0   -999.0      2   999.0
# 2578           대전                  여행사업  202003.0   -999.0      3   999.0
# 2579           대전                  여행사업  202004.0   -999.0      4   999.0
#
# [10320 rows x 6 columns]

# %% [markdown]
# #### 추가변수 결합

# %%
data.shape
# Out:
# (26048114, 13)

# %%
local_percent_df
# Out:
#        CARD_SIDO_NM CARD_CCG_NM            STD_CLSS_NM REG_YYMM         LP
# 0                강원         강릉시             건강보조식품 소매업   201901   0.138432
# 1                강원         강릉시                골프장 운영업   201901   0.148825
# 2                강원         강릉시            과실 및 채소 소매업   201901   1.468549
# 3                강원         강릉시      관광 민예품 및 선물용품 소매업   201901   0.022661
# 4                강원         강릉시        그외 기타 스포츠시설 운영업   201901   0.003255
# ...             ...         ...                    ...      ...        ...
# 124523           충북         충주시  피자 햄버거 샌드위치 및 유사 음식점업   202004   1.362619
# 124524           충북         충주시                한식 음식점업   202004  18.402971
# 124525           충북         충주시                    호텔업   202004   0.059226
# 124526           충북         충주시          화장품 및 방향제 소매업   202004   0.368080
# 124527           충북         충주시               휴양콘도 운영업   202004   0.004580
#
# [124528 rows x 5 columns]

# %%
columns = ['REG_YYMM', 'CARD_SIDO_NM', 'CARD_CCG_NM', 'STD_CLSS_NM', 'HOM_SIDO_NM', 'AGE', 'SEX_CTGO_CD', 'FLC']
df = data.groupby(columns, as_index=False)[['AMT']].sum()

# %%
grouped = pd.merge(df,all_jobs_df,on =['CARD_SIDO_NM','STD_CLSS_NM'],how = 'left')
grouped = pd.merge(grouped,local_percent_df,on =['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM','REG_YYMM'],how = 'left')
grouped = pd.merge(grouped,job_percent_df,on =['CARD_SIDO_NM','CARD_CCG_NM','STD_CLSS_NM','REG_YYMM'],how = 'left')
grouped = pd.merge(grouped, trade_num, on =['CARD_SIDO_NM','STD_CLSS_NM','REG_YYMM'], how = 'left')

# %%
grouped.head(5)
# Out:
#   REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM  AGE  SEX_CTGO_CD  \
# 0   201901           강원         강릉시  건강보조식품 소매업          강원  20s            1
# 1   201901           강원         강릉시  건강보조식품 소매업          강원  30s            1
# 2   201901           강원         강릉시  건강보조식품 소매업          강원  30s            2
# 3   201901           강원         강릉시  건강보조식품 소매업          강원  40s            1
# 4   201901           강원         강릉시  건강보조식품 소매업          강원  40s            1
#
#    FLC      AMT  company  employee        LP        JP  loyal  month  refund
# 0    1   311200    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0
# 1    2  1374500    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0
# 2    2   818700    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0
# 3    3  1717000    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0
# 4    4  1047300    263.0     399.0  0.138432  0.279221   80.0    1.0   -32.0

# %%
grouped.REG_YYMM = pd.to_datetime(grouped.REG_YYMM, format='%Y%m')

# %%
from sklearn.preprocessing import LabelEncoder

# 인코딩
dtypes = grouped.dtypes
encoders = {}
for column in grouped.columns:
    if str(dtypes[column]) == 'object':
        encoder = LabelEncoder()
        encoder.fit(grouped[column])
        encoders[column] = encoder
        
df_num = grouped.copy()        
for column in encoders.keys():
    encoder = encoders[column]
    df_num[column] = encoder.transform(grouped[column])

# %%
df_num
# Out:
#           REG_YYMM  CARD_SIDO_NM  CARD_CCG_NM  STD_CLSS_NM  HOM_SIDO_NM  AGE  \
# 0       2019-01-01             0            4            0            0    1
# 1       2019-01-01             0            4            0            0    2
# 2       2019-01-01             0            4            0            0    2
# 3       2019-01-01             0            4            0            0    3
# 4       2019-01-01             0            4            0            0    3
# ...            ...           ...          ...          ...          ...  ...
# 5630138 2020-04-01            16          202           40           16    1
# 5630139 2020-04-01            16          202           40           16    2
# 5630140 2020-04-01            16          202           40           16    3
# 5630141 2020-04-01            16          202           40           16    4
# 5630142 2020-04-01            16          202           40           16    5
#
#          SEX_CTGO_CD  FLC      AMT  company  employee        LP        JP  \
# 0                  1    1   311200    263.0     399.0  0.138432  0.279221
# 1                  1    2  1374500    263.0     399.0  0.138432  0.279221
# 2                  2    2   818700    263.0     399.0  0.138432  0.279221
# 3                  1    3  1717000    263.0     399.0  0.138432  0.279221
# 4                  1    4  1047300    263.0     399.0  0.138432  0.279221
# ...              ...  ...      ...      ...       ...       ...       ...
# 5630138            1    1    77000     11.0     492.0  0.004580  0.011570
# 5630139            1    2    92000     11.0     492.0  0.004580  0.011570
# 5630140            2    3   193000     11.0     492.0  0.004580  0.011570
# 5630141            1    4    86000     11.0     492.0  0.004580  0.011570
# 5630142            2    5   227000     11.0     492.0  0.004580  0.011570
#
#          loyal  month  refund
# 0         80.0    1.0   -32.0
# 1         80.0    1.0   -32.0
# 2         80.0    1.0   -32.0
# 3         80.0    1.0   -32.0
# 4         80.0    1.0   -32.0
# ...        ...    ...     ...
# 5630138   62.0    4.0   999.0
# 5630139   62.0    4.0   999.0
# 5630140   62.0    4.0   999.0
# 5630141   62.0    4.0   999.0
# 5630142   62.0    4.0   999.0
#
# [5630143 rows x 16 columns]

# %% [markdown]
# --------------

# %% [markdown]
# ### 중간 저장

# %%
grouped.to_csv("data/중간저장.csv", index=False)

# %%
df_num.to_csv("data/중간저장 as num.csv", index=False)

# %% [markdown]
# --------------

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5630143 entries, 0 to 5630142
# Data columns (total 16 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   REG_YYMM      datetime64[ns]
#  1   CARD_SIDO_NM  int32
#  2   CARD_CCG_NM   int32
#  3   STD_CLSS_NM   int32
#  4   HOM_SIDO_NM   int32
#  5   AGE           int32
#  6   SEX_CTGO_CD   int64
#  7   FLC           int64
#  8   AMT           int64
#  9   company       float64
#  10  employee      float64
#  11  LP            float64
#  12  JP            float64
#  13  loyal         float64
#  14  month         float64
#  15  refund        float64
# dtypes: datetime64[ns](1), float64(7), int32(5), int64(3)
# memory usage: 622.8 MB

# %%
import datetime as dt

df_num['month'] = df_num['REG_YYMM'].dt.month
df_num['year'] = df_num['REG_YYMM'].dt.year

# %%
train_df = df_num[df_num['REG_YYMM'] < '2020-03-01']
validation_df = df_num[df_num['REG_YYMM'] == '2020-03-01']

# %%
# 7월 데이터 = 2020년의 평균값을 사용.

temp = df_num[df_num['REG_YYMM'] >= '2020']
temp = temp.groupby(['CARD_SIDO_NM', 'CARD_CCG_NM', 'STD_CLSS_NM',
                     'HOM_SIDO_NM', 'AGE', 'SEX_CTGO_CD', 'FLC'], as_index=False)[['company', 'employee', 
                                                            'LP', 'JP', 'loyal', 'month', 'refund', 'year']].mean()

# %%
temp.month = 7
temp = pd.concat([df_num[df_num['REG_YYMM'] == '2020-04-01'], temp])

# %%
temp = temp.drop(['REG_YYMM', 'AMT'], axis=1)

# %% [markdown]
# ### Light GBM

# %%
import lightgbm as lgb

# %%
train_df.head(1)
# Out:
#     REG_YYMM  CARD_SIDO_NM  CARD_CCG_NM  STD_CLSS_NM  HOM_SIDO_NM  AGE  \
# 0 2019-01-01             0            4            0            0    1
#
#    SEX_CTGO_CD  FLC     AMT  company  employee        LP        JP  loyal  \
# 0            1    1  311200    263.0     399.0  0.138432  0.279221   80.0
#
#    month  refund  year
# 0      1   -32.0  2019

# %%
train = train_df.drop(['AMT', 'REG_YYMM'], axis=1)
trian_label = np.log1p(train_df[['AMT']])

# %%
validation = validation_df.drop(['AMT', 'REG_YYMM'], axis=1)
validation_label = np.log1p(validation_df[['AMT']])

# %%
lgb_train = lgb.Dataset(train, label=trian_label)
lgb_eval = lgb.Dataset(validation, label=validation_label, reference=lgb_train)

# %%
evals_result = {}
params = {
    'boosting_type': 'gbdt',
    'objective': 'tweedie',
    'metric': 'rmse',
    'tweedie_variance_power':1.1,
    'max_depth':11,
    'num_leaves': 31,
    'learning_rate': 0.7,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0}

# %%
model = lgb.train(params, lgb_train, early_stopping_rounds=100,
                  num_boost_round=1000, evals_result=evals_result,
                  valid_sets= (lgb_train, lgb_eval),)
# Out:
# [1]	training's rmse: 1.96585	valid_1's rmse: 1.9559
# Training until validation scores don't improve for 100 rounds
# [2]	training's rmse: 1.86769	valid_1's rmse: 1.86232
# [3]	training's rmse: 1.83554	valid_1's rmse: 1.83533
# [4]	training's rmse: 1.75455	valid_1's rmse: 1.74442
# [5]	training's rmse: 1.68188	valid_1's rmse: 1.66159
# [6]	training's rmse: 1.64389	valid_1's rmse: 1.62551
# [7]	training's rmse: 1.63457	valid_1's rmse: 1.61769
# [8]	training's rmse: 1.61534	valid_1's rmse: 1.59931
# [9]	training's rmse: 1.5914	valid_1's rmse: 1.57588
# [10]	training's rmse: 1.58031	valid_1's rmse: 1.56461
# [11]	training's rmse: 1.56538	valid_1's rmse: 1.54809
# [12]	training's rmse: 1.56252	valid_1's rmse: 1.54441
# [13]	training's rmse: 1.54292	valid_1's rmse: 1.52502
# [14]	training's rmse: 1.53149	valid_1's rmse: 1.51156
# [15]	training's rmse: 1.51805	valid_1's rmse: 1.499
# [16]	training's rmse: 1.48903	valid_1's rmse: 1.46825
# [17]	training's rmse: 1.45879	valid_1's rmse: 1.44568
# [18]	training's rmse: 1.45108	valid_1's rmse: 1.43695
# [19]	training's rmse: 1.43947	valid_1's rmse: 1.42548
# [20]	training's rmse: 1.43438	valid_1's rmse: 1.42156
# [21]	training's rmse: 1.4307	valid_1's rmse: 1.4179
# [22]	training's rmse: 1.41341	valid_1's rmse: 1.39832
# [23]	training's rmse: 1.4103	valid_1's rmse: 1.39513
# [24]	training's rmse: 1.39336	valid_1's rmse: 1.39648
# [25]	training's rmse: 1.37919	valid_1's rmse: 1.3827
# [26]	training's rmse: 1.36463	valid_1's rmse: 1.3703
# [27]	training's rmse: 1.35753	valid_1's rmse: 1.36353
# [28]	training's rmse: 1.34973	valid_1's rmse: 1.3553
# [29]	training's rmse: 1.33879	valid_1's rmse: 1.34497
# [30]	training's rmse: 1.33099	valid_1's rmse: 1.33742
# [31]	training's rmse: 1.30798	valid_1's rmse: 1.30832
# [32]	training's rmse: 1.30409	valid_1's rmse: 1.30407
# [33]	training's rmse: 1.30075	valid_1's rmse: 1.3026
# [34]	training's rmse: 1.29911	valid_1's rmse: 1.30113
# [35]	training's rmse: 1.29442	valid_1's rmse: 1.2982
# [36]	training's rmse: 1.29113	valid_1's rmse: 1.29424
# [37]	training's rmse: 1.28154	valid_1's rmse: 1.28339
# [38]	training's rmse: 1.27723	valid_1's rmse: 1.27862
# [39]	training's rmse: 1.25335	valid_1's rmse: 1.25449
# [40]	training's rmse: 1.25016	valid_1's rmse: 1.25108
# [41]	training's rmse: 1.24694	valid_1's rmse: 1.2491
# [42]	training's rmse: 1.24025	valid_1's rmse: 1.23812
# [43]	training's rmse: 1.2364	valid_1's rmse: 1.23442
# [44]	training's rmse: 1.23245	valid_1's rmse: 1.23017
# [45]	training's rmse: 1.22982	valid_1's rmse: 1.22809
# [46]	training's rmse: 1.22746	valid_1's rmse: 1.22946
# [47]	training's rmse: 1.22015	valid_1's rmse: 1.22333
# [48]	training's rmse: 1.21696	valid_1's rmse: 1.22073
# [49]	training's rmse: 1.21215	valid_1's rmse: 1.21523
# [50]	training's rmse: 1.20812	valid_1's rmse: 1.20946
# [51]	training's rmse: 1.20496	valid_1's rmse: 1.20619
# [52]	training's rmse: 1.20324	valid_1's rmse: 1.20461
# [53]	training's rmse: 1.20223	valid_1's rmse: 1.20518
# [54]	training's rmse: 1.2006	valid_1's rmse: 1.20404
# [55]	training's rmse: 1.19817	valid_1's rmse: 1.20721
# [56]	training's rmse: 1.19195	valid_1's rmse: 1.20063
# [57]	training's rmse: 1.19011	valid_1's rmse: 1.19894
# [58]	training's rmse: 1.1891	valid_1's rmse: 1.19822
# [59]	training's rmse: 1.18708	valid_1's rmse: 1.19693
# [60]	training's rmse: 1.18556	valid_1's rmse: 1.19537
# [61]	training's rmse: 1.1832	valid_1's rmse: 1.19322
# [62]	training's rmse: 1.18145	valid_1's rmse: 1.19144
# [63]	training's rmse: 1.17817	valid_1's rmse: 1.18798
# [64]	training's rmse: 1.17273	valid_1's rmse: 1.18344
# [65]	training's rmse: 1.17068	valid_1's rmse: 1.1812
# [66]	training's rmse: 1.16588	valid_1's rmse: 1.17646
# [67]	training's rmse: 1.16299	valid_1's rmse: 1.17349
# [68]	training's rmse: 1.16108	valid_1's rmse: 1.17184
# [69]	training's rmse: 1.15867	valid_1's rmse: 1.16971
# [70]	training's rmse: 1.15712	valid_1's rmse: 1.16793
# [71]	training's rmse: 1.15235	valid_1's rmse: 1.16302
# [72]	training's rmse: 1.14762	valid_1's rmse: 1.15825
# [73]	training's rmse: 1.13697	valid_1's rmse: 1.14762
# [74]	training's rmse: 1.13469	valid_1's rmse: 1.14558
# [75]	training's rmse: 1.13119	valid_1's rmse: 1.14135
# [76]	training's rmse: 1.12912	valid_1's rmse: 1.13964
# [77]	training's rmse: 1.11419	valid_1's rmse: 1.12754
# [78]	training's rmse: 1.11069	valid_1's rmse: 1.12508
# [79]	training's rmse: 1.10742	valid_1's rmse: 1.12267
# [80]	training's rmse: 1.10489	valid_1's rmse: 1.12014
# [81]	training's rmse: 1.10253	valid_1's rmse: 1.1178
# [82]	training's rmse: 1.09656	valid_1's rmse: 1.11383
# [83]	training's rmse: 1.09482	valid_1's rmse: 1.11281
# [84]	training's rmse: 1.09345	valid_1's rmse: 1.11344
# [85]	training's rmse: 1.08985	valid_1's rmse: 1.1093
# [86]	training's rmse: 1.08786	valid_1's rmse: 1.10755
# [87]	training's rmse: 1.0853	valid_1's rmse: 1.1045
# [88]	training's rmse: 1.08381	valid_1's rmse: 1.10294
# [89]	training's rmse: 1.08262	valid_1's rmse: 1.10192
# [90]	training's rmse: 1.08045	valid_1's rmse: 1.09922
# [91]	training's rmse: 1.07937	valid_1's rmse: 1.0987
# [92]	training's rmse: 1.07802	valid_1's rmse: 1.09743
# [93]	training's rmse: 1.07653	valid_1's rmse: 1.09591
# [94]	training's rmse: 1.07475	valid_1's rmse: 1.09402
# [95]	training's rmse: 1.07364	valid_1's rmse: 1.09288
# [96]	training's rmse: 1.07255	valid_1's rmse: 1.09218
# [97]	training's rmse: 1.07007	valid_1's rmse: 1.09023
# [98]	training's rmse: 1.06902	valid_1's rmse: 1.08953
# [99]	training's rmse: 1.06798	valid_1's rmse: 1.0885
# [100]	training's rmse: 1.06719	valid_1's rmse: 1.08796
# [101]	training's rmse: 1.06603	valid_1's rmse: 1.08791
# [102]	training's rmse: 1.06523	valid_1's rmse: 1.08747
# [103]	training's rmse: 1.06275	valid_1's rmse: 1.08471
# [104]	training's rmse: 1.06089	valid_1's rmse: 1.08324
# [105]	training's rmse: 1.05918	valid_1's rmse: 1.0815
# [106]	training's rmse: 1.05643	valid_1's rmse: 1.07898
# [107]	training's rmse: 1.05581	valid_1's rmse: 1.07829
# [108]	training's rmse: 1.05539	valid_1's rmse: 1.07805
# [109]	training's rmse: 1.05105	valid_1's rmse: 1.07443
# [110]	training's rmse: 1.04724	valid_1's rmse: 1.07069
# [111]	training's rmse: 1.04599	valid_1's rmse: 1.06982
# [112]	training's rmse: 1.04518	valid_1's rmse: 1.06903
# [113]	training's rmse: 1.04382	valid_1's rmse: 1.06824
# [114]	training's rmse: 1.04302	valid_1's rmse: 1.06749
# [115]	training's rmse: 1.03937	valid_1's rmse: 1.0645
# [116]	training's rmse: 1.03824	valid_1's rmse: 1.06389
# [117]	training's rmse: 1.03668	valid_1's rmse: 1.06212
# [118]	training's rmse: 1.03518	valid_1's rmse: 1.06104
# [119]	training's rmse: 1.03388	valid_1's rmse: 1.05987
# [120]	training's rmse: 1.03324	valid_1's rmse: 1.06104
# [121]	training's rmse: 1.03225	valid_1's rmse: 1.06013
# [122]	training's rmse: 1.03109	valid_1's rmse: 1.05928
# [123]	training's rmse: 1.02997	valid_1's rmse: 1.05826
# [124]	training's rmse: 1.0275	valid_1's rmse: 1.05534
# [125]	training's rmse: 1.02606	valid_1's rmse: 1.05314
# [126]	training's rmse: 1.02505	valid_1's rmse: 1.05302
# [127]	training's rmse: 1.02444	valid_1's rmse: 1.05214
# [128]	training's rmse: 1.02397	valid_1's rmse: 1.05179
# [129]	training's rmse: 1.02316	valid_1's rmse: 1.05114
# [130]	training's rmse: 1.02255	valid_1's rmse: 1.05058
# [131]	training's rmse: 1.02196	valid_1's rmse: 1.05017
# [132]	training's rmse: 1.02102	valid_1's rmse: 1.04949
# [133]	training's rmse: 1.01962	valid_1's rmse: 1.0484
# [134]	training's rmse: 1.01911	valid_1's rmse: 1.04771
# [135]	training's rmse: 1.01838	valid_1's rmse: 1.04727
# [136]	training's rmse: 1.01571	valid_1's rmse: 1.04304
# [137]	training's rmse: 1.01469	valid_1's rmse: 1.04242
# [138]	training's rmse: 1.01415	valid_1's rmse: 1.04202
# [139]	training's rmse: 1.01348	valid_1's rmse: 1.04117
# [140]	training's rmse: 1.01189	valid_1's rmse: 1.03983
# [141]	training's rmse: 1.01118	valid_1's rmse: 1.03914
# [142]	training's rmse: 1.01	valid_1's rmse: 1.03785
# [143]	training's rmse: 1.00926	valid_1's rmse: 1.03734
# [144]	training's rmse: 1.0079	valid_1's rmse: 1.03593
# [145]	training's rmse: 1.00689	valid_1's rmse: 1.03528
# [146]	training's rmse: 1.00525	valid_1's rmse: 1.03365
# [147]	training's rmse: 1.00314	valid_1's rmse: 1.03227
# [148]	training's rmse: 1.00215	valid_1's rmse: 1.03136
# [149]	training's rmse: 1.0007	valid_1's rmse: 1.0298
# [150]	training's rmse: 0.999658	valid_1's rmse: 1.02899
# [151]	training's rmse: 0.999011	valid_1's rmse: 1.02847
# [152]	training's rmse: 0.998633	valid_1's rmse: 1.02807
# [153]	training's rmse: 0.99814	valid_1's rmse: 1.02763
# [154]	training's rmse: 0.997415	valid_1's rmse: 1.02692
# [155]	training's rmse: 0.997032	valid_1's rmse: 1.02667
# [156]	training's rmse: 0.996012	valid_1's rmse: 1.02583
# [157]	training's rmse: 0.995268	valid_1's rmse: 1.02505
# [158]	training's rmse: 0.994926	valid_1's rmse: 1.02471
# [159]	training's rmse: 0.994524	valid_1's rmse: 1.0247
# [160]	training's rmse: 0.993919	valid_1's rmse: 1.02461
# [161]	training's rmse: 0.993457	valid_1's rmse: 1.02432
# [162]	training's rmse: 0.992532	valid_1's rmse: 1.02387
# [163]	training's rmse: 0.990296	valid_1's rmse: 1.02208
# [164]	training's rmse: 0.989744	valid_1's rmse: 1.02156
# [165]	training's rmse: 0.988464	valid_1's rmse: 1.02083
# [166]	training's rmse: 0.987562	valid_1's rmse: 1.02003
# [167]	training's rmse: 0.987064	valid_1's rmse: 1.01944
# [168]	training's rmse: 0.984745	valid_1's rmse: 1.01648
# [169]	training's rmse: 0.983823	valid_1's rmse: 1.01573
# [170]	training's rmse: 0.983163	valid_1's rmse: 1.01544
# [171]	training's rmse: 0.982041	valid_1's rmse: 1.01489
# [172]	training's rmse: 0.980791	valid_1's rmse: 1.01206
# [173]	training's rmse: 0.979991	valid_1's rmse: 1.01146
# [174]	training's rmse: 0.979516	valid_1's rmse: 1.01099
# [175]	training's rmse: 0.979199	valid_1's rmse: 1.0108
# [176]	training's rmse: 0.978785	valid_1's rmse: 1.01054
# [177]	training's rmse: 0.978382	valid_1's rmse: 1.01057
# [178]	training's rmse: 0.977767	valid_1's rmse: 1.0102
# [179]	training's rmse: 0.977284	valid_1's rmse: 1.00967
# [180]	training's rmse: 0.976517	valid_1's rmse: 1.00944
# [181]	training's rmse: 0.975307	valid_1's rmse: 1.00763
# [182]	training's rmse: 0.973527	valid_1's rmse: 1.00576
# [183]	training's rmse: 0.972131	valid_1's rmse: 1.00475
# [184]	training's rmse: 0.970848	valid_1's rmse: 1.00113
# [185]	training's rmse: 0.970489	valid_1's rmse: 1.00079
# [186]	training's rmse: 0.969547	valid_1's rmse: 1.00034
# [187]	training's rmse: 0.968835	valid_1's rmse: 0.999726
# [188]	training's rmse: 0.968567	valid_1's rmse: 0.999389
# [189]	training's rmse: 0.96815	valid_1's rmse: 0.99928
# [190]	training's rmse: 0.967868	valid_1's rmse: 0.998972
# [191]	training's rmse: 0.967095	valid_1's rmse: 0.998125
# [192]	training's rmse: 0.966536	valid_1's rmse: 0.997713
# [193]	training's rmse: 0.965964	valid_1's rmse: 0.997187
# [194]	training's rmse: 0.964907	valid_1's rmse: 0.996202
# [195]	training's rmse: 0.964243	valid_1's rmse: 0.995701
# [196]	training's rmse: 0.963362	valid_1's rmse: 0.992899
# [197]	training's rmse: 0.963058	valid_1's rmse: 0.992586
# [198]	training's rmse: 0.962503	valid_1's rmse: 0.992561
# [199]	training's rmse: 0.961969	valid_1's rmse: 0.9922
# [200]	training's rmse: 0.961383	valid_1's rmse: 0.991671
# [201]	training's rmse: 0.960502	valid_1's rmse: 0.990596
# [202]	training's rmse: 0.959998	valid_1's rmse: 0.990483
# [203]	training's rmse: 0.959734	valid_1's rmse: 0.990382
# [204]	training's rmse: 0.959343	valid_1's rmse: 0.990036
# [205]	training's rmse: 0.957195	valid_1's rmse: 0.986945
# [206]	training's rmse: 0.956386	valid_1's rmse: 0.986619
# [207]	training's rmse: 0.954569	valid_1's rmse: 0.985016
# [208]	training's rmse: 0.954203	valid_1's rmse: 0.983156
# [209]	training's rmse: 0.953634	valid_1's rmse: 0.982704
# [210]	training's rmse: 0.952908	valid_1's rmse: 0.981738
# [211]	training's rmse: 0.952655	valid_1's rmse: 0.981657
# [212]	training's rmse: 0.951987	valid_1's rmse: 0.981188
# [213]	training's rmse: 0.951365	valid_1's rmse: 0.98052
# [214]	training's rmse: 0.950525	valid_1's rmse: 0.979585
# [215]	training's rmse: 0.950141	valid_1's rmse: 0.97931
# [216]	training's rmse: 0.949626	valid_1's rmse: 0.978872
# [217]	training's rmse: 0.9488	valid_1's rmse: 0.977651
# [218]	training's rmse: 0.948166	valid_1's rmse: 0.976944
# [219]	training's rmse: 0.947355	valid_1's rmse: 0.976198
# [220]	training's rmse: 0.947111	valid_1's rmse: 0.975933
# [221]	training's rmse: 0.946233	valid_1's rmse: 0.975057
# [222]	training's rmse: 0.945982	valid_1's rmse: 0.974806
# [223]	training's rmse: 0.945612	valid_1's rmse: 0.974529
# [224]	training's rmse: 0.944231	valid_1's rmse: 0.973372
# [225]	training's rmse: 0.943986	valid_1's rmse: 0.973114
# [226]	training's rmse: 0.943679	valid_1's rmse: 0.972945
# [227]	training's rmse: 0.942949	valid_1's rmse: 0.972827
# [228]	training's rmse: 0.942225	valid_1's rmse: 0.972071
# [229]	training's rmse: 0.941445	valid_1's rmse: 0.971449
# [230]	training's rmse: 0.941053	valid_1's rmse: 0.971192
# [231]	training's rmse: 0.940845	valid_1's rmse: 0.971032
# [232]	training's rmse: 0.940393	valid_1's rmse: 0.97072
# [233]	training's rmse: 0.939688	valid_1's rmse: 0.970065
# [234]	training's rmse: 0.939169	valid_1's rmse: 0.969467
# [235]	training's rmse: 0.93876	valid_1's rmse: 0.969215
# [236]	training's rmse: 0.938256	valid_1's rmse: 0.969175
# [237]	training's rmse: 0.937723	valid_1's rmse: 0.968787
# [238]	training's rmse: 0.937274	valid_1's rmse: 0.968357
# [239]	training's rmse: 0.937008	valid_1's rmse: 0.968208
# [240]	training's rmse: 0.935326	valid_1's rmse: 0.967606
# [241]	training's rmse: 0.935151	valid_1's rmse: 0.967602
# [242]	training's rmse: 0.934267	valid_1's rmse: 0.967269
# [243]	training's rmse: 0.933677	valid_1's rmse: 0.966842
# [244]	training's rmse: 0.933325	valid_1's rmse: 0.966456
# [245]	training's rmse: 0.932969	valid_1's rmse: 0.966093
# [246]	training's rmse: 0.9328	valid_1's rmse: 0.966001
# [247]	training's rmse: 0.932325	valid_1's rmse: 0.965707
# [248]	training's rmse: 0.931884	valid_1's rmse: 0.965556
# [249]	training's rmse: 0.931066	valid_1's rmse: 0.96461
# [250]	training's rmse: 0.930368	valid_1's rmse: 0.96408
# [251]	training's rmse: 0.930044	valid_1's rmse: 0.963855
# [252]	training's rmse: 0.929672	valid_1's rmse: 0.963627
# [253]	training's rmse: 0.929456	valid_1's rmse: 0.963341
# [254]	training's rmse: 0.928799	valid_1's rmse: 0.962973
# [255]	training's rmse: 0.928206	valid_1's rmse: 0.961886
# [256]	training's rmse: 0.927836	valid_1's rmse: 0.961859
# [257]	training's rmse: 0.926855	valid_1's rmse: 0.961247
# [258]	training's rmse: 0.926418	valid_1's rmse: 0.960844
# [259]	training's rmse: 0.926115	valid_1's rmse: 0.960927
# [260]	training's rmse: 0.925849	valid_1's rmse: 0.96088
# [261]	training's rmse: 0.924836	valid_1's rmse: 0.959494
# [262]	training's rmse: 0.924162	valid_1's rmse: 0.958702
# [263]	training's rmse: 0.923565	valid_1's rmse: 0.958412
# [264]	training's rmse: 0.9225	valid_1's rmse: 0.957464
# [265]	training's rmse: 0.922086	valid_1's rmse: 0.957067
# [266]	training's rmse: 0.921844	valid_1's rmse: 0.956936
# [267]	training's rmse: 0.920967	valid_1's rmse: 0.956451
# [268]	training's rmse: 0.920455	valid_1's rmse: 0.955982
# [269]	training's rmse: 0.919827	valid_1's rmse: 0.955178
# [270]	training's rmse: 0.91933	valid_1's rmse: 0.954832
# [271]	training's rmse: 0.91851	valid_1's rmse: 0.95449
# [272]	training's rmse: 0.918118	valid_1's rmse: 0.954231
# [273]	training's rmse: 0.917672	valid_1's rmse: 0.953775
# [274]	training's rmse: 0.917251	valid_1's rmse: 0.953537
# [275]	training's rmse: 0.915662	valid_1's rmse: 0.952173
# [276]	training's rmse: 0.914873	valid_1's rmse: 0.951345
# [277]	training's rmse: 0.914631	valid_1's rmse: 0.951107
# [278]	training's rmse: 0.914358	valid_1's rmse: 0.950876
# [279]	training's rmse: 0.913934	valid_1's rmse: 0.950452
# [280]	training's rmse: 0.913375	valid_1's rmse: 0.949858
# [281]	training's rmse: 0.912554	valid_1's rmse: 0.949149
# [282]	training's rmse: 0.91187	valid_1's rmse: 0.948761
# [283]	training's rmse: 0.911456	valid_1's rmse: 0.948451
# [284]	training's rmse: 0.910812	valid_1's rmse: 0.947808
# [285]	training's rmse: 0.910609	valid_1's rmse: 0.947569
# [286]	training's rmse: 0.910131	valid_1's rmse: 0.947148
# [287]	training's rmse: 0.909602	valid_1's rmse: 0.946636
# [288]	training's rmse: 0.909381	valid_1's rmse: 0.946485
# [289]	training's rmse: 0.908999	valid_1's rmse: 0.946298
# [290]	training's rmse: 0.9086	valid_1's rmse: 0.94612
# [291]	training's rmse: 0.908261	valid_1's rmse: 0.945767
# [292]	training's rmse: 0.907405	valid_1's rmse: 0.944713
# [293]	training's rmse: 0.906915	valid_1's rmse: 0.944325
# [294]	training's rmse: 0.906409	valid_1's rmse: 0.943902
# [295]	training's rmse: 0.905829	valid_1's rmse: 0.943568
# [296]	training's rmse: 0.90551	valid_1's rmse: 0.943428
# [297]	training's rmse: 0.905323	valid_1's rmse: 0.943608
# [298]	training's rmse: 0.90469	valid_1's rmse: 0.942752
# [299]	training's rmse: 0.904381	valid_1's rmse: 0.942479
# [300]	training's rmse: 0.904211	valid_1's rmse: 0.942303
# [301]	training's rmse: 0.903958	valid_1's rmse: 0.942118
# [302]	training's rmse: 0.903691	valid_1's rmse: 0.941903
# [303]	training's rmse: 0.90344	valid_1's rmse: 0.941604
# [304]	training's rmse: 0.903177	valid_1's rmse: 0.941457
# [305]	training's rmse: 0.902942	valid_1's rmse: 0.941245
# [306]	training's rmse: 0.902394	valid_1's rmse: 0.940934
# [307]	training's rmse: 0.902113	valid_1's rmse: 0.940699
# [308]	training's rmse: 0.901835	valid_1's rmse: 0.940484
# [309]	training's rmse: 0.901116	valid_1's rmse: 0.939836
# [310]	training's rmse: 0.900844	valid_1's rmse: 0.939689
# [311]	training's rmse: 0.900648	valid_1's rmse: 0.939603
# [312]	training's rmse: 0.899797	valid_1's rmse: 0.939078
# [313]	training's rmse: 0.899089	valid_1's rmse: 0.938838
# [314]	training's rmse: 0.898726	valid_1's rmse: 0.938609
# [315]	training's rmse: 0.898591	valid_1's rmse: 0.938476
# [316]	training's rmse: 0.898009	valid_1's rmse: 0.937825
# [317]	training's rmse: 0.897775	valid_1's rmse: 0.937719
# [318]	training's rmse: 0.89688	valid_1's rmse: 0.936963
# [319]	training's rmse: 0.896771	valid_1's rmse: 0.936935
# [320]	training's rmse: 0.89646	valid_1's rmse: 0.936835
# [321]	training's rmse: 0.895884	valid_1's rmse: 0.936519
# [322]	training's rmse: 0.895601	valid_1's rmse: 0.936503
# [323]	training's rmse: 0.895333	valid_1's rmse: 0.936262
# [324]	training's rmse: 0.894952	valid_1's rmse: 0.935862
# [325]	training's rmse: 0.894675	valid_1's rmse: 0.935686
# [326]	training's rmse: 0.894411	valid_1's rmse: 0.935551
# [327]	training's rmse: 0.894218	valid_1's rmse: 0.935509
# [328]	training's rmse: 0.893941	valid_1's rmse: 0.935796
# [329]	training's rmse: 0.893499	valid_1's rmse: 0.935312
# [330]	training's rmse: 0.893339	valid_1's rmse: 0.935206
# [331]	training's rmse: 0.893161	valid_1's rmse: 0.935272
# [332]	training's rmse: 0.892388	valid_1's rmse: 0.934547
# [333]	training's rmse: 0.892269	valid_1's rmse: 0.934499
# [334]	training's rmse: 0.891894	valid_1's rmse: 0.934233
# [335]	training's rmse: 0.891552	valid_1's rmse: 0.933981
# [336]	training's rmse: 0.891369	valid_1's rmse: 0.933824
# [337]	training's rmse: 0.891138	valid_1's rmse: 0.933836
# [338]	training's rmse: 0.890855	valid_1's rmse: 0.933565
# [339]	training's rmse: 0.890507	valid_1's rmse: 0.933425
# [340]	training's rmse: 0.890021	valid_1's rmse: 0.933035
# [341]	training's rmse: 0.889533	valid_1's rmse: 0.932628
# [342]	training's rmse: 0.889245	valid_1's rmse: 0.932375
# [343]	training's rmse: 0.888802	valid_1's rmse: 0.931911
# [344]	training's rmse: 0.888445	valid_1's rmse: 0.931697
# [345]	training's rmse: 0.888209	valid_1's rmse: 0.931187
# [346]	training's rmse: 0.888053	valid_1's rmse: 0.931106
# [347]	training's rmse: 0.887636	valid_1's rmse: 0.930751
# [348]	training's rmse: 0.887388	valid_1's rmse: 0.930657
# [349]	training's rmse: 0.886689	valid_1's rmse: 0.930033
# [350]	training's rmse: 0.886388	valid_1's rmse: 0.929719
# [351]	training's rmse: 0.885864	valid_1's rmse: 0.929171
# [352]	training's rmse: 0.885546	valid_1's rmse: 0.928869
# [353]	training's rmse: 0.885237	valid_1's rmse: 0.92866
# [354]	training's rmse: 0.884985	valid_1's rmse: 0.928628
# [355]	training's rmse: 0.88463	valid_1's rmse: 0.928235
# [356]	training's rmse: 0.884441	valid_1's rmse: 0.928113
# [357]	training's rmse: 0.884108	valid_1's rmse: 0.927893
# [358]	training's rmse: 0.88392	valid_1's rmse: 0.927771
# [359]	training's rmse: 0.883249	valid_1's rmse: 0.927125
# [360]	training's rmse: 0.882747	valid_1's rmse: 0.926498
# [361]	training's rmse: 0.882558	valid_1's rmse: 0.926603
# [362]	training's rmse: 0.882401	valid_1's rmse: 0.926421
# [363]	training's rmse: 0.881931	valid_1's rmse: 0.925826
# [364]	training's rmse: 0.881404	valid_1's rmse: 0.925371
# [365]	training's rmse: 0.881008	valid_1's rmse: 0.925138
# [366]	training's rmse: 0.880745	valid_1's rmse: 0.92496
# [367]	training's rmse: 0.880175	valid_1's rmse: 0.924259
# [368]	training's rmse: 0.879903	valid_1's rmse: 0.924015
# [369]	training's rmse: 0.879691	valid_1's rmse: 0.923842
# [370]	training's rmse: 0.87924	valid_1's rmse: 0.92337
# [371]	training's rmse: 0.879066	valid_1's rmse: 0.92343
# [372]	training's rmse: 0.87886	valid_1's rmse: 0.923308
# [373]	training's rmse: 0.878735	valid_1's rmse: 0.923329
# [374]	training's rmse: 0.878457	valid_1's rmse: 0.923163
# [375]	training's rmse: 0.878246	valid_1's rmse: 0.923044
# [376]	training's rmse: 0.87777	valid_1's rmse: 0.922665
# [377]	training's rmse: 0.877031	valid_1's rmse: 0.922012
# [378]	training's rmse: 0.87671	valid_1's rmse: 0.921882
# [379]	training's rmse: 0.876379	valid_1's rmse: 0.921651
# [380]	training's rmse: 0.876187	valid_1's rmse: 0.92151
# [381]	training's rmse: 0.875881	valid_1's rmse: 0.921275
# [382]	training's rmse: 0.875592	valid_1's rmse: 0.921069
# [383]	training's rmse: 0.875384	valid_1's rmse: 0.9208
# [384]	training's rmse: 0.875137	valid_1's rmse: 0.920453
# [385]	training's rmse: 0.875017	valid_1's rmse: 0.920436
# [386]	training's rmse: 0.874718	valid_1's rmse: 0.920466
# [387]	training's rmse: 0.874569	valid_1's rmse: 0.920473
# [388]	training's rmse: 0.873946	valid_1's rmse: 0.919818
# [389]	training's rmse: 0.873594	valid_1's rmse: 0.919545
# [390]	training's rmse: 0.873353	valid_1's rmse: 0.919468
# [391]	training's rmse: 0.873232	valid_1's rmse: 0.91927
# [392]	training's rmse: 0.872951	valid_1's rmse: 0.919334
# [393]	training's rmse: 0.872808	valid_1's rmse: 0.919434
# [394]	training's rmse: 0.872677	valid_1's rmse: 0.919448
# [395]	training's rmse: 0.872399	valid_1's rmse: 0.919282
# [396]	training's rmse: 0.87202	valid_1's rmse: 0.918863
# [397]	training's rmse: 0.871718	valid_1's rmse: 0.918735
# [398]	training's rmse: 0.87131	valid_1's rmse: 0.918628
# [399]	training's rmse: 0.870941	valid_1's rmse: 0.918462
# [400]	training's rmse: 0.870546	valid_1's rmse: 0.91814
# [401]	training's rmse: 0.870418	valid_1's rmse: 0.918036
# [402]	training's rmse: 0.870202	valid_1's rmse: 0.917994
# [403]	training's rmse: 0.869982	valid_1's rmse: 0.917902
# [404]	training's rmse: 0.869749	valid_1's rmse: 0.917655
# [405]	training's rmse: 0.869638	valid_1's rmse: 0.91761
# [406]	training's rmse: 0.869529	valid_1's rmse: 0.917541
# [407]	training's rmse: 0.86925	valid_1's rmse: 0.917107
# [408]	training's rmse: 0.869015	valid_1's rmse: 0.916956
# [409]	training's rmse: 0.868876	valid_1's rmse: 0.916913
# [410]	training's rmse: 0.868633	valid_1's rmse: 0.916751
# [411]	training's rmse: 0.868363	valid_1's rmse: 0.916547
# [412]	training's rmse: 0.867988	valid_1's rmse: 0.916252
# [413]	training's rmse: 0.867819	valid_1's rmse: 0.916032
# [414]	training's rmse: 0.867262	valid_1's rmse: 0.915812
# [415]	training's rmse: 0.866935	valid_1's rmse: 0.915412
# [416]	training's rmse: 0.86673	valid_1's rmse: 0.915204
# [417]	training's rmse: 0.865939	valid_1's rmse: 0.914278
# [418]	training's rmse: 0.865817	valid_1's rmse: 0.914055
# [419]	training's rmse: 0.865476	valid_1's rmse: 0.913802
# [420]	training's rmse: 0.865283	valid_1's rmse: 0.913821
# [421]	training's rmse: 0.865166	valid_1's rmse: 0.91364
# [422]	training's rmse: 0.864736	valid_1's rmse: 0.913314
# [423]	training's rmse: 0.86458	valid_1's rmse: 0.913148
# [424]	training's rmse: 0.86444	valid_1's rmse: 0.913049
# [425]	training's rmse: 0.864239	valid_1's rmse: 0.913
# [426]	training's rmse: 0.863987	valid_1's rmse: 0.912957
# [427]	training's rmse: 0.863837	valid_1's rmse: 0.912937
# [428]	training's rmse: 0.863532	valid_1's rmse: 0.912778
# [429]	training's rmse: 0.863186	valid_1's rmse: 0.912688
# [430]	training's rmse: 0.863061	valid_1's rmse: 0.9127
# [431]	training's rmse: 0.862457	valid_1's rmse: 0.911918
# [432]	training's rmse: 0.862253	valid_1's rmse: 0.911689
# [433]	training's rmse: 0.862133	valid_1's rmse: 0.911495
# [434]	training's rmse: 0.861951	valid_1's rmse: 0.911404
# [435]	training's rmse: 0.861666	valid_1's rmse: 0.911253
# [436]	training's rmse: 0.861508	valid_1's rmse: 0.911148
# [437]	training's rmse: 0.861332	valid_1's rmse: 0.911056
# [438]	training's rmse: 0.860836	valid_1's rmse: 0.910705
# [439]	training's rmse: 0.860644	valid_1's rmse: 0.910451
# [440]	training's rmse: 0.860206	valid_1's rmse: 0.910028
# [441]	training's rmse: 0.85999	valid_1's rmse: 0.909899
# [442]	training's rmse: 0.859825	valid_1's rmse: 0.909783
# [443]	training's rmse: 0.859598	valid_1's rmse: 0.909749
# [444]	training's rmse: 0.859472	valid_1's rmse: 0.909759
# [445]	training's rmse: 0.85922	valid_1's rmse: 0.909488
# [446]	training's rmse: 0.859051	valid_1's rmse: 0.90941
# [447]	training's rmse: 0.858875	valid_1's rmse: 0.908986
# [448]	training's rmse: 0.858505	valid_1's rmse: 0.908629
# [449]	training's rmse: 0.858319	valid_1's rmse: 0.908423
# [450]	training's rmse: 0.858	valid_1's rmse: 0.908101
# [451]	training's rmse: 0.857751	valid_1's rmse: 0.907824
# [452]	training's rmse: 0.857348	valid_1's rmse: 0.907533
# [453]	training's rmse: 0.857121	valid_1's rmse: 0.90744
# [454]	training's rmse: 0.856833	valid_1's rmse: 0.907171
# [455]	training's rmse: 0.856713	valid_1's rmse: 0.907202
# [456]	training's rmse: 0.856434	valid_1's rmse: 0.906932
# [457]	training's rmse: 0.855768	valid_1's rmse: 0.906206
# [458]	training's rmse: 0.855624	valid_1's rmse: 0.906116
# [459]	training's rmse: 0.85543	valid_1's rmse: 0.906016
# [460]	training's rmse: 0.855108	valid_1's rmse: 0.905545
# [461]	training's rmse: 0.854776	valid_1's rmse: 0.905191
# [462]	training's rmse: 0.854593	valid_1's rmse: 0.905121
# [463]	training's rmse: 0.85435	valid_1's rmse: 0.904939
# [464]	training's rmse: 0.854108	valid_1's rmse: 0.904612
# [465]	training's rmse: 0.854025	valid_1's rmse: 0.904589
# [466]	training's rmse: 0.853647	valid_1's rmse: 0.904171
# [467]	training's rmse: 0.853431	valid_1's rmse: 0.904162
# [468]	training's rmse: 0.853335	valid_1's rmse: 0.904212
# [469]	training's rmse: 0.853105	valid_1's rmse: 0.903929
# [470]	training's rmse: 0.85281	valid_1's rmse: 0.903691
# [471]	training's rmse: 0.85259	valid_1's rmse: 0.903525
# [472]	training's rmse: 0.852441	valid_1's rmse: 0.903382
# [473]	training's rmse: 0.852184	valid_1's rmse: 0.903003
# [474]	training's rmse: 0.852057	valid_1's rmse: 0.902958
# [475]	training's rmse: 0.851782	valid_1's rmse: 0.902546
# [476]	training's rmse: 0.851622	valid_1's rmse: 0.902341
# [477]	training's rmse: 0.85112	valid_1's rmse: 0.901874
# [478]	training's rmse: 0.850656	valid_1's rmse: 0.901518
# [479]	training's rmse: 0.850544	valid_1's rmse: 0.901482
# [480]	training's rmse: 0.850428	valid_1's rmse: 0.901386
# [481]	training's rmse: 0.849908	valid_1's rmse: 0.901225
# [482]	training's rmse: 0.849705	valid_1's rmse: 0.901293
# [483]	training's rmse: 0.849423	valid_1's rmse: 0.90116
# [484]	training's rmse: 0.849261	valid_1's rmse: 0.901046
# [485]	training's rmse: 0.84904	valid_1's rmse: 0.90087
# [486]	training's rmse: 0.848924	valid_1's rmse: 0.900747
# [487]	training's rmse: 0.848821	valid_1's rmse: 0.900671
# [488]	training's rmse: 0.848653	valid_1's rmse: 0.900559
# [489]	training's rmse: 0.848514	valid_1's rmse: 0.900504
# [490]	training's rmse: 0.848351	valid_1's rmse: 0.900441
# [491]	training's rmse: 0.848186	valid_1's rmse: 0.90039
# [492]	training's rmse: 0.847953	valid_1's rmse: 0.900248
# [493]	training's rmse: 0.847902	valid_1's rmse: 0.900219
# [494]	training's rmse: 0.847673	valid_1's rmse: 0.900176
# [495]	training's rmse: 0.847403	valid_1's rmse: 0.900205
# [496]	training's rmse: 0.847121	valid_1's rmse: 0.900081
# [497]	training's rmse: 0.847009	valid_1's rmse: 0.900009
# [498]	training's rmse: 0.846879	valid_1's rmse: 0.899921
# [499]	training's rmse: 0.846813	valid_1's rmse: 0.899962
# [500]	training's rmse: 0.846667	valid_1's rmse: 0.899937
# [501]	training's rmse: 0.846502	valid_1's rmse: 0.899992
# [502]	training's rmse: 0.84641	valid_1's rmse: 0.899984
# [503]	training's rmse: 0.845921	valid_1's rmse: 0.899792
# [504]	training's rmse: 0.845775	valid_1's rmse: 0.899688
# [505]	training's rmse: 0.845311	valid_1's rmse: 0.899334
# [506]	training's rmse: 0.844917	valid_1's rmse: 0.89853
# [507]	training's rmse: 0.844763	valid_1's rmse: 0.898388
# [508]	training's rmse: 0.844468	valid_1's rmse: 0.898104
# [509]	training's rmse: 0.844128	valid_1's rmse: 0.897916
# [510]	training's rmse: 0.843935	valid_1's rmse: 0.89777
# [511]	training's rmse: 0.843697	valid_1's rmse: 0.897536
# [512]	training's rmse: 0.843515	valid_1's rmse: 0.897486
# [513]	training's rmse: 0.843208	valid_1's rmse: 0.897
# [514]	training's rmse: 0.843095	valid_1's rmse: 0.897167
# [515]	training's rmse: 0.842878	valid_1's rmse: 0.897035
# [516]	training's rmse: 0.842528	valid_1's rmse: 0.896718
# [517]	training's rmse: 0.842381	valid_1's rmse: 0.896595
# [518]	training's rmse: 0.842246	valid_1's rmse: 0.896459
# [519]	training's rmse: 0.842101	valid_1's rmse: 0.896372
# [520]	training's rmse: 0.841528	valid_1's rmse: 0.895759
# [521]	training's rmse: 0.84121	valid_1's rmse: 0.895511
# [522]	training's rmse: 0.841016	valid_1's rmse: 0.895286
# [523]	training's rmse: 0.840863	valid_1's rmse: 0.895219
# [524]	training's rmse: 0.840732	valid_1's rmse: 0.895175
# [525]	training's rmse: 0.840474	valid_1's rmse: 0.89503
# [526]	training's rmse: 0.840367	valid_1's rmse: 0.89504
# [527]	training's rmse: 0.840242	valid_1's rmse: 0.894909
# [528]	training's rmse: 0.840191	valid_1's rmse: 0.894893
# [529]	training's rmse: 0.840048	valid_1's rmse: 0.894704
# [530]	training's rmse: 0.83991	valid_1's rmse: 0.894543
# [531]	training's rmse: 0.83916	valid_1's rmse: 0.893663
# [532]	training's rmse: 0.838644	valid_1's rmse: 0.89331
# [533]	training's rmse: 0.838407	valid_1's rmse: 0.893175
# [534]	training's rmse: 0.838254	valid_1's rmse: 0.893006
# [535]	training's rmse: 0.8382	valid_1's rmse: 0.892967
# [536]	training's rmse: 0.837973	valid_1's rmse: 0.892743
# [537]	training's rmse: 0.837527	valid_1's rmse: 0.892068
# [538]	training's rmse: 0.837297	valid_1's rmse: 0.891851
# [539]	training's rmse: 0.837186	valid_1's rmse: 0.891739
# [540]	training's rmse: 0.837069	valid_1's rmse: 0.891693
# [541]	training's rmse: 0.836823	valid_1's rmse: 0.891442
# [542]	training's rmse: 0.836755	valid_1's rmse: 0.891412
# [543]	training's rmse: 0.836586	valid_1's rmse: 0.891366
# [544]	training's rmse: 0.836184	valid_1's rmse: 0.891019
# [545]	training's rmse: 0.835983	valid_1's rmse: 0.89089
# [546]	training's rmse: 0.835836	valid_1's rmse: 0.890848
# [547]	training's rmse: 0.835397	valid_1's rmse: 0.890408
# [548]	training's rmse: 0.835193	valid_1's rmse: 0.890286
# [549]	training's rmse: 0.834987	valid_1's rmse: 0.887708
# [550]	training's rmse: 0.834555	valid_1's rmse: 0.887325
# [551]	training's rmse: 0.834347	valid_1's rmse: 0.88715
# [552]	training's rmse: 0.834052	valid_1's rmse: 0.886856
# [553]	training's rmse: 0.833597	valid_1's rmse: 0.88636
# [554]	training's rmse: 0.833217	valid_1's rmse: 0.885992
# [555]	training's rmse: 0.833008	valid_1's rmse: 0.885932
# [556]	training's rmse: 0.832638	valid_1's rmse: 0.885644
# [557]	training's rmse: 0.832499	valid_1's rmse: 0.885502
# [558]	training's rmse: 0.832333	valid_1's rmse: 0.885406
# [559]	training's rmse: 0.832169	valid_1's rmse: 0.885284
# [560]	training's rmse: 0.832122	valid_1's rmse: 0.885247
# [561]	training's rmse: 0.832045	valid_1's rmse: 0.885196
# [562]	training's rmse: 0.831997	valid_1's rmse: 0.88519
# [563]	training's rmse: 0.831559	valid_1's rmse: 0.884922
# [564]	training's rmse: 0.831348	valid_1's rmse: 0.884765
# [565]	training's rmse: 0.831195	valid_1's rmse: 0.884684
# [566]	training's rmse: 0.830447	valid_1's rmse: 0.884158
# [567]	training's rmse: 0.829854	valid_1's rmse: 0.883495
# [568]	training's rmse: 0.829618	valid_1's rmse: 0.88329
# [569]	training's rmse: 0.829522	valid_1's rmse: 0.8832
# [570]	training's rmse: 0.829191	valid_1's rmse: 0.882982
# [571]	training's rmse: 0.828913	valid_1's rmse: 0.882677
# [572]	training's rmse: 0.828682	valid_1's rmse: 0.882574
# [573]	training's rmse: 0.828589	valid_1's rmse: 0.882565
# [574]	training's rmse: 0.828184	valid_1's rmse: 0.882186
# [575]	training's rmse: 0.827917	valid_1's rmse: 0.882059
# [576]	training's rmse: 0.827298	valid_1's rmse: 0.881291
# [577]	training's rmse: 0.827062	valid_1's rmse: 0.881165
# [578]	training's rmse: 0.826908	valid_1's rmse: 0.880956
# [579]	training's rmse: 0.826505	valid_1's rmse: 0.880789
# [580]	training's rmse: 0.826214	valid_1's rmse: 0.88066
# [581]	training's rmse: 0.825736	valid_1's rmse: 0.880398
# [582]	training's rmse: 0.825539	valid_1's rmse: 0.880232
# [583]	training's rmse: 0.825401	valid_1's rmse: 0.88021
# [584]	training's rmse: 0.824984	valid_1's rmse: 0.879791
# [585]	training's rmse: 0.824837	valid_1's rmse: 0.879701
# [586]	training's rmse: 0.824667	valid_1's rmse: 0.879526
# [587]	training's rmse: 0.824388	valid_1's rmse: 0.879313
# [588]	training's rmse: 0.824072	valid_1's rmse: 0.878977
# [589]	training's rmse: 0.82395	valid_1's rmse: 0.878879
# [590]	training's rmse: 0.823822	valid_1's rmse: 0.878829
# [591]	training's rmse: 0.823667	valid_1's rmse: 0.878757
# [592]	training's rmse: 0.823502	valid_1's rmse: 0.878578
# [593]	training's rmse: 0.823025	valid_1's rmse: 0.878247
# [594]	training's rmse: 0.822807	valid_1's rmse: 0.878044
# [595]	training's rmse: 0.822498	valid_1's rmse: 0.877678
# [596]	training's rmse: 0.822345	valid_1's rmse: 0.877552
# [597]	training's rmse: 0.822074	valid_1's rmse: 0.877316
# [598]	training's rmse: 0.821946	valid_1's rmse: 0.877184
# [599]	training's rmse: 0.821761	valid_1's rmse: 0.877016
# [600]	training's rmse: 0.821606	valid_1's rmse: 0.876934
# [601]	training's rmse: 0.82136	valid_1's rmse: 0.876586
# [602]	training's rmse: 0.821266	valid_1's rmse: 0.876511
# [603]	training's rmse: 0.821187	valid_1's rmse: 0.876441
# [604]	training's rmse: 0.821068	valid_1's rmse: 0.87646
# [605]	training's rmse: 0.820852	valid_1's rmse: 0.87648
# [606]	training's rmse: 0.82075	valid_1's rmse: 0.876592
# [607]	training's rmse: 0.820662	valid_1's rmse: 0.876565
# [608]	training's rmse: 0.820472	valid_1's rmse: 0.876495
# [609]	training's rmse: 0.820228	valid_1's rmse: 0.876394
# [610]	training's rmse: 0.820145	valid_1's rmse: 0.876353
# [611]	training's rmse: 0.820083	valid_1's rmse: 0.876333
# [612]	training's rmse: 0.819833	valid_1's rmse: 0.876239
# [613]	training's rmse: 0.819635	valid_1's rmse: 0.876032
# [614]	training's rmse: 0.819373	valid_1's rmse: 0.875764
# [615]	training's rmse: 0.819076	valid_1's rmse: 0.875388
# [616]	training's rmse: 0.818506	valid_1's rmse: 0.874666
# [617]	training's rmse: 0.818304	valid_1's rmse: 0.874537
# [618]	training's rmse: 0.81813	valid_1's rmse: 0.874486
# [619]	training's rmse: 0.817801	valid_1's rmse: 0.874287
# [620]	training's rmse: 0.817634	valid_1's rmse: 0.874153
# [621]	training's rmse: 0.817483	valid_1's rmse: 0.874047
# [622]	training's rmse: 0.81729	valid_1's rmse: 0.873925
# [623]	training's rmse: 0.817042	valid_1's rmse: 0.87375
# [624]	training's rmse: 0.816934	valid_1's rmse: 0.873652
# [625]	training's rmse: 0.816744	valid_1's rmse: 0.873512
# [626]	training's rmse: 0.816555	valid_1's rmse: 0.873361
# [627]	training's rmse: 0.816408	valid_1's rmse: 0.873208
# [628]	training's rmse: 0.816329	valid_1's rmse: 0.873157
# [629]	training's rmse: 0.816202	valid_1's rmse: 0.873382
# [630]	training's rmse: 0.815877	valid_1's rmse: 0.873093
# [631]	training's rmse: 0.815696	valid_1's rmse: 0.873024
# [632]	training's rmse: 0.815576	valid_1's rmse: 0.872879
# [633]	training's rmse: 0.815332	valid_1's rmse: 0.872654
# [634]	training's rmse: 0.815155	valid_1's rmse: 0.872578
# [635]	training's rmse: 0.81502	valid_1's rmse: 0.872504
# [636]	training's rmse: 0.814825	valid_1's rmse: 0.872402
# [637]	training's rmse: 0.814514	valid_1's rmse: 0.872141
# [638]	training's rmse: 0.81429	valid_1's rmse: 0.871944
# [639]	training's rmse: 0.814069	valid_1's rmse: 0.871528
# [640]	training's rmse: 0.81388	valid_1's rmse: 0.87149
# [641]	training's rmse: 0.813668	valid_1's rmse: 0.871212
# [642]	training's rmse: 0.813583	valid_1's rmse: 0.871158
# [643]	training's rmse: 0.813455	valid_1's rmse: 0.871086
# [644]	training's rmse: 0.812699	valid_1's rmse: 0.870604
# [645]	training's rmse: 0.812485	valid_1's rmse: 0.870411
# [646]	training's rmse: 0.812262	valid_1's rmse: 0.870282
# [647]	training's rmse: 0.812152	valid_1's rmse: 0.870245
# [648]	training's rmse: 0.811821	valid_1's rmse: 0.869941
# [649]	training's rmse: 0.811672	valid_1's rmse: 0.86996
# [650]	training's rmse: 0.81154	valid_1's rmse: 0.869787
# [651]	training's rmse: 0.811366	valid_1's rmse: 0.869618
# [652]	training's rmse: 0.811297	valid_1's rmse: 0.869587
# [653]	training's rmse: 0.811229	valid_1's rmse: 0.869595
# [654]	training's rmse: 0.811189	valid_1's rmse: 0.86959
# [655]	training's rmse: 0.811108	valid_1's rmse: 0.869548
# [656]	training's rmse: 0.810992	valid_1's rmse: 0.869457
# [657]	training's rmse: 0.810886	valid_1's rmse: 0.869371
# [658]	training's rmse: 0.810802	valid_1's rmse: 0.869332
# [659]	training's rmse: 0.810701	valid_1's rmse: 0.869251
# [660]	training's rmse: 0.81065	valid_1's rmse: 0.869158
# [661]	training's rmse: 0.810555	valid_1's rmse: 0.869143
# [662]	training's rmse: 0.810367	valid_1's rmse: 0.868984
# [663]	training's rmse: 0.810303	valid_1's rmse: 0.868918
# [664]	training's rmse: 0.810222	valid_1's rmse: 0.8689
# [665]	training's rmse: 0.810126	valid_1's rmse: 0.868904
# [666]	training's rmse: 0.809714	valid_1's rmse: 0.868536
# [667]	training's rmse: 0.809579	valid_1's rmse: 0.868444
# [668]	training's rmse: 0.809431	valid_1's rmse: 0.868298
# [669]	training's rmse: 0.80933	valid_1's rmse: 0.868252
# [670]	training's rmse: 0.809106	valid_1's rmse: 0.868239
# [671]	training's rmse: 0.808998	valid_1's rmse: 0.868175
# [672]	training's rmse: 0.808904	valid_1's rmse: 0.86817
# [673]	training's rmse: 0.808815	valid_1's rmse: 0.868223
# [674]	training's rmse: 0.808736	valid_1's rmse: 0.868225
# [675]	training's rmse: 0.808626	valid_1's rmse: 0.868163
# [676]	training's rmse: 0.808506	valid_1's rmse: 0.868105
# [677]	training's rmse: 0.808329	valid_1's rmse: 0.868072
# [678]	training's rmse: 0.808195	valid_1's rmse: 0.86802
# [679]	training's rmse: 0.808057	valid_1's rmse: 0.867829
# [680]	training's rmse: 0.807985	valid_1's rmse: 0.867822
# [681]	training's rmse: 0.807956	valid_1's rmse: 0.867821
# [682]	training's rmse: 0.807765	valid_1's rmse: 0.867635
# [683]	training's rmse: 0.807684	valid_1's rmse: 0.86765
# [684]	training's rmse: 0.80759	valid_1's rmse: 0.867562
# [685]	training's rmse: 0.807421	valid_1's rmse: 0.867542
# [686]	training's rmse: 0.80727	valid_1's rmse: 0.867533
# [687]	training's rmse: 0.80711	valid_1's rmse: 0.867339
# [688]	training's rmse: 0.807021	valid_1's rmse: 0.867286
# [689]	training's rmse: 0.806901	valid_1's rmse: 0.867129
# [690]	training's rmse: 0.806689	valid_1's rmse: 0.867083
# [691]	training's rmse: 0.806326	valid_1's rmse: 0.866993
# [692]	training's rmse: 0.806178	valid_1's rmse: 0.866739
# [693]	training's rmse: 0.806082	valid_1's rmse: 0.866638
# [694]	training's rmse: 0.805938	valid_1's rmse: 0.866537
# [695]	training's rmse: 0.80585	valid_1's rmse: 0.866525
# [696]	training's rmse: 0.805605	valid_1's rmse: 0.86631
# [697]	training's rmse: 0.805477	valid_1's rmse: 0.866197
# [698]	training's rmse: 0.805252	valid_1's rmse: 0.866034
# [699]	training's rmse: 0.805021	valid_1's rmse: 0.865921
# [700]	training's rmse: 0.804761	valid_1's rmse: 0.865836
# [701]	training's rmse: 0.804694	valid_1's rmse: 0.865744
# [702]	training's rmse: 0.804508	valid_1's rmse: 0.865672
# [703]	training's rmse: 0.80443	valid_1's rmse: 0.86564
# [704]	training's rmse: 0.804315	valid_1's rmse: 0.865561
# [705]	training's rmse: 0.804198	valid_1's rmse: 0.865619
# [706]	training's rmse: 0.803915	valid_1's rmse: 0.865393
# [707]	training's rmse: 0.803688	valid_1's rmse: 0.86523
# [708]	training's rmse: 0.803444	valid_1's rmse: 0.865084
# [709]	training's rmse: 0.803288	valid_1's rmse: 0.864966
# [710]	training's rmse: 0.803146	valid_1's rmse: 0.864764
# [711]	training's rmse: 0.80302	valid_1's rmse: 0.864687
# [712]	training's rmse: 0.802931	valid_1's rmse: 0.865007
# [713]	training's rmse: 0.802624	valid_1's rmse: 0.86477
# [714]	training's rmse: 0.802518	valid_1's rmse: 0.864769
# [715]	training's rmse: 0.802377	valid_1's rmse: 0.864713
# [716]	training's rmse: 0.802277	valid_1's rmse: 0.86467
# [717]	training's rmse: 0.802186	valid_1's rmse: 0.864637
# [718]	training's rmse: 0.802022	valid_1's rmse: 0.864458
# [719]	training's rmse: 0.801834	valid_1's rmse: 0.864282
# [720]	training's rmse: 0.80173	valid_1's rmse: 0.864285
# [721]	training's rmse: 0.801589	valid_1's rmse: 0.864179
# [722]	training's rmse: 0.801545	valid_1's rmse: 0.864159
# [723]	training's rmse: 0.80144	valid_1's rmse: 0.864101
# [724]	training's rmse: 0.801336	valid_1's rmse: 0.864008
# [725]	training's rmse: 0.801133	valid_1's rmse: 0.863787
# [726]	training's rmse: 0.801021	valid_1's rmse: 0.863745
# [727]	training's rmse: 0.800873	valid_1's rmse: 0.863627
# [728]	training's rmse: 0.800686	valid_1's rmse: 0.86349
# [729]	training's rmse: 0.800602	valid_1's rmse: 0.863448
# [730]	training's rmse: 0.800014	valid_1's rmse: 0.863055
# [731]	training's rmse: 0.799815	valid_1's rmse: 0.862887
# [732]	training's rmse: 0.799747	valid_1's rmse: 0.862822
# [733]	training's rmse: 0.799186	valid_1's rmse: 0.86237
# [734]	training's rmse: 0.799076	valid_1's rmse: 0.862323
# [735]	training's rmse: 0.798934	valid_1's rmse: 0.862187
# [736]	training's rmse: 0.798688	valid_1's rmse: 0.861943
# [737]	training's rmse: 0.79843	valid_1's rmse: 0.861707
# [738]	training's rmse: 0.798072	valid_1's rmse: 0.861463
# [739]	training's rmse: 0.797985	valid_1's rmse: 0.861377
# [740]	training's rmse: 0.797854	valid_1's rmse: 0.861328
# [741]	training's rmse: 0.797619	valid_1's rmse: 0.861062
# [742]	training's rmse: 0.797411	valid_1's rmse: 0.861104
# [743]	training's rmse: 0.797314	valid_1's rmse: 0.861056
# [744]	training's rmse: 0.797098	valid_1's rmse: 0.860961
# [745]	training's rmse: 0.796868	valid_1's rmse: 0.86077
# [746]	training's rmse: 0.796765	valid_1's rmse: 0.860741
# [747]	training's rmse: 0.796591	valid_1's rmse: 0.860801
# [748]	training's rmse: 0.796466	valid_1's rmse: 0.860661
# [749]	training's rmse: 0.796307	valid_1's rmse: 0.860544
# [750]	training's rmse: 0.796055	valid_1's rmse: 0.860261
# [751]	training's rmse: 0.795957	valid_1's rmse: 0.860187
# [752]	training's rmse: 0.795852	valid_1's rmse: 0.860089
# [753]	training's rmse: 0.79572	valid_1's rmse: 0.860016
# [754]	training's rmse: 0.79562	valid_1's rmse: 0.860023
# [755]	training's rmse: 0.795533	valid_1's rmse: 0.860021
# [756]	training's rmse: 0.795284	valid_1's rmse: 0.859833
# [757]	training's rmse: 0.795212	valid_1's rmse: 0.859851
# [758]	training's rmse: 0.794958	valid_1's rmse: 0.859719
# [759]	training's rmse: 0.794719	valid_1's rmse: 0.859622
# [760]	training's rmse: 0.794426	valid_1's rmse: 0.859316
# [761]	training's rmse: 0.794234	valid_1's rmse: 0.859176
# [762]	training's rmse: 0.794142	valid_1's rmse: 0.859169
# [763]	training's rmse: 0.794074	valid_1's rmse: 0.85919
# [764]	training's rmse: 0.79391	valid_1's rmse: 0.85904
# [765]	training's rmse: 0.793554	valid_1's rmse: 0.85866
# [766]	training's rmse: 0.793452	valid_1's rmse: 0.858613
# [767]	training's rmse: 0.793295	valid_1's rmse: 0.858274
# [768]	training's rmse: 0.79324	valid_1's rmse: 0.858291
# [769]	training's rmse: 0.79316	valid_1's rmse: 0.858216
# [770]	training's rmse: 0.792975	valid_1's rmse: 0.858057
# [771]	training's rmse: 0.792782	valid_1's rmse: 0.857928
# [772]	training's rmse: 0.792494	valid_1's rmse: 0.857667
# [773]	training's rmse: 0.792334	valid_1's rmse: 0.857622
# [774]	training's rmse: 0.792223	valid_1's rmse: 0.857855
# [775]	training's rmse: 0.792147	valid_1's rmse: 0.857818
# [776]	training's rmse: 0.792036	valid_1's rmse: 0.85771
# [777]	training's rmse: 0.791663	valid_1's rmse: 0.857347
# [778]	training's rmse: 0.791574	valid_1's rmse: 0.857345
# [779]	training's rmse: 0.791429	valid_1's rmse: 0.857107
# [780]	training's rmse: 0.791236	valid_1's rmse: 0.856903
# [781]	training's rmse: 0.791107	valid_1's rmse: 0.856746
# [782]	training's rmse: 0.791054	valid_1's rmse: 0.856766
# [783]	training's rmse: 0.790972	valid_1's rmse: 0.856752
# [784]	training's rmse: 0.790871	valid_1's rmse: 0.856741
# [785]	training's rmse: 0.790814	valid_1's rmse: 0.856707
# [786]	training's rmse: 0.790769	valid_1's rmse: 0.856717
# [787]	training's rmse: 0.790514	valid_1's rmse: 0.856472
# [788]	training's rmse: 0.790443	valid_1's rmse: 0.856504
# [789]	training's rmse: 0.790362	valid_1's rmse: 0.856475
# [790]	training's rmse: 0.790287	valid_1's rmse: 0.856406
# [791]	training's rmse: 0.790133	valid_1's rmse: 0.85634
# [792]	training's rmse: 0.790011	valid_1's rmse: 0.856221
# [793]	training's rmse: 0.78996	valid_1's rmse: 0.856277
# [794]	training's rmse: 0.789841	valid_1's rmse: 0.856183
# [795]	training's rmse: 0.789587	valid_1's rmse: 0.855965
# [796]	training's rmse: 0.789492	valid_1's rmse: 0.85585
# [797]	training's rmse: 0.78944	valid_1's rmse: 0.855832
# [798]	training's rmse: 0.789364	valid_1's rmse: 0.855749
# [799]	training's rmse: 0.789232	valid_1's rmse: 0.855646
# [800]	training's rmse: 0.789091	valid_1's rmse: 0.855603
# [801]	training's rmse: 0.789034	valid_1's rmse: 0.855549
# [802]	training's rmse: 0.788968	valid_1's rmse: 0.855544
# [803]	training's rmse: 0.788847	valid_1's rmse: 0.855441
# [804]	training's rmse: 0.788749	valid_1's rmse: 0.855414
# [805]	training's rmse: 0.788647	valid_1's rmse: 0.855351
# [806]	training's rmse: 0.788532	valid_1's rmse: 0.855172
# [807]	training's rmse: 0.788435	valid_1's rmse: 0.855079
# [808]	training's rmse: 0.788336	valid_1's rmse: 0.854969
# [809]	training's rmse: 0.7882	valid_1's rmse: 0.854927
# [810]	training's rmse: 0.788113	valid_1's rmse: 0.854778
# [811]	training's rmse: 0.787986	valid_1's rmse: 0.854771
# [812]	training's rmse: 0.787918	valid_1's rmse: 0.854764
# [813]	training's rmse: 0.787844	valid_1's rmse: 0.854712
# [814]	training's rmse: 0.787783	valid_1's rmse: 0.85471
# [815]	training's rmse: 0.787646	valid_1's rmse: 0.854709
# [816]	training's rmse: 0.787539	valid_1's rmse: 0.854698
# [817]	training's rmse: 0.787345	valid_1's rmse: 0.854507
# [818]	training's rmse: 0.787247	valid_1's rmse: 0.854397
# [819]	training's rmse: 0.787094	valid_1's rmse: 0.854246
# [820]	training's rmse: 0.786906	valid_1's rmse: 0.854183
# [821]	training's rmse: 0.786745	valid_1's rmse: 0.854045
# [822]	training's rmse: 0.786681	valid_1's rmse: 0.854066
# [823]	training's rmse: 0.786586	valid_1's rmse: 0.854168
# [824]	training's rmse: 0.786533	valid_1's rmse: 0.854153
# [825]	training's rmse: 0.786434	valid_1's rmse: 0.854131
# [826]	training's rmse: 0.7862	valid_1's rmse: 0.853969
# [827]	training's rmse: 0.786136	valid_1's rmse: 0.854024
# [828]	training's rmse: 0.786024	valid_1's rmse: 0.853901
# [829]	training's rmse: 0.785974	valid_1's rmse: 0.853908
# [830]	training's rmse: 0.785881	valid_1's rmse: 0.853777
# [831]	training's rmse: 0.785586	valid_1's rmse: 0.853461
# [832]	training's rmse: 0.785463	valid_1's rmse: 0.853351
# [833]	training's rmse: 0.785429	valid_1's rmse: 0.853203
# [834]	training's rmse: 0.78533	valid_1's rmse: 0.853218
# [835]	training's rmse: 0.785212	valid_1's rmse: 0.85319
# [836]	training's rmse: 0.785144	valid_1's rmse: 0.853138
# [837]	training's rmse: 0.785118	valid_1's rmse: 0.853116
# [838]	training's rmse: 0.784997	valid_1's rmse: 0.853028
# [839]	training's rmse: 0.784856	valid_1's rmse: 0.853062
# [840]	training's rmse: 0.784719	valid_1's rmse: 0.853003
# [841]	training's rmse: 0.784549	valid_1's rmse: 0.852971
# [842]	training's rmse: 0.784519	valid_1's rmse: 0.85299
# [843]	training's rmse: 0.784452	valid_1's rmse: 0.852958
# [844]	training's rmse: 0.784358	valid_1's rmse: 0.852893
# [845]	training's rmse: 0.784067	valid_1's rmse: 0.852616
# [846]	training's rmse: 0.784026	valid_1's rmse: 0.852568
# [847]	training's rmse: 0.783978	valid_1's rmse: 0.852539
# [848]	training's rmse: 0.783885	valid_1's rmse: 0.852426
# [849]	training's rmse: 0.78381	valid_1's rmse: 0.852343
# [850]	training's rmse: 0.783769	valid_1's rmse: 0.852326
# [851]	training's rmse: 0.783687	valid_1's rmse: 0.852324
# [852]	training's rmse: 0.783632	valid_1's rmse: 0.852262
# [853]	training's rmse: 0.783435	valid_1's rmse: 0.852165
# [854]	training's rmse: 0.783277	valid_1's rmse: 0.852119
# [855]	training's rmse: 0.783136	valid_1's rmse: 0.85197
# [856]	training's rmse: 0.783069	valid_1's rmse: 0.851961
# [857]	training's rmse: 0.782933	valid_1's rmse: 0.851838
# [858]	training's rmse: 0.7828	valid_1's rmse: 0.851788
# [859]	training's rmse: 0.782703	valid_1's rmse: 0.851765
# [860]	training's rmse: 0.782571	valid_1's rmse: 0.851617
# [861]	training's rmse: 0.782309	valid_1's rmse: 0.851129
# [862]	training's rmse: 0.782223	valid_1's rmse: 0.851168
# [863]	training's rmse: 0.782144	valid_1's rmse: 0.851196
# [864]	training's rmse: 0.782036	valid_1's rmse: 0.851068
# [865]	training's rmse: 0.781945	valid_1's rmse: 0.851
# [866]	training's rmse: 0.781848	valid_1's rmse: 0.85099
# [867]	training's rmse: 0.781627	valid_1's rmse: 0.850882
# [868]	training's rmse: 0.781527	valid_1's rmse: 0.850846
# [869]	training's rmse: 0.78148	valid_1's rmse: 0.850817
# [870]	training's rmse: 0.781414	valid_1's rmse: 0.850761
# [871]	training's rmse: 0.78124	valid_1's rmse: 0.850488
# [872]	training's rmse: 0.781117	valid_1's rmse: 0.850484
# [873]	training's rmse: 0.780992	valid_1's rmse: 0.850288
# [874]	training's rmse: 0.780941	valid_1's rmse: 0.850219
# [875]	training's rmse: 0.780914	valid_1's rmse: 0.850208
# [876]	training's rmse: 0.780811	valid_1's rmse: 0.850083
# [877]	training's rmse: 0.780713	valid_1's rmse: 0.850034
# [878]	training's rmse: 0.780665	valid_1's rmse: 0.850026
# [879]	training's rmse: 0.780589	valid_1's rmse: 0.850029
# [880]	training's rmse: 0.780535	valid_1's rmse: 0.850039
# [881]	training's rmse: 0.780428	valid_1's rmse: 0.849995
# [882]	training's rmse: 0.78035	valid_1's rmse: 0.85001
# [883]	training's rmse: 0.780205	valid_1's rmse: 0.849826
# [884]	training's rmse: 0.780067	valid_1's rmse: 0.849673
# [885]	training's rmse: 0.779998	valid_1's rmse: 0.849708
# [886]	training's rmse: 0.77988	valid_1's rmse: 0.849714
# [887]	training's rmse: 0.779745	valid_1's rmse: 0.849667
# [888]	training's rmse: 0.779661	valid_1's rmse: 0.849582
# [889]	training's rmse: 0.779574	valid_1's rmse: 0.849531
# [890]	training's rmse: 0.779489	valid_1's rmse: 0.849443
# [891]	training's rmse: 0.779399	valid_1's rmse: 0.849483
# [892]	training's rmse: 0.779294	valid_1's rmse: 0.849356
# [893]	training's rmse: 0.779172	valid_1's rmse: 0.849242
# [894]	training's rmse: 0.779108	valid_1's rmse: 0.849207
# [895]	training's rmse: 0.778999	valid_1's rmse: 0.849015
# [896]	training's rmse: 0.778787	valid_1's rmse: 0.848934
# [897]	training's rmse: 0.778689	valid_1's rmse: 0.848846
# [898]	training's rmse: 0.778622	valid_1's rmse: 0.848833
# [899]	training's rmse: 0.778489	valid_1's rmse: 0.848894
# [900]	training's rmse: 0.778436	valid_1's rmse: 0.848879
# [901]	training's rmse: 0.778296	valid_1's rmse: 0.848768
# [902]	training's rmse: 0.778219	valid_1's rmse: 0.84876
# [903]	training's rmse: 0.778132	valid_1's rmse: 0.848685
# [904]	training's rmse: 0.777991	valid_1's rmse: 0.848625
# [905]	training's rmse: 0.77791	valid_1's rmse: 0.848642
# [906]	training's rmse: 0.777846	valid_1's rmse: 0.848626
# [907]	training's rmse: 0.777559	valid_1's rmse: 0.848449
# [908]	training's rmse: 0.777486	valid_1's rmse: 0.848356
# [909]	training's rmse: 0.777304	valid_1's rmse: 0.848298
# [910]	training's rmse: 0.777111	valid_1's rmse: 0.848073
# [911]	training's rmse: 0.776975	valid_1's rmse: 0.848
# [912]	training's rmse: 0.776912	valid_1's rmse: 0.848046
# [913]	training's rmse: 0.776851	valid_1's rmse: 0.848025
# [914]	training's rmse: 0.776712	valid_1's rmse: 0.847997
# [915]	training's rmse: 0.776539	valid_1's rmse: 0.847899
# [916]	training's rmse: 0.776413	valid_1's rmse: 0.847844
# [917]	training's rmse: 0.776384	valid_1's rmse: 0.847819
# [918]	training's rmse: 0.77626	valid_1's rmse: 0.847822
# [919]	training's rmse: 0.776233	valid_1's rmse: 0.847826
# [920]	training's rmse: 0.776172	valid_1's rmse: 0.847779
# [921]	training's rmse: 0.776009	valid_1's rmse: 0.845109
# [922]	training's rmse: 0.775886	valid_1's rmse: 0.84496
# [923]	training's rmse: 0.775835	valid_1's rmse: 0.844947
# [924]	training's rmse: 0.775586	valid_1's rmse: 0.844797
# [925]	training's rmse: 0.775466	valid_1's rmse: 0.844695
# [926]	training's rmse: 0.775411	valid_1's rmse: 0.844735
# [927]	training's rmse: 0.775275	valid_1's rmse: 0.844634
# [928]	training's rmse: 0.775161	valid_1's rmse: 0.844612
# [929]	training's rmse: 0.775057	valid_1's rmse: 0.844526
# [930]	training's rmse: 0.774985	valid_1's rmse: 0.844443
# [931]	training's rmse: 0.774873	valid_1's rmse: 0.844369
# [932]	training's rmse: 0.774718	valid_1's rmse: 0.844182
# [933]	training's rmse: 0.774658	valid_1's rmse: 0.844121
# [934]	training's rmse: 0.774481	valid_1's rmse: 0.844133
# [935]	training's rmse: 0.774343	valid_1's rmse: 0.844078
# [936]	training's rmse: 0.774264	valid_1's rmse: 0.844038
# [937]	training's rmse: 0.774086	valid_1's rmse: 0.843904
# [938]	training's rmse: 0.773906	valid_1's rmse: 0.843964
# [939]	training's rmse: 0.773839	valid_1's rmse: 0.843909
# [940]	training's rmse: 0.7737	valid_1's rmse: 0.843704
# [941]	training's rmse: 0.773535	valid_1's rmse: 0.843583
# [942]	training's rmse: 0.773492	valid_1's rmse: 0.84351
# [943]	training's rmse: 0.773438	valid_1's rmse: 0.843501
# [944]	training's rmse: 0.773263	valid_1's rmse: 0.843375
# [945]	training's rmse: 0.773162	valid_1's rmse: 0.843232
# [946]	training's rmse: 0.773015	valid_1's rmse: 0.843085
# [947]	training's rmse: 0.772916	valid_1's rmse: 0.842995
# [948]	training's rmse: 0.772795	valid_1's rmse: 0.842782
# [949]	training's rmse: 0.772654	valid_1's rmse: 0.842654
# [950]	training's rmse: 0.772534	valid_1's rmse: 0.842565
# [951]	training's rmse: 0.772313	valid_1's rmse: 0.84241
# [952]	training's rmse: 0.772168	valid_1's rmse: 0.842266
# [953]	training's rmse: 0.772116	valid_1's rmse: 0.842241
# [954]	training's rmse: 0.772022	valid_1's rmse: 0.842241
# [955]	training's rmse: 0.771927	valid_1's rmse: 0.842227
# [956]	training's rmse: 0.771783	valid_1's rmse: 0.842116
# [957]	training's rmse: 0.771727	valid_1's rmse: 0.842092
# [958]	training's rmse: 0.771666	valid_1's rmse: 0.842013
# [959]	training's rmse: 0.771369	valid_1's rmse: 0.841889
# [960]	training's rmse: 0.771273	valid_1's rmse: 0.841818
# [961]	training's rmse: 0.771183	valid_1's rmse: 0.841757
# [962]	training's rmse: 0.771057	valid_1's rmse: 0.841605
# [963]	training's rmse: 0.77103	valid_1's rmse: 0.841609
# [964]	training's rmse: 0.770984	valid_1's rmse: 0.841589
# [965]	training's rmse: 0.770952	valid_1's rmse: 0.841607
# [966]	training's rmse: 0.77083	valid_1's rmse: 0.841534
# [967]	training's rmse: 0.770667	valid_1's rmse: 0.841459
# [968]	training's rmse: 0.770627	valid_1's rmse: 0.841465
# [969]	training's rmse: 0.770505	valid_1's rmse: 0.841367
# [970]	training's rmse: 0.770448	valid_1's rmse: 0.840997
# [971]	training's rmse: 0.770404	valid_1's rmse: 0.840978
# [972]	training's rmse: 0.770351	valid_1's rmse: 0.840915
# [973]	training's rmse: 0.770275	valid_1's rmse: 0.840869
# [974]	training's rmse: 0.77014	valid_1's rmse: 0.840849
# [975]	training's rmse: 0.770096	valid_1's rmse: 0.840815
# [976]	training's rmse: 0.77005	valid_1's rmse: 0.840752
# [977]	training's rmse: 0.770014	valid_1's rmse: 0.840783
# [978]	training's rmse: 0.769961	valid_1's rmse: 0.840798
# [979]	training's rmse: 0.769918	valid_1's rmse: 0.840776
# [980]	training's rmse: 0.769861	valid_1's rmse: 0.840772
# [981]	training's rmse: 0.76982	valid_1's rmse: 0.840741
# [982]	training's rmse: 0.769744	valid_1's rmse: 0.840623
# [983]	training's rmse: 0.769712	valid_1's rmse: 0.840569
# [984]	training's rmse: 0.769625	valid_1's rmse: 0.840473
# [985]	training's rmse: 0.769562	valid_1's rmse: 0.840449
# [986]	training's rmse: 0.769484	valid_1's rmse: 0.840404
# [987]	training's rmse: 0.769409	valid_1's rmse: 0.840324
# [988]	training's rmse: 0.769252	valid_1's rmse: 0.840201
# [989]	training's rmse: 0.769173	valid_1's rmse: 0.840189
# [990]	training's rmse: 0.768985	valid_1's rmse: 0.840083
# [991]	training's rmse: 0.768849	valid_1's rmse: 0.839941
# [992]	training's rmse: 0.768752	valid_1's rmse: 0.839952
# [993]	training's rmse: 0.768655	valid_1's rmse: 0.839868
# [994]	training's rmse: 0.768562	valid_1's rmse: 0.839823
# [995]	training's rmse: 0.768498	valid_1's rmse: 0.839823
# [996]	training's rmse: 0.768441	valid_1's rmse: 0.839782
# [997]	training's rmse: 0.768368	valid_1's rmse: 0.839731
# [998]	training's rmse: 0.76821	valid_1's rmse: 0.839697
# [999]	training's rmse: 0.768112	valid_1's rmse: 0.839622
# [1000]	training's rmse: 0.768003	valid_1's rmse: 0.839609
# Did not meet early stopping. Best iteration is:
# [1000]	training's rmse: 0.768003	valid_1's rmse: 0.839609

# %%
import matplotlib as mlt
import matplotlib.pyplot as plt
# %matplotlib inline

lgb.plot_metric(evals_result, figsize=(12, 5))

# %%
pred = model.predict(temp)
pred = np.expm1(pred)
temp['AMT'] = np.round(pred, 0)
temp['REG_YYMM'] = temp['year']*100 + temp['month']
temp = temp[['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT']]
temp = temp.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM']).sum().reset_index(drop=False)

# %%
# 디코딩 (Random Forest)
temp['CARD_SIDO_NM'] = encoders['CARD_SIDO_NM'].inverse_transform(temp['CARD_SIDO_NM'])
temp['STD_CLSS_NM'] = encoders['STD_CLSS_NM'].inverse_transform(temp['STD_CLSS_NM'])

# %%
# 제출 파일 만들기(Random Forest)
submission = pd.read_csv('../../Data/Jeju/submission.csv', index_col=0)
submission = submission.drop(['AMT'], axis=1)
submission = submission.merge(temp, left_on=['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM'], right_on=['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM'], how='left')
submission.index.name = 'id'
compare_pred = submission.dropna()
submission = submission.fillna(0)
submission.head()
# Out:
#     REG_YYMM CARD_SIDO_NM           STD_CLSS_NM           AMT
# id
# 0     202004           강원            건강보조식품 소매업  4.772363e+07
# 1     202004           강원               골프장 운영업  2.675183e+09
# 2     202004           강원           과실 및 채소 소매업  7.556058e+08
# 3     202004           강원     관광 민예품 및 선물용품 소매업  1.044818e+07
# 4     202004           강원  그외 기타 분류안된 오락관련 서비스업  0.000000e+00

# %%
submission.to_csv('submission/submission lgbm 0728 valid March_re.csv', encoding='utf-8-sig')
